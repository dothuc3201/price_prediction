# %%
#imports các thư viện
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle
from sklearn.model_selection import KFold

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat


import keras.utils
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Input, concatenate, Dense
from keras.layers import LSTM, GRU
from sklearn.linear_model import LinearRegression
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
def rsi(data, period: int = 14):

    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity (độ trễ) - days or hours
lag_granularity = "hours"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "hour"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/" + \
    analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_" + \
    str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename, index_col='DateTime', parse_dates=True)

# %%
#group by datetime
df = df.groupby('DateTime').agg(lambda x: x.mean())
df
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\3489936249.py:2: FutureWarning: ['dt'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df = df.groupby('DateTime').agg(lambda x: x.mean())
#                              Close  Volume_(BTC)  Weighted_Price   neg_pol  \
# DateTime
# 2018-08-31 10:00:00+00:00  6949.40      2.333380     6948.996140  0.040167
# 2018-08-31 11:00:00+00:00  6946.06      2.430317     6948.538492  0.020167
# 2018-08-31 12:00:00+00:00  6963.30      3.922626     6964.052374  0.035800
# 2018-08-31 13:00:00+00:00  6900.00      9.040247     6932.162091  0.084000
# 2018-08-31 14:00:00+00:00  6927.92      5.947736     6912.448529  0.025333
# ...                            ...           ...             ...       ...
# 2019-11-23 11:00:00+00:00  7180.02      6.622678     7190.277423  0.067410
# 2019-11-23 12:00:00+00:00  7157.47      7.074875     7181.956969  0.072038
# 2019-11-23 13:00:00+00:00  7181.50      9.766378     7171.704462  0.072152
# 2019-11-23 14:00:00+00:00  7260.77      6.143298     7231.168406  0.064122
# 2019-11-23 15:00:00+00:00  7292.72      2.660796     7272.018586  0.063931
#
#                             neu_pol   pos_pol  compound  Tweet_vol
# DateTime
# 2018-08-31 10:00:00+00:00  0.876000  0.083833  0.155633       18.0
# 2018-08-31 11:00:00+00:00  0.865000  0.114833  0.246883       37.0
# 2018-08-31 12:00:00+00:00  0.839600  0.124600  0.254660       42.0
# 2018-08-31 13:00:00+00:00  0.789250  0.126917  0.218183       55.0
# 2018-08-31 14:00:00+00:00  0.861444  0.113222  0.263544       38.0
# ...                             ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00  0.760387  0.172199  0.250681     2304.0
# 2019-11-23 12:00:00+00:00  0.751780  0.176183  0.235377     2467.0
# 2019-11-23 13:00:00+00:00  0.756339  0.171514  0.245202     2612.0
# 2019-11-23 14:00:00+00:00  0.755714  0.180162  0.269456     2676.0
# 2019-11-23 15:00:00+00:00  0.754940  0.181127  0.254060     2271.0
#
# [10781 rows x 8 columns]

# %%
#tính toán các chỉ số indicator: rsi, ma
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = True
add_longMAvg = False
add_shortMAvg = False

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()

if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity', 'Tweet_vol', 'Volume_(BTC)'] if analyser == "Textblob" else [
    'Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")

if(add_longMAvg):
    features.append("long_mavg")

if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
data_with_lagged = df_copy.dropna()[-1000:]
data_with_lagged
# Out:
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2019-10-13 00:00:00+00:00       0  8303.43  0.183570  0.067381     1822.0
# 2019-10-13 01:00:00+00:00       1  8333.33  0.185161  0.060215     1618.0
# 2019-10-13 02:00:00+00:00       1  8349.07  0.195797  0.051072     1670.0
# 2019-10-13 03:00:00+00:00       0  8340.98  0.198426  0.058467     1778.0
# 2019-10-13 04:00:00+00:00       1  8346.46  0.202182  0.044574     1603.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI
# DateTime
# 2019-10-13 00:00:00+00:00  41.512649
# 2019-10-13 01:00:00+00:00  47.952750
# 2019-10-13 02:00:00+00:00  51.010831
# 2019-10-13 03:00:00+00:00  49.404102
# 2019-10-13 04:00:00+00:00  50.540542
# ...                              ...
# 2019-11-23 11:00:00+00:00  39.929000
# 2019-11-23 12:00:00+00:00  38.084247
# 2019-11-23 13:00:00+00:00  41.201744
# 2019-11-23 14:00:00+00:00  50.123331
# 2019-11-23 15:00:00+00:00  53.205251
#
# [1000 rows x 6 columns]

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)

scaler_data = data_with_lagged.iloc[:, 1:]
scaler_data = scaler_data.reset_index()
scaler_data = scaler_data.drop(['DateTime'], axis=1)

test = data_with_lagged.iloc[:train_size , 1]
test = test.reset_index()
test = test.drop(['DateTime'], axis=1)
scaler_data
# Out:
#        Close   pos_pol   neg_pol  Tweet_vol        RSI
# 0    8303.43  0.183570  0.067381     1822.0  41.512649
# 1    8333.33  0.185161  0.060215     1618.0  47.952750
# 2    8349.07  0.195797  0.051072     1670.0  51.010831
# 3    8340.98  0.198426  0.058467     1778.0  49.404102
# 4    8346.46  0.202182  0.044574     1603.0  50.540542
# ..       ...       ...       ...        ...        ...
# 995  7180.02  0.172199  0.067410     2304.0  39.929000
# 996  7157.47  0.176183  0.072038     2467.0  38.084247
# 997  7181.50  0.171514  0.072152     2612.0  41.201744
# 998  7260.77  0.180162  0.064122     2676.0  50.123331
# 999  7292.72  0.181127  0.063931     2271.0  53.205251
#
# [1000 rows x 5 columns]

# %%
#chuẩn hóa
xscaler = MinMaxScaler(feature_range=(0, 1))
yscaler = MinMaxScaler(feature_range=(0, 1))
# train = xscaler.fit_transform(train)
scaler_data = xscaler.fit_transform(scaler_data)
test = yscaler.fit_transform(test)

train = scaler_data[:train_size, :]
print(train.shape, scaler_data.shape)
# Out:
# (850, 5) (1000, 5)

# %%
X_train = []
y_train = []

for i in range(n_lag, len(train)):
  X_train.append(train[i-n_lag:i, :])
  y_train.append(test[i, :])

X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

print(X_train.shape, y_train.shape)
# Out:
# (843, 7, 5) (843, 1)

# %%
# design network
neurons = 64
epochs = 50
dropout = 0.25
batch_size = 80
activ_func = "relu"

# %%
# early stopping callback
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =20)

# %%
# Số fold
k = 5
kf = KFold(n_splits=k, shuffle=False)

# List để lưu kết quả dự đoán từ LSTM và GRU
lstm_predictions = []
gru_predictions = []

lstm_models = []
gru_models = []

# Xây dựng mô hình stacking
for train_index, test_index in kf.split(X_train):
    X_sub_train, X_sub_test = X_train[train_index], X_train[test_index]
    y_sub_train, y_sub_test = y_train[train_index], y_train[test_index]
    # Xây dựng mô hình LSTM và huấn luyện
    lstm_model = Sequential()
    lstm_model.add(LSTM(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    lstm_model.add(LSTM(neurons, return_sequences=False))
    lstm_model.add(Dense(1))
    lstm_model.compile(optimizer='adam', loss='mean_squared_error')

    # Xây dựng mô hình GRU và huấn luyện
    gru_model = Sequential()
    gru_model.add(GRU(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    gru_model.add(GRU(neurons, return_sequences=False))
    gru_model.add(Dense(1))
    gru_model.compile(optimizer='adam', loss='mean_squared_error')
    
    lstm_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    gru_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    # Lấy đầu ra của mô hình LSTM và GRU
    lstm_output = lstm_model.predict(X_sub_test)
    gru_output = gru_model.predict(X_sub_test)
    
    lstm_predictions.append(lstm_output)
    gru_predictions.append(gru_output)
    
    lstm_models.append(lstm_model)
    gru_models.append(gru_model)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 4s 15ms/step - loss: 0.1837
# Epoch 2/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0430
# Epoch 3/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0278
# Epoch 4/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0207
# Epoch 5/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0099
# Epoch 6/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0060
# Epoch 7/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0049
# Epoch 8/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0035
# Epoch 9/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0028
# Epoch 10/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0024
# Epoch 11/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 12/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 13/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 14/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 15/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 16/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 17/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 18/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 19/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 20/50
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0018
# Epoch 21/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 22/50
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0017
# Epoch 23/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 24/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 25/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0016
# Epoch 26/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 27/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0016
# Epoch 28/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 29/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 30/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0016
# Epoch 31/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 32/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 33/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 34/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 35/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 36/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 38/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 39/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 40/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 41/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 42/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 43/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 44/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 45/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 46/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 47/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 48/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 49/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 50/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 1/50
# 9/9 [==============================] - 3s 9ms/step - loss: 0.1531
# Epoch 2/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0463
# Epoch 3/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0269
# Epoch 4/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0194
# Epoch 5/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0061
# Epoch 6/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 7/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 8/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 9/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 10/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 11/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 12/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 13/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 14/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 15/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 16/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 17/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 18/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 19/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 21/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 22/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 23/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 24/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 25/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 26/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 27/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 28/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 29/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 30/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0011
# Epoch 31/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 32/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 33/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.9141e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.9662e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.5532e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.6067e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.2282e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.2670e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.7389e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.2464e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 8ms/step - loss: 8.6693e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 8ms/step - loss: 8.5919e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2251e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2521e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 16ms/step - loss: 8.0925e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 13ms/step - loss: 7.9434e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 16ms/step - loss: 8.3800e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.8943e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 8ms/step - loss: 7.7577e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 8ms/step - loss: 7.6025e-04
# 6/6 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 1s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 3s 10ms/step - loss: 0.1467
# Epoch 2/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0301
# Epoch 3/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0158
# Epoch 4/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0150
# Epoch 5/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0100
# Epoch 6/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0068
# Epoch 7/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0044
# Epoch 8/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 9/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 10/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 11/50
# 9/9 [==============================] - 0s 10ms/step - loss: 9.4479e-04
# Epoch 12/50
# 9/9 [==============================] - 0s 11ms/step - loss: 7.7253e-04
# Epoch 13/50
# 9/9 [==============================] - 0s 11ms/step - loss: 7.2327e-04
# Epoch 14/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.9729e-04
# Epoch 15/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.7488e-04
# Epoch 16/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.6731e-04
# Epoch 17/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.3702e-04
# Epoch 18/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.3168e-04
# Epoch 19/50
# 9/9 [==============================] - 0s 11ms/step - loss: 6.4889e-04
# Epoch 20/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.3403e-04
# Epoch 21/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.9476e-04
# Epoch 22/50
# 9/9 [==============================] - 0s 9ms/step - loss: 6.0213e-04
# Epoch 23/50
# 9/9 [==============================] - 0s 11ms/step - loss: 5.9110e-04
# Epoch 24/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.6684e-04
# Epoch 25/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.6469e-04
# Epoch 26/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.4578e-04
# Epoch 27/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.4475e-04
# Epoch 28/50
# 9/9 [==============================] - 0s 11ms/step - loss: 5.4511e-04
# Epoch 29/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.4016e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.2237e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.2376e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.1223e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.0339e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.9552e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 11ms/step - loss: 5.1834e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 11ms/step - loss: 5.9982e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.1392e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.7391e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.8927e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 17ms/step - loss: 5.2610e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.1457e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.7959e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.7274e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.5474e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 11ms/step - loss: 4.5206e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.4889e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.3887e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.3826e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.4348e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.4215e-04
# Epoch 1/50
# 9/9 [==============================] - 3s 9ms/step - loss: 0.0956
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0366
# Epoch 3/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0225
# Epoch 4/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0111
# Epoch 5/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0049
# Epoch 6/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 7/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 8/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 9/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.0223e-04
# Epoch 10/50
# 9/9 [==============================] - 0s 8ms/step - loss: 7.9074e-04
# Epoch 11/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.3687e-04
# Epoch 12/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.1298e-04
# Epoch 13/50
# 9/9 [==============================] - 0s 9ms/step - loss: 5.9464e-04
# Epoch 14/50
# 9/9 [==============================] - 0s 9ms/step - loss: 5.3157e-04
# Epoch 15/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.0269e-04
# Epoch 16/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.8699e-04
# Epoch 17/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.7130e-04
# Epoch 18/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6654e-04
# Epoch 19/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.5181e-04
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.4075e-04
# Epoch 21/50
# 9/9 [==============================] - 0s 15ms/step - loss: 4.3378e-04
# Epoch 22/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.3617e-04
# Epoch 23/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.5240e-04
# Epoch 24/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.1708e-04
# Epoch 25/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.0610e-04
# Epoch 26/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.1714e-04
# Epoch 27/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.8712e-04
# Epoch 28/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.8326e-04
# Epoch 29/50
# 9/9 [==============================] - 0s 10ms/step - loss: 3.8360e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.6357e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.5701e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 3.5472e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.5742e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.4211e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.4045e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 11ms/step - loss: 3.3719e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.6802e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 10ms/step - loss: 3.9185e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.9141e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.3356e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 10ms/step - loss: 3.5754e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.3541e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.0481e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.0629e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.1252e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.2633e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.2581e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.1635e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 9ms/step - loss: 3.2189e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.3914e-04
# 6/6 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 1s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 3s 10ms/step - loss: 0.1196
# Epoch 2/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0353
# Epoch 3/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0225
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0185
# Epoch 5/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0113
# Epoch 6/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0054
# Epoch 7/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 8/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 9/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0021
# Epoch 10/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 11/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 12/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 13/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0016
# Epoch 14/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0015
# Epoch 15/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 16/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 17/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 18/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 19/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 20/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 21/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 22/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 23/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 24/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 25/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 26/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 27/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 28/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 29/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0012
# Epoch 30/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 31/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 33/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 34/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 35/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0010
# Epoch 36/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 37/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 38/50
# 9/9 [==============================] - 0s 10ms/step - loss: 9.8338e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 40/50
# 9/9 [==============================] - 0s 12ms/step - loss: 9.8037e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 23ms/step - loss: 9.1207e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.8784e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.8751e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 16ms/step - loss: 9.8871e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 12ms/step - loss: 8.9959e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.8476e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.5788e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.4968e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 10ms/step - loss: 8.5691e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 10ms/step - loss: 8.4058e-04
# Epoch 1/50
# 9/9 [==============================] - 3s 8ms/step - loss: 0.1037
# Epoch 2/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0409
# Epoch 3/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0246
# Epoch 4/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0182
# Epoch 5/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0129
# Epoch 6/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0073
# Epoch 7/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0038
# Epoch 8/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0027
# Epoch 9/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 10/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 11/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 12/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 13/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 14/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 15/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 16/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 17/50
# 9/9 [==============================] - 0s 17ms/step - loss: 9.7304e-04
# Epoch 18/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.5206e-04
# Epoch 19/50
# 9/9 [==============================] - 0s 11ms/step - loss: 9.3075e-04
# Epoch 20/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.1599e-04
# Epoch 21/50
# 9/9 [==============================] - 0s 16ms/step - loss: 9.3470e-04
# Epoch 22/50
# 9/9 [==============================] - 0s 9ms/step - loss: 8.8654e-04
# Epoch 23/50
# 9/9 [==============================] - 0s 13ms/step - loss: 8.8743e-04
# Epoch 24/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.1457e-04
# Epoch 25/50
# 9/9 [==============================] - 0s 10ms/step - loss: 8.7120e-04
# Epoch 26/50
# 9/9 [==============================] - 0s 23ms/step - loss: 8.4598e-04
# Epoch 27/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.5102e-04
# Epoch 28/50
# 9/9 [==============================] - 0s 9ms/step - loss: 8.0234e-04
# Epoch 29/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.5856e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.4159e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.3984e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.4186e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.3072e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 11ms/step - loss: 7.3346e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.1293e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.9756e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.2635e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 30ms/step - loss: 6.7973e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 11ms/step - loss: 6.4830e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.4276e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 14ms/step - loss: 6.3063e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 13ms/step - loss: 6.2893e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 13ms/step - loss: 6.3949e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 17ms/step - loss: 6.2806e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 11ms/step - loss: 6.1767e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 9ms/step - loss: 6.1050e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.0142e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 10ms/step - loss: 5.9878e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 11ms/step - loss: 5.9854e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 15ms/step - loss: 5.9284e-04
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 1s 4ms/step
# Epoch 1/50
# 9/9 [==============================] - 3s 10ms/step - loss: 0.1004
# Epoch 2/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0396
# Epoch 3/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0236
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0173
# Epoch 5/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0098
# Epoch 6/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0042
# Epoch 7/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0029
# Epoch 8/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0025
# Epoch 9/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 10/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0021
# Epoch 11/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 12/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 13/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 14/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0018
# Epoch 15/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0017
# Epoch 16/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0016
# Epoch 17/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0016
# Epoch 18/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 19/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 20/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 21/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 22/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 23/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 24/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 25/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 26/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0013
# Epoch 27/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 28/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 29/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 30/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 31/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 33/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 34/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 35/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 36/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 37/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 38/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 39/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 40/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 41/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 42/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 43/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 44/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 45/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 46/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 47/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 48/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 49/50
# 9/9 [==============================] - 0s 10ms/step - loss: 9.6316e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 10ms/step - loss: 9.5310e-04
# Epoch 1/50
# 9/9 [==============================] - 4s 9ms/step - loss: 0.1005
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0342
# Epoch 3/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0201
# Epoch 4/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0110
# Epoch 5/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0055
# Epoch 6/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037
# Epoch 7/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 8/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0024
# Epoch 9/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 10/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 11/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 12/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 13/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 14/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 15/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 16/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0014
# Epoch 17/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 18/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 19/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 20/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 21/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 22/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 23/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 24/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 25/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 26/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 27/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 28/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0010
# Epoch 29/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 30/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.6352e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 9.0855e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 17ms/step - loss: 8.9509e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 12ms/step - loss: 8.5770e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 16ms/step - loss: 8.4378e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.2427e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.9710e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.8292e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 11ms/step - loss: 7.6273e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.4114e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.3837e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.3994e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.0848e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 10ms/step - loss: 6.9358e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 15ms/step - loss: 7.5623e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 14ms/step - loss: 6.7776e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 14ms/step - loss: 6.7990e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 13ms/step - loss: 6.6490e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 21ms/step - loss: 6.5637e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 14ms/step - loss: 6.1141e-04
# 6/6 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 1s 5ms/step
# Epoch 1/50
# 9/9 [==============================] - 4s 10ms/step - loss: 0.1821
# Epoch 2/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0539
# Epoch 3/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0382
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0245
# Epoch 5/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0111
# Epoch 6/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0038
# Epoch 7/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0031
# Epoch 8/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0023
# Epoch 9/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0022
# Epoch 10/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 11/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 12/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 13/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 14/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 15/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 16/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 17/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 18/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 19/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 20/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 21/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0015
# Epoch 22/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 23/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 24/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 25/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 26/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 27/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 28/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 29/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 30/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 31/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 32/50
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0012
# Epoch 33/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 34/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 35/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 36/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 37/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 38/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 39/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 40/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0010
# Epoch 41/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 42/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 43/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 44/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0010
# Epoch 45/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 46/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 47/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 48/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 49/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 50/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.8773e-04
# Epoch 1/50
# 9/9 [==============================] - 4s 13ms/step - loss: 0.1811
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0454
# Epoch 3/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0247
# Epoch 4/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0131
# Epoch 5/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0039
# Epoch 6/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 7/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0019
# Epoch 8/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 9/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 10/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 11/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 12/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 13/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 14/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 15/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 16/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 17/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 18/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 19/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 20/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 21/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 22/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 23/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 24/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 25/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 26/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 27/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 28/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0010
# Epoch 29/50
# 9/9 [==============================] - 0s 12ms/step - loss: 9.8230e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 11ms/step - loss: 9.2473e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 11ms/step - loss: 9.2058e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 9.3472e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 10ms/step - loss: 8.8778e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 10ms/step - loss: 8.1625e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.1227e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 10ms/step - loss: 8.3051e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.7270e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.7139e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.8049e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.6084e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 12ms/step - loss: 8.4745e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 20ms/step - loss: 7.9750e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 12ms/step - loss: 7.9774e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 13ms/step - loss: 8.0119e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 15ms/step - loss: 7.9275e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 13ms/step - loss: 7.0937e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 12ms/step - loss: 7.1111e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 11ms/step - loss: 6.6828e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 12ms/step - loss: 6.9419e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 15ms/step - loss: 6.4260e-04
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 1s 3ms/step

# %%
type(lstm_predictions)
# Out:
# list

# %%
# Lấy đầu ra của LSTM và GRU
lstm_outputs = np.concatenate(lstm_predictions, axis=0)
gru_outputs = np.concatenate(gru_predictions, axis=0)

# %%
from numpy import column_stack

lstm_outputs = yscaler.inverse_transform(lstm_outputs)
gru_outputs = yscaler.inverse_transform(gru_outputs)

y_train = yscaler.inverse_transform(y_train)

stacking_inputs = column_stack((lstm_outputs, gru_outputs))

# %%
stacking_inputs
# Out:
# array([[8331.13 , 8342.704],
#        [8312.832, 8326.011],
#        [8301.794, 8332.466],
#        ...,
#        [8467.952, 8488.742],
#        [8450.87 , 8446.888],
#        [8496.33 , 8500.482]], dtype=float32)

# %%
# stacking_model = Sequential()
# stacking_model.add(Dense(2, input_shape=(stacking_inputs.shape[1],)))
# stacking_model.add(Dense(1, activation='linear'))
# stacking_model.compile(optimizer='adam', loss='mean_squared_error')

stacking_model = LinearRegression()

# Train stacking model
stacking_model.fit(stacking_inputs, y_train)
# Out:
# LinearRegression()

# %%
#tạo testing data set
test_data = scaler_data[train_size - n_lag: , :]
x_test = []
y_test = data_with_lagged.iloc[train_size:, 1]
y_test = y_test.reset_index()
y_test = y_test.drop(['DateTime'], axis=1)

for i in range(n_lag, len(test_data)):
  x_test.append(test_data[i-n_lag:i, :])

x_test = np.asarray(x_test)
print(x_test.shape, y_test.shape)
# Out:
# (150, 7, 5) (150, 1)

# %%
#get the models predicted price value
lstm_test_predictions = []
gru_test_predictions = []

for i in range(5):
  lstm_test_prediction = lstm_models[i].predict(x_test)
  gru_test_prediction = gru_models[i].predict(x_test)
  
  lstm_test_prediction = yscaler.inverse_transform(lstm_test_prediction)
  gru_test_prediction = yscaler.inverse_transform(gru_test_prediction)
  
  lstm_test_predictions.append(lstm_test_prediction)
  gru_test_predictions.append(gru_test_prediction)

lstm_test_predictions = sum(lstm_test_predictions) / len(lstm_test_predictions)
gru_test_predictions = sum(gru_test_predictions) / len(gru_test_predictions)

stacking_close_predictions = stacking_model.predict(column_stack((lstm_test_predictions, gru_test_predictions)))

# stacking_close_predictions = xscaler.inverse_transform(stacking_close_predictions)
# stacking_close_predictions.to_csv("pred-price.csv", index=False)
stacking_close_predictions.shape
# Out:
# 5/5 [==============================] - 0s 6ms/step
# 5/5 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# (150, 1)

# %%
#sai số
mse = np.mean((y_test - stacking_close_predictions)**2)
mae = np.mean(np.abs(y_test - stacking_close_predictions))
mape = np.mean(np.abs((y_test - stacking_close_predictions) / y_test)) * 100
smape = 200 * np.mean(np.abs((y_test - stacking_close_predictions) / (np.abs(y_test) + np.abs(stacking_close_predictions))))
print(mse["Close"], mae["Close"], mape["Close"], smape["Close"])

#sai số
mseLSTM = np.mean((y_test - lstm_test_predictions)**2)
maeLSTM = np.mean(np.abs(y_test - lstm_test_predictions))
mapeLSTM = np.mean(np.abs((y_test - lstm_test_predictions) / y_test)) * 100
smapeLSTM = 200 * np.mean(np.abs((y_test - lstm_test_predictions) / (np.abs(y_test) + np.abs(lstm_test_predictions))))
print(mseLSTM["Close"], maeLSTM["Close"], mapeLSTM["Close"], smapeLSTM["Close"])

#sai số
mseGRU = np.mean((y_test - gru_test_predictions)**2)
maeGRU = np.mean(np.abs(y_test - gru_test_predictions))
mapeGRU = np.mean(np.abs((y_test - gru_test_predictions) / y_test)) * 100
smapeGRU = 200 * np.mean(np.abs((y_test - gru_test_predictions) / (np.abs(y_test) + np.abs(gru_test_predictions))))
print(mseGRU["Close"], maeGRU["Close"], mapeGRU["Close"], smapeGRU["Close"])
# Out:
# 3642.2617955385304 43.3195819010417 0.557559194342875 0.5565083555440559
# 9019.151357222945 60.954761588541686 0.8025139639407227 0.7950965280081542
# 4916.366968236676 46.6763986979167 0.6086526061223281 0.6053275046242799
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#
valid = data_with_lagged[train_size:]
valid['SE'] = stacking_close_predictions
valid['LSTM'] = lstm_test_predictions
valid['GRU'] = gru_test_predictions

#hiển thị dữ liệu gần đây
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Giá (USD)', fontsize=18)
plt.plot(valid[['Close','SE','LSTM', 'GRU']])
plt.legend(['Val', 'SE', 'LSTM', 'GRU'], loc='lower right')
plt.show()
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\871103454.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['SE'] = stacking_close_predictions
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\871103454.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['LSTM'] = lstm_test_predictions
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\871103454.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['GRU'] = gru_test_predictions

# %%
#create file if it does not exist
data = {
    'Model': 'SE',
    'Thông tin': ['MAE', 'MSE', 'MAPE', 'sMAPE'],
    'Price + Twitter': [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]
}
result_table = pd.read_csv("result-hours.csv")
result_table['Price + Twitter'] = [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]
result_table.to_csv("result-hours.csv", index=False)
result_table
# Out:
#   Model Thông tin        Price  Price + Twitter
# 0    SE       MAE    45.411735        43.319582
# 1    SE       MSE  3660.381269      3642.261796
# 2    SE      MAPE     0.583582         0.557559
# 3    SE     sMAPE     0.582781         0.556508

# %%
valid["PredSE"] = (valid["SE"] > valid["SE"].shift(1)).astype(int)
valid["PredLSTM"] = (valid["LSTM"] > valid["LSTM"].shift(1)).astype(int)
valid["PredGRU"] = (valid["GRU"] > valid["GRU"].shift(1)).astype(int)
valid["CorrectSE"] = (valid["PredSE"] - valid["Change"]) == 0
valid["CorrectLSTM"] = (valid["PredLSTM"] - valid["Change"]) == 0
valid["CorrectGRU"] = (valid["PredGRU"] - valid["Change"]) == 0
incorrect = valid.loc[valid['CorrectSE'] == False]
incorrect_len = len(incorrect)
prices_len = len(valid)
print("Accuracy = ",((prices_len-incorrect_len + 1)/prices_len))
print("Accuracy = ",((len(valid.loc[valid['CorrectLSTM'] == True]) + 1)/prices_len))
print("Accuracy = ",((len(valid.loc[valid['CorrectGRU'] == True]) + 1)/prices_len))
valid
# Out:
# Accuracy =  0.5533333333333333
# Accuracy =  0.4666666666666667
# Accuracy =  0.48
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\1832410782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["PredSE"] = (valid["SE"] > valid["SE"].shift(1)).astype(int)
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\1832410782.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["PredLSTM"] = (valid["LSTM"] > valid["LSTM"].shift(1)).astype(int)
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\1832410782.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["PredGRU"] = (valid["GRU"] > valid["GRU"].shift(1)).astype(int)
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\1832410782.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["CorrectSE"] = (valid["PredSE"] - valid["Change"]) == 0
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\1832410782.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["CorrectLSTM"] = (valid["PredLSTM"] - valid["Change"]) == 0
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_14148\1832410782.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["CorrectGRU"] = (valid["PredGRU"] - valid["Change"]) == 0
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2019-11-17 10:00:00+00:00       0  8521.51  0.179613  0.086724     2003.0
# 2019-11-17 11:00:00+00:00       0  8517.85  0.176844  0.083686     2095.0
# 2019-11-17 12:00:00+00:00       1  8562.34  0.178609  0.089045     2209.0
# 2019-11-17 13:00:00+00:00       0  8533.17  0.174711  0.071781     2239.0
# 2019-11-17 14:00:00+00:00       0  8516.54  0.188581  0.061722     2492.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI           SE         LSTM          GRU  \
# DateTime
# 2019-11-17 10:00:00+00:00  55.449108  8556.452148  8504.948242  8528.521484
# 2019-11-17 11:00:00+00:00  54.785894  8517.917969  8519.822266  8511.084961
# 2019-11-17 12:00:00+00:00  60.906931  8487.010742  8519.337891  8492.345703
# 2019-11-17 13:00:00+00:00  55.592844  8496.989258  8529.391602  8502.185547
# 2019-11-17 14:00:00+00:00  52.766279  8506.987305  8527.509766  8507.466797
# ...                              ...          ...          ...          ...
# 2019-11-23 11:00:00+00:00  39.929000  7220.375977  7292.329590  7262.125000
# 2019-11-23 12:00:00+00:00  38.084247  7218.072754  7295.136719  7261.817383
# 2019-11-23 13:00:00+00:00  41.201744  7192.022949  7289.054688  7243.850098
# 2019-11-23 14:00:00+00:00  50.123331  7193.086914  7290.584473  7245.075195
# 2019-11-23 15:00:00+00:00  53.205251  7271.625488  7311.760742  7300.331055
#
#                            PredSE  PredLSTM  PredGRU  CorrectSE  CorrectLSTM  \
# DateTime
# 2019-11-17 10:00:00+00:00       0         0        0       True         True
# 2019-11-17 11:00:00+00:00       0         1        0       True        False
# 2019-11-17 12:00:00+00:00       0         0        0      False        False
# 2019-11-17 13:00:00+00:00       1         1        1      False        False
# 2019-11-17 14:00:00+00:00       1         0        1      False         True
# ...                           ...       ...      ...        ...          ...
# 2019-11-23 11:00:00+00:00       1         1        1       True         True
# 2019-11-23 12:00:00+00:00       0         1        0       True        False
# 2019-11-23 13:00:00+00:00       0         0        0      False        False
# 2019-11-23 14:00:00+00:00       1         1        1       True         True
# 2019-11-23 15:00:00+00:00       1         1        1       True         True
#
#                            CorrectGRU
# DateTime
# 2019-11-17 10:00:00+00:00        True
# 2019-11-17 11:00:00+00:00        True
# 2019-11-17 12:00:00+00:00       False
# 2019-11-17 13:00:00+00:00       False
# 2019-11-17 14:00:00+00:00       False
# ...                               ...
# 2019-11-23 11:00:00+00:00        True
# 2019-11-23 12:00:00+00:00        True
# 2019-11-23 13:00:00+00:00       False
# 2019-11-23 14:00:00+00:00        True
# 2019-11-23 15:00:00+00:00        True
#
# [150 rows x 15 columns]
