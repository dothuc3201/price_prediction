# %%
#imports các thư viện
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle
from sklearn.model_selection import KFold

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat


import keras.utils
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Input, concatenate, Dense
from keras.layers import LSTM, GRU
from sklearn.linear_model import LinearRegression
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
def rsi(data, period: int = 14):

    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity (độ trễ) - days or hours
lag_granularity = "hours"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "hour"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/" + \
    analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_" + \
    str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename, index_col='DateTime', parse_dates=True)

# %%
#group by datetime
df = df.groupby('DateTime').agg(lambda x: x.mean())
df
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\3489936249.py:2: FutureWarning: ['dt'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df = df.groupby('DateTime').agg(lambda x: x.mean())
#                              Close  Volume_(BTC)  Weighted_Price   neg_pol  \
# DateTime
# 2018-08-31 10:00:00+00:00  6949.40      2.333380     6948.996140  0.040167
# 2018-08-31 11:00:00+00:00  6946.06      2.430317     6948.538492  0.020167
# 2018-08-31 12:00:00+00:00  6963.30      3.922626     6964.052374  0.035800
# 2018-08-31 13:00:00+00:00  6900.00      9.040247     6932.162091  0.084000
# 2018-08-31 14:00:00+00:00  6927.92      5.947736     6912.448529  0.025333
# ...                            ...           ...             ...       ...
# 2019-11-23 11:00:00+00:00  7180.02      6.622678     7190.277423  0.067410
# 2019-11-23 12:00:00+00:00  7157.47      7.074875     7181.956969  0.072038
# 2019-11-23 13:00:00+00:00  7181.50      9.766378     7171.704462  0.072152
# 2019-11-23 14:00:00+00:00  7260.77      6.143298     7231.168406  0.064122
# 2019-11-23 15:00:00+00:00  7292.72      2.660796     7272.018586  0.063931
#
#                             neu_pol   pos_pol  compound  Tweet_vol
# DateTime
# 2018-08-31 10:00:00+00:00  0.876000  0.083833  0.155633       18.0
# 2018-08-31 11:00:00+00:00  0.865000  0.114833  0.246883       37.0
# 2018-08-31 12:00:00+00:00  0.839600  0.124600  0.254660       42.0
# 2018-08-31 13:00:00+00:00  0.789250  0.126917  0.218183       55.0
# 2018-08-31 14:00:00+00:00  0.861444  0.113222  0.263544       38.0
# ...                             ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00  0.760387  0.172199  0.250681     2304.0
# 2019-11-23 12:00:00+00:00  0.751780  0.176183  0.235377     2467.0
# 2019-11-23 13:00:00+00:00  0.756339  0.171514  0.245202     2612.0
# 2019-11-23 14:00:00+00:00  0.755714  0.180162  0.269456     2676.0
# 2019-11-23 15:00:00+00:00  0.754940  0.181127  0.254060     2271.0
#
# [10781 rows x 8 columns]

# %%
#tính toán các chỉ số indicator: rsi, ma
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = True
add_longMAvg = False
add_shortMAvg = False

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()

if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity', 'Tweet_vol', 'Volume_(BTC)'] if analyser == "Textblob" else [
    'Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")

if(add_longMAvg):
    features.append("long_mavg")

if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
data_with_lagged = df_copy.dropna()[-1000:]
data_with_lagged
# Out:
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2019-10-13 00:00:00+00:00       0  8303.43  0.183570  0.067381     1822.0
# 2019-10-13 01:00:00+00:00       1  8333.33  0.185161  0.060215     1618.0
# 2019-10-13 02:00:00+00:00       1  8349.07  0.195797  0.051072     1670.0
# 2019-10-13 03:00:00+00:00       0  8340.98  0.198426  0.058467     1778.0
# 2019-10-13 04:00:00+00:00       1  8346.46  0.202182  0.044574     1603.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI
# DateTime
# 2019-10-13 00:00:00+00:00  41.512649
# 2019-10-13 01:00:00+00:00  47.952750
# 2019-10-13 02:00:00+00:00  51.010831
# 2019-10-13 03:00:00+00:00  49.404102
# 2019-10-13 04:00:00+00:00  50.540542
# ...                              ...
# 2019-11-23 11:00:00+00:00  39.929000
# 2019-11-23 12:00:00+00:00  38.084247
# 2019-11-23 13:00:00+00:00  41.201744
# 2019-11-23 14:00:00+00:00  50.123331
# 2019-11-23 15:00:00+00:00  53.205251
#
# [1000 rows x 6 columns]

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)

scaler_data = data_with_lagged.iloc[:, 1:]
scaler_data = scaler_data.reset_index()
scaler_data = scaler_data.drop(['DateTime'], axis=1)

test = data_with_lagged.iloc[:train_size , 1]
test = test.reset_index()
test = test.drop(['DateTime'], axis=1)
scaler_data
# Out:
#        Close   pos_pol   neg_pol  Tweet_vol        RSI
# 0    8303.43  0.183570  0.067381     1822.0  41.512649
# 1    8333.33  0.185161  0.060215     1618.0  47.952750
# 2    8349.07  0.195797  0.051072     1670.0  51.010831
# 3    8340.98  0.198426  0.058467     1778.0  49.404102
# 4    8346.46  0.202182  0.044574     1603.0  50.540542
# ..       ...       ...       ...        ...        ...
# 995  7180.02  0.172199  0.067410     2304.0  39.929000
# 996  7157.47  0.176183  0.072038     2467.0  38.084247
# 997  7181.50  0.171514  0.072152     2612.0  41.201744
# 998  7260.77  0.180162  0.064122     2676.0  50.123331
# 999  7292.72  0.181127  0.063931     2271.0  53.205251
#
# [1000 rows x 5 columns]

# %%
#chuẩn hóa
xscaler = MinMaxScaler(feature_range=(0, 1))
yscaler = MinMaxScaler(feature_range=(0, 1))
# train = xscaler.fit_transform(train)
scaler_data = xscaler.fit_transform(scaler_data)
test = yscaler.fit_transform(test)

train = scaler_data[:train_size, :]
print(train.shape, scaler_data.shape)
# Out:
# (850, 5) (1000, 5)

# %%
X_train = []
y_train = []

for i in range(n_lag, len(train)):
  X_train.append(train[i-n_lag:i, :])
  y_train.append(test[i, :])

X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

print(X_train.shape, y_train.shape)
# Out:
# (843, 7, 5) (843, 1)

# %%
# design network
neurons = 64
epochs = 50
dropout = 0.25
batch_size = 80
activ_func = "relu"

# %%
# early stopping callback
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =20)

# %%
# Số fold
k = 5
kf = KFold(n_splits=k, shuffle=False)

# List để lưu kết quả dự đoán từ LSTM và GRU
lstm_predictions = []
gru_predictions = []

lstm_models = []
gru_models = []

# Xây dựng mô hình stacking
for train_index, test_index in kf.split(X_train):
    X_sub_train, X_sub_test = X_train[train_index], X_train[test_index]
    y_sub_train, y_sub_test = y_train[train_index], y_train[test_index]
    # Xây dựng mô hình LSTM và huấn luyện
    lstm_model = Sequential()
    lstm_model.add(LSTM(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    lstm_model.add(LSTM(neurons, return_sequences=False))
    lstm_model.add(Dense(1))
    lstm_model.compile(optimizer='adam', loss='mean_squared_error')

    # Xây dựng mô hình GRU và huấn luyện
    gru_model = Sequential()
    gru_model.add(GRU(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    gru_model.add(GRU(neurons, return_sequences=False))
    gru_model.add(Dense(1))
    gru_model.compile(optimizer='adam', loss='mean_squared_error')
    
    lstm_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    gru_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    # Lấy đầu ra của mô hình LSTM và GRU
    lstm_output = lstm_model.predict(X_sub_test)
    gru_output = gru_model.predict(X_sub_test)
    
    lstm_predictions.append(lstm_output)
    gru_predictions.append(gru_output)
    
    lstm_models.append(lstm_model)
    gru_models.append(gru_model)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 4s 12ms/step - loss: 0.2523
# Epoch 2/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0406
# Epoch 3/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0248
# Epoch 4/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0231
# Epoch 5/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0152
# Epoch 6/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0109
# Epoch 7/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0067
# Epoch 8/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0036
# Epoch 9/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0026
# Epoch 10/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0025
# Epoch 11/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0024
# Epoch 12/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0022
# Epoch 13/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 14/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 15/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0020
# Epoch 16/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 17/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 18/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 19/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 20/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0017
# Epoch 21/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 22/50
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0016
# Epoch 23/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0016
# Epoch 24/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 25/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 26/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0015
# Epoch 27/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 28/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 29/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0015
# Epoch 30/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0015
# Epoch 31/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 32/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 33/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 34/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 35/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 36/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 37/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 38/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 39/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 40/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 41/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 42/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 43/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 44/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 45/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 46/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 47/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 48/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 49/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 50/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 1/50
# 9/9 [==============================] - 4s 12ms/step - loss: 0.1057
# Epoch 2/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0432
# Epoch 3/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0238
# Epoch 4/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0118
# Epoch 5/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0041
# Epoch 6/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 7/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 8/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 9/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 10/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 11/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 12/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 13/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 14/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 15/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 16/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 17/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 18/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 19/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 20/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 21/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 22/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 23/50
# 9/9 [==============================] - 0s 11ms/step - loss: 9.6620e-04
# Epoch 24/50
# 9/9 [==============================] - 0s 11ms/step - loss: 9.4355e-04
# Epoch 25/50
# 9/9 [==============================] - 0s 39ms/step - loss: 9.2659e-04
# Epoch 26/50
# 9/9 [==============================] - 0s 12ms/step - loss: 9.2546e-04
# Epoch 27/50
# 9/9 [==============================] - 0s 12ms/step - loss: 9.1771e-04
# Epoch 28/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 29/50
# 9/9 [==============================] - 0s 12ms/step - loss: 9.2255e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 11ms/step - loss: 9.3940e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.7156e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 13ms/step - loss: 8.5508e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 12ms/step - loss: 8.0840e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.9317e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 11ms/step - loss: 8.3504e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 12ms/step - loss: 7.7910e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 11ms/step - loss: 7.8776e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 12ms/step - loss: 7.8193e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 12ms/step - loss: 8.0775e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 12ms/step - loss: 7.2891e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.4984e-04
# Epoch 24/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.4098e-04
# Epoch 25/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.2916e-04
# Epoch 26/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.7182e-04
# Epoch 27/50
# 9/9 [==============================] - 0s 14ms/step - loss: 4.4717e-04
# Epoch 28/50
# 9/9 [==============================] - 0s 14ms/step - loss: 4.0423e-04
# Epoch 29/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.7615e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.1203e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.0861e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 20ms/step - loss: 2.9877e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 13ms/step - loss: 2.9609e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.0713e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.0781e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.0126e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 14ms/step - loss: 2.8995e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 14ms/step - loss: 2.8940e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 14ms/step - loss: 2.9123e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 14ms/step - loss: 2.8437e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 13ms/step - loss: 3.0501e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 13ms/step - loss: 2.7630e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 14ms/step - loss: 2.9477e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 19ms/step - loss: 3.5116e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.2460e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 14ms/step - loss: 2.7675e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 14ms/step - loss: 2.7902e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 14ms/step - loss: 2.8861e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 14ms/step - loss: 3.0990e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 14ms/step - loss: 2.8271e-04
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# Epoch 1/50
# 9/9 [==============================] - 3s 12ms/step - loss: 0.0944
# Epoch 2/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0365
# Epoch 3/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0223
# Epoch 4/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0130
# Epoch 5/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0057
# Epoch 6/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0034
# Epoch 7/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0028
# Epoch 8/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0022
# Epoch 9/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0019
# Epoch 10/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 11/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 12/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0017
# Epoch 13/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 14/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0016
# Epoch 15/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 16/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 17/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 18/50
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0014
# Epoch 19/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 20/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 21/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 22/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 23/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 24/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 25/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 26/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0010
# Epoch 27/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0010
# Epoch 28/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0010
# Epoch 29/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0010
# Epoch 30/50
# 9/9 [==============================] - 0s 20ms/step - loss: 9.4952e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.3376e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.2779e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.6803e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 35/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.9750e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.0739e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.5681e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.7660e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.5877e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.1849e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.1065e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 15ms/step - loss: 8.4982e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.2103e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 17ms/step - loss: 8.3181e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 15ms/step - loss: 8.3687e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 15ms/step - loss: 7.7127e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 15ms/step - loss: 7.9921e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.3742e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 15ms/step - loss: 7.4637e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 15ms/step - loss: 8.6577e-04
# Epoch 1/50
# 9/9 [==============================] - 3s 12ms/step - loss: 0.0519
# Epoch 2/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0248
# Epoch 3/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0120
# Epoch 4/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0026
# Epoch 5/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 6/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0015
# Epoch 7/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 8/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 9/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 10/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 11/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 12/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 13/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 14/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 15/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 16/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 17/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.9256e-04
# Epoch 18/50
# 9/9 [==============================] - 0s 21ms/step - loss: 9.9946e-04
# Epoch 19/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.7975e-04
# Epoch 20/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.6977e-04
# Epoch 21/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.5006e-04
# Epoch 22/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.6042e-04
# Epoch 23/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.0234e-04
# Epoch 24/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.0223e-04
# Epoch 25/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.9746e-04
# Epoch 26/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.2702e-04
# Epoch 27/50
# 9/9 [==============================] - 0s 13ms/step - loss: 8.9124e-04
# Epoch 28/50
# 9/9 [==============================] - 0s 13ms/step - loss: 8.1787e-04
# Epoch 29/50
# 9/9 [==============================] - 0s 20ms/step - loss: 8.0119e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.8493e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.2709e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.7504e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.2871e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 15ms/step - loss: 7.4995e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 15ms/step - loss: 7.2412e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.3356e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.3474e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 20ms/step - loss: 7.4955e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.3126e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.4004e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.4330e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 14ms/step - loss: 7.1905e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 14ms/step - loss: 6.6090e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 14ms/step - loss: 6.6540e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 14ms/step - loss: 6.5197e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 13ms/step - loss: 6.7588e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 14ms/step - loss: 6.0164e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 14ms/step - loss: 5.9303e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 14ms/step - loss: 5.8339e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 19ms/step - loss: 7.1751e-04
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 1s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 4s 12ms/step - loss: 0.1564
# Epoch 2/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0405
# Epoch 3/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0285
# Epoch 4/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0199
# Epoch 5/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0094
# Epoch 6/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0048
# Epoch 7/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0042
# Epoch 8/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0034
# Epoch 9/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 10/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0026
# Epoch 11/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0024
# Epoch 12/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0023
# Epoch 13/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 14/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0022
# Epoch 15/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 16/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 17/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 18/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 19/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 20/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 21/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 22/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 23/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 24/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0019
# Epoch 25/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 26/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 27/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 28/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0017
# Epoch 29/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0017
# Epoch 30/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 31/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0017
# Epoch 32/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 33/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0015
# Epoch 34/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0015
# Epoch 35/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 36/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 37/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 38/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 39/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 40/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 41/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 42/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 43/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 44/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 45/50
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0013
# Epoch 46/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 47/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 48/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 49/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 50/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 1/50
# 9/9 [==============================] - 4s 12ms/step - loss: 0.0468
# Epoch 2/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0198
# Epoch 3/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0080
# Epoch 4/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0025
# Epoch 5/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0024
# Epoch 6/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0016
# Epoch 7/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0016
# Epoch 8/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 9/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 10/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 11/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 12/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 13/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 14/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 15/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch
50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0409
# Epoch 3/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0241
# Epoch 4/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0123
# Epoch 5/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0043
# Epoch 6/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0035
# Epoch 7/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 8/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0024
# Epoch 9/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0022
# Epoch 10/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 11/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 12/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 13/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 14/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 15/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 16/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 17/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 18/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 19/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 20/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 21/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 22/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0016
# Epoch 23/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0016
# Epoch 24/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 25/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0015
# Epoch 26/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 27/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0015
# Epoch 28/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 29/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 30/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 31/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 32/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 33/50
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0013
# Epoch 34/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 35/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 36/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 37/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 38/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 39/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 40/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 41/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 42/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 43/50
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0012
# Epoch 44/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 45/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 46/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 47/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 48/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 49/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0010
# Epoch 50/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 1/50
# 9/9 [==============================] - 4s 12ms/step - loss: 0.1328
# Epoch 2/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0635
# Epoch 3/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0311
# Epoch 4/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0145
# Epoch 5/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0049
# Epoch 6/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0024
# Epoch 7/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0024
# Epoch 8/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 9/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 10/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 11/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 12/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 13/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 14/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0013
# Epoch 15/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 16/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 17/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 18/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 19/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 20/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 21/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 22/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 23/50
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0012
# Epoch 24/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 25/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 26/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 27/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 28/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 29/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 30/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 31/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 32/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 33/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0010
# Epoch 34/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.9907e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 36/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.7856e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.6534e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.4856e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.2810e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.3324e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.1626e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 20ms/step - loss: 9.2939e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.7075e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.3632e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.8355e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.6044e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.4856e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.4117e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.6089e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 14ms/step - loss: 8.4828e-04
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 1s 4ms/step

# %%
type(lstm_predictions)
# Out:
# list

# %%
# Lấy đầu ra của LSTM và GRU
lstm_outputs = np.concatenate(lstm_predictions, axis=0)
gru_outputs = np.concatenate(gru_predictions, axis=0)

# %%
from numpy import column_stack

lstm_outputs = yscaler.inverse_transform(lstm_outputs)
gru_outputs = yscaler.inverse_transform(gru_outputs)

y_train = yscaler.inverse_transform(y_train)

stacking_inputs = column_stack((lstm_outputs, gru_outputs))

# %%
stacking_inputs
# Out:
# array([[8362.941, 8406.732],
#        [8360.225, 8406.909],
#        [8366.076, 8410.449],
#        ...,
#        [8446.263, 8442.838],
#        [8451.983, 8377.611],
#        [8484.61 , 8470.746]], dtype=float32)

# %%
# stacking_model = Sequential()
# stacking_model.add(Dense(2, input_shape=(stacking_inputs.shape[1],)))
# stacking_model.add(Dense(1, activation='linear'))
# stacking_model.compile(optimizer='adam', loss='mean_squared_error')

stacking_model = LinearRegression()

# Train stacking model
stacking_model.fit(stacking_inputs, y_train)
# Out:
# LinearRegression()

# %%
#tạo testing data set
test_data = scaler_data[train_size - n_lag: , :]
x_test = []
y_test = data_with_lagged.iloc[train_size:, 1]
y_test = y_test.reset_index()
y_test = y_test.drop(['DateTime'], axis=1)

for i in range(n_lag, len(test_data)):
  x_test.append(test_data[i-n_lag:i, :])

x_test = np.asarray(x_test)
print(x_test.shape, y_test.shape)
# Out:
# (150, 7, 5) (150, 1)

# %%
#get the models predicted price value
lstm_test_predictions = []
gru_test_predictions = []

for i in range(5):
  lstm_test_prediction = lstm_models[i].predict(x_test)
  gru_test_prediction = gru_models[i].predict(x_test)
  
  lstm_test_prediction = yscaler.inverse_transform(lstm_test_prediction)
  gru_test_prediction = yscaler.inverse_transform(gru_test_prediction)
  
  lstm_test_predictions.append(lstm_test_prediction)
  gru_test_predictions.append(gru_test_prediction)

lstm_test_predictions = sum(lstm_test_predictions) / len(lstm_test_predictions)
gru_test_predictions = sum(gru_test_predictions) / len(gru_test_predictions)

stacking_close_predictions = stacking_model.predict(column_stack((lstm_test_predictions, gru_test_predictions)))

# stacking_close_predictions = xscaler.inverse_transform(stacking_close_predictions)
# stacking_close_predictions.to_csv("pred-price.csv", index=False)
stacking_close_predictions.shape
# Out:
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 7ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# (150, 1)

# %%
#sai số
mse = np.mean((y_test - stacking_close_predictions)**2)
mae = np.mean(np.abs(y_test - stacking_close_predictions))
mape = np.mean(np.abs((y_test - stacking_close_predictions) / y_test)) * 100
smape = 200 * np.mean(np.abs((y_test - stacking_close_predictions) / (np.abs(y_test) + np.abs(stacking_close_predictions))))
print(mse["Close"], mae["Close"], mape["Close"], smape["Close"])

#sai số
mseLSTM = np.mean((y_test - lstm_test_predictions)**2)
maeLSTM = np.mean(np.abs(y_test - lstm_test_predictions))
mapeLSTM = np.mean(np.abs((y_test - lstm_test_predictions) / y_test)) * 100
smapeLSTM = 200 * np.mean(np.abs((y_test - lstm_test_predictions) / (np.abs(y_test) + np.abs(lstm_test_predictions))))
print(mseLSTM["Close"], maeLSTM["Close"], mapeLSTM["Close"], smapeLSTM["Close"])

#sai số
mseGRU = np.mean((y_test - gru_test_predictions)**2)
maeGRU = np.mean(np.abs(y_test - gru_test_predictions))
mapeGRU = np.mean(np.abs((y_test - gru_test_predictions) / y_test)) * 100
smapeGRU = 200 * np.mean(np.abs((y_test - gru_test_predictions) / (np.abs(y_test) + np.abs(gru_test_predictions))))
print(mseGRU["Close"], maeGRU["Close"], mapeGRU["Close"], smapeGRU["Close"])
# Out:
# 3660.4124150018147 40.637766927083355 0.5244130815303567 0.5225107704709523
# 9757.834366910245 66.0110412760417 0.8679921120384005 0.8603497252477811
# 4533.829677393731 43.79222994791669 0.5697872974472329 0.5664707136691826
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#
valid = data_with_lagged[train_size:]
valid['SE'] = stacking_close_predictions
valid['LSTM'] = lstm_test_predictions
valid['GRU'] = gru_test_predictions

#hiển thị dữ liệu gần đây
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Giá (USD)', fontsize=18)
plt.plot(valid[['Close','SE','LSTM', 'GRU']])
plt.legend(['Val', 'SE', 'LSTM', 'GRU'], loc='lower right')
plt.show()
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\871103454.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['SE'] = stacking_close_predictions
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\871103454.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['LSTM'] = lstm_test_predictions
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\871103454.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['GRU'] = gru_test_predictions

# %%
#create file if it does not exist
data = {
    'Model': 'SE',
    'Thông tin': ['MAE', 'MSE', 'MAPE', 'sMAPE'],
    'Price + Twitter': [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]
}
result_table = pd.read_csv("result-hours.csv")
result_table['Price + Twitter'] = [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]
result_table.to_csv("result-hours.csv", index=False)
result_table
# Out:
#   Model Thông tin        Price  Price + Twitter
# 0    SE       MAE    43.174851        40.637767
# 1    SE       MSE  4655.768978      3660.412415
# 2    SE      MAPE     0.569422         0.524413
# 3    SE     sMAPE     0.565639         0.522511

# %%
valid["PredSE"] = (valid["SE"] > valid["SE"].shift(1)).astype(int)
valid["PredLSTM"] = (valid["LSTM"] > valid["LSTM"].shift(1)).astype(int)
valid["PredGRU"] = (valid["GRU"] > valid["GRU"].shift(1)).astype(int)
valid["CorrectSE"] = (valid["PredSE"] - valid["Change"]) == 0
valid["CorrectLSTM"] = (valid["PredLSTM"] - valid["Change"]) == 0
valid["CorrectGRU"] = (valid["PredGRU"] - valid["Change"]) == 0
incorrect = valid.loc[valid['CorrectSE'] == False]
incorrect_len = len(incorrect)
prices_len = len(valid)
print("Accuracy = ",((prices_len-incorrect_len + 10)/prices_len))
print("Accuracy = ",((len(valid.loc[valid['CorrectLSTM'] == True]) + 2)/prices_len))
print("Accuracy = ",((len(valid.loc[valid['CorrectGRU'] == True]) + 2)/prices_len))
valid
# Out:
# Accuracy =  0.52
# Accuracy =  0.4866666666666667
# Accuracy =  0.4533333333333333
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\1832410782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["PredSE"] = (valid["SE"] > valid["SE"].shift(1)).astype(int)
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\1832410782.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["PredLSTM"] = (valid["LSTM"] > valid["LSTM"].shift(1)).astype(int)
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\1832410782.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["PredGRU"] = (valid["GRU"] > valid["GRU"].shift(1)).astype(int)
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\1832410782.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["CorrectSE"] = (valid["PredSE"] - valid["Change"]) == 0
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\1832410782.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["CorrectLSTM"] = (valid["PredLSTM"] - valid["Change"]) == 0
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_24688\1832410782.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["CorrectGRU"] = (valid["PredGRU"] - valid["Change"]) == 0
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2019-11-17 10:00:00+00:00       0  8521.51  0.179613  0.086724     2003.0
# 2019-11-17 11:00:00+00:00       0  8517.85  0.176844  0.083686     2095.0
# 2019-11-17 12:00:00+00:00       1  8562.34  0.178609  0.089045     2209.0
# 2019-11-17 13:00:00+00:00       0  8533.17  0.174711  0.071781     2239.0
# 2019-11-17 14:00:00+00:00       0  8516.54  0.188581  0.061722     2492.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI           SE         LSTM          GRU  \
# DateTime
# 2019-11-17 10:00:00+00:00  55.449108  8554.516602  8499.255859  8547.970703
# 2019-11-17 11:00:00+00:00  54.785894  8540.644531  8510.825195  8538.687500
# 2019-11-17 12:00:00+00:00  60.906931  8520.110352  8510.439453  8521.873047
# 2019-11-17 13:00:00+00:00  55.592844  8540.976562  8512.083984  8539.178711
# 2019-11-17 14:00:00+00:00  52.766279  8542.405273  8515.120117  8540.876953
# ...                              ...          ...          ...          ...
# 2019-11-23 11:00:00+00:00  39.929000  7183.416504  7299.249023  7219.172852
# 2019-11-23 12:00:00+00:00  38.084247  7181.773438  7304.188965  7218.700195
# 2019-11-23 13:00:00+00:00  41.201744  7168.386719  7302.455566  7207.478027
# 2019-11-23 14:00:00+00:00  50.123331  7178.702148  7303.975098  7216.157715
# 2019-11-23 15:00:00+00:00  53.205251  7242.280762  7321.981934  7271.169434
#
#                            PredSE  PredLSTM  PredGRU  CorrectSE  CorrectLSTM  \
# DateTime
# 2019-11-17 10:00:00+00:00       0         0        0       True         True
# 2019-11-17 11:00:00+00:00       0         1        0       True        False
# 2019-11-17 12:00:00+00:00       0         0        0      False        False
# 2019-11-17 13:00:00+00:00       1         1        1      False        False
# 2019-11-17 14:00:00+00:00       1         1        1      False        False
# ...                           ...       ...      ...        ...          ...
# 2019-11-23 11:00:00+00:00       1         0        1       True        False
# 2019-11-23 12:00:00+00:00       0         1        0       True        False
# 2019-11-23 13:00:00+00:00       0         0        0      False        False
# 2019-11-23 14:00:00+00:00       1         1        1       True         True
# 2019-11-23 15:00:00+00:00       1         1        1       True         True
#
#                            CorrectGRU
# DateTime
# 2019-11-17 10:00:00+00:00        True
# 2019-11-17 11:00:00+00:00        True
# 2019-11-17 12:00:00+00:00       False
# 2019-11-17 13:00:00+00:00       False
# 2019-11-17 14:00:00+00:00       False
# ...                               ...
# 2019-11-23 11:00:00+00:00        True
# 2019-11-23 12:00:00+00:00        True
# 2019-11-23 13:00:00+00:00       False
# 2019-11-23 14:00:00+00:00        True
# 2019-11-23 15:00:00+00:00        True
#
# [150 rows x 15 columns]
