# %%
#imports các thư viện
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle
from sklearn.model_selection import KFold

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat


import keras.utils
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Input, concatenate, Dense
from keras.layers import LSTM, GRU
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
def rsi(data, period: int = 14):

    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity (độ trễ) - days or hours
lag_granularity = "hours"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "hour"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/" + \
    analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_" + \
    str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename, index_col='DateTime', parse_dates=True)

# %%
#group by datetime
df = df.groupby('DateTime').agg(lambda x: x.mean())
df
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_11652\3489936249.py:2: FutureWarning: ['dt'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df = df.groupby('DateTime').agg(lambda x: x.mean())
#                              Close  Volume_(BTC)  Weighted_Price   neg_pol  \
# DateTime
# 2018-08-31 10:00:00+00:00  6949.40      2.333380     6948.996140  0.040167
# 2018-08-31 11:00:00+00:00  6946.06      2.430317     6948.538492  0.020167
# 2018-08-31 12:00:00+00:00  6963.30      3.922626     6964.052374  0.035800
# 2018-08-31 13:00:00+00:00  6900.00      9.040247     6932.162091  0.084000
# 2018-08-31 14:00:00+00:00  6927.92      5.947736     6912.448529  0.025333
# ...                            ...           ...             ...       ...
# 2019-11-23 11:00:00+00:00  7180.02      6.622678     7190.277423  0.067410
# 2019-11-23 12:00:00+00:00  7157.47      7.074875     7181.956969  0.072038
# 2019-11-23 13:00:00+00:00  7181.50      9.766378     7171.704462  0.072152
# 2019-11-23 14:00:00+00:00  7260.77      6.143298     7231.168406  0.064122
# 2019-11-23 15:00:00+00:00  7292.72      2.660796     7272.018586  0.063931
#
#                             neu_pol   pos_pol  compound  Tweet_vol
# DateTime
# 2018-08-31 10:00:00+00:00  0.876000  0.083833  0.155633       18.0
# 2018-08-31 11:00:00+00:00  0.865000  0.114833  0.246883       37.0
# 2018-08-31 12:00:00+00:00  0.839600  0.124600  0.254660       42.0
# 2018-08-31 13:00:00+00:00  0.789250  0.126917  0.218183       55.0
# 2018-08-31 14:00:00+00:00  0.861444  0.113222  0.263544       38.0
# ...                             ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00  0.760387  0.172199  0.250681     2304.0
# 2019-11-23 12:00:00+00:00  0.751780  0.176183  0.235377     2467.0
# 2019-11-23 13:00:00+00:00  0.756339  0.171514  0.245202     2612.0
# 2019-11-23 14:00:00+00:00  0.755714  0.180162  0.269456     2676.0
# 2019-11-23 15:00:00+00:00  0.754940  0.181127  0.254060     2271.0
#
# [10781 rows x 8 columns]

# %%
#tính toán các chỉ số indicator: rsi, ma
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = True
add_longMAvg = True
add_shortMAvg = True

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()

if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_11652\259356298.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_11652\259356298.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity', 'Tweet_vol', 'Volume_(BTC)'] if analyser == "Textblob" else [
    'Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")

if(add_longMAvg):
    features.append("long_mavg")

if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
data_with_lagged = df_copy.dropna()
data_with_lagged
# Out:
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2018-09-01 21:00:00+00:00       0  7195.95  0.070500  0.019000       30.0
# 2018-09-01 22:00:00+00:00       0  7187.23  0.073000  0.073833       37.0
# 2018-09-01 23:00:00+00:00       1  7189.90  0.152250  0.032000       30.0
# 2018-09-02 00:00:00+00:00       1  7197.50  0.063333  0.040333       31.0
# 2018-09-02 01:00:00+00:00       0  7159.99  0.233667  0.000000       18.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI    long_mavg   short_mavg
# DateTime
# 2018-09-01 21:00:00+00:00  65.930409  7097.183810  7156.526667
# 2018-09-01 22:00:00+00:00  64.172838  7104.425238  7173.410000
# 2018-09-01 23:00:00+00:00  64.485028  7111.765714  7188.968889
# 2018-09-02 00:00:00+00:00  65.408993  7119.059048  7197.981111
# 2018-09-02 01:00:00+00:00  57.462959  7123.820476  7196.502222
# ...                              ...          ...          ...
# 2019-11-23 11:00:00+00:00  39.929000  7223.752857  7204.497778
# 2019-11-23 12:00:00+00:00  38.084247  7225.775238  7190.205556
# 2019-11-23 13:00:00+00:00  41.201744  7228.573810  7185.751111
# 2019-11-23 14:00:00+00:00  50.123331  7233.933810  7189.787778
# 2019-11-23 15:00:00+00:00  53.205251  7236.630476  7196.947778
#
# [10727 rows x 8 columns]

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)

train = data_with_lagged.iloc[:train_size]
train = train.reset_index()
train = train.drop(['DateTime'], axis=1)

train
# Out:
#       Change     Close   pos_pol   neg_pol  Tweet_vol        RSI  \
# 0          0   7195.95  0.070500  0.019000       30.0  65.930409
# 1          0   7187.23  0.073000  0.073833       37.0  64.172838
# 2          1   7189.90  0.152250  0.032000       30.0  64.485028
# 3          1   7197.50  0.063333  0.040333       31.0  65.408993
# 4          0   7159.99  0.233667  0.000000       18.0  57.462959
# ...      ...       ...       ...       ...        ...        ...
# 9112       0  10168.00  0.178109  0.082320     2790.0  40.532781
# 9113       0  10153.97  0.185682  0.075785     2765.0  38.801796
# 9114       1  10168.54  0.170748  0.071725     3092.0  41.591447
# 9115       0  10159.50  0.174339  0.061375     3405.0  40.362089
# 9116       1  10208.42  0.186011  0.074069     3264.0  49.125569
#
#          long_mavg    short_mavg
# 0      7097.183810   7156.526667
# 1      7104.425238   7173.410000
# 2      7111.765714   7188.968889
# 3      7119.059048   7197.981111
# 4      7123.820476   7196.502222
# ...            ...           ...
# 9112  10194.198095  10216.297778
# 9113  10194.863333  10208.506667
# 9114  10195.836190  10201.170000
# 9115  10197.285714  10192.781111
# 9116  10202.210476  10187.507778
#
# [9117 rows x 8 columns]

# %%
#chuẩn hóa
xscaler = MinMaxScaler(feature_range=(0, 1))
train = xscaler.fit_transform(train)
scaler_data = xscaler.transform(data_with_lagged)
# scaler_data = data_with_lagged
print(train.shape, scaler_data.shape)
# Out:
# (9117, 8) (10727, 8)

# %%
X_train = []
y_train = []

for i in range(n_lag, len(train)):
  X_train.append(train[i-n_lag:i, :])
  y_train.append(train[i, :])

X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

print(X_train.shape, y_train.shape)
# Out:
# (9110, 7, 8) (9110, 8)

# %%
# design network
neurons = 64
epochs = 32
dropout = 0.25
batch_size = 80
activ_func = "relu"

# %%
# early stopping callback
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =20)

# %%
# Số fold
k = 5
kf = KFold(n_splits=k, shuffle=False)

# List để lưu kết quả dự đoán từ LSTM và GRU
lstm_predictions = []
gru_predictions = []

# Xây dựng mô hình stacking
for train_index, test_index in kf.split(X_train):
    X_sub_train, X_sub_test = X_train[train_index], X_train[test_index]
    y_sub_train, y_sub_test = y_train[train_index], y_train[test_index]
    # Xây dựng mô hình LSTM và huấn luyện
    lstm_model = Sequential()
    lstm_model.add(LSTM(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    lstm_model.add(LSTM(neurons, return_sequences=False))
    lstm_model.add(Dense(8))
    lstm_model.compile(optimizer='adam', loss='mean_squared_error')

    # Xây dựng mô hình GRU và huấn luyện
    gru_model = Sequential()
    gru_model.add(GRU(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    gru_model.add(GRU(neurons, return_sequences=False))
    gru_model.add(Dense(8))
    gru_model.compile(optimizer='adam', loss='mean_squared_error')
    
    lstm_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    gru_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size,)

    # Lấy đầu ra của mô hình LSTM và GRU
    lstm_output = lstm_model.predict(X_sub_test)
    gru_output = gru_model.predict(X_sub_test)
    
    lstm_predictions.append(lstm_output)
    gru_predictions.append(gru_output)
# Out:
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.0526
# Epoch 2/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0347
# Epoch 3/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0342
# Epoch 4/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 5/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0340
# Epoch 6/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0337
# Epoch 7/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0338
# Epoch 8/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0337
# Epoch 9/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 10/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0335
# Epoch 11/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0336
# Epoch 12/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0334
# Epoch 13/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0334
# Epoch 14/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 15/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0334
# Epoch 16/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0334
# Epoch 17/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0332
# Epoch 18/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0332
# Epoch 19/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0333
# Epoch 20/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 21/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0333
# Epoch 22/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0332
# Epoch 23/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0333
# Epoch 24/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0333
# Epoch 25/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0332
# Epoch 26/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0332
# Epoch 27/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0332
# Epoch 28/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0331
# Epoch 29/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0332
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0332
# Epoch 31/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0332
# Epoch 32/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0331
# Epoch 1/32
# 92/92 [==============================] - 4s 8ms/step - loss: 0.0490
# Epoch 2/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0343
# Epoch 3/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 4/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0337
# Epoch 5/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0338
# Epoch 6/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0336
# Epoch 7/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0335
# Epoch 8/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 9/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 10/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0333
# Epoch 11/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 12/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0333
# Epoch 13/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0332
# Epoch 14/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0333
# Epoch 15/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 16/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0333
# Epoch 17/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0333
# Epoch 18/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 19/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0332
# Epoch 20/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0333
# Epoch 21/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0332
# Epoch 22/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0332
# Epoch 23/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0332
# Epoch 24/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0331
# Epoch 25/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0331
# Epoch 26/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0331
# Epoch 27/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0331
# Epoch 28/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0332
# Epoch 29/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0331
# Epoch 30/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0331
# Epoch 31/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0330
# Epoch 32/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0331
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 4ms/step
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.0584
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0353
# Epoch 3/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0348
# Epoch 4/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0346
# Epoch 5/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0342
# Epoch 6/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0341
# Epoch 7/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 8/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 9/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 10/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 11/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 12/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 13/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0337
# Epoch 14/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 15/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0337
# Epoch 16/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0336
# Epoch 17/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0337
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0336
# Epoch 19/32
# 92/92 [==============================] - 1s 13ms/step - loss: 0.0336
# Epoch 20/32
# 92/92 [==============================] - 1s 14ms/step - loss: 0.0336
# Epoch 21/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0336
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0337
# Epoch 23/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 24/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0335
# Epoch 25/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0336
# Epoch 26/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 27/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 28/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 31/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 1/32
# 92/92 [==============================] - 4s 8ms/step - loss: 0.0498
# Epoch 2/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0345
# Epoch 3/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0342
# Epoch 4/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 5/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 6/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0337
# Epoch 7/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0337
# Epoch 8/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0336
# Epoch 9/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0339
# Epoch 10/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0336
# Epoch 11/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0337
# Epoch 12/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0336
# Epoch 13/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0336
# Epoch 14/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0337
# Epoch 15/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 16/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 17/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 18/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 19/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 20/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0334
# Epoch 21/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 22/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 23/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0334
# Epoch 24/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0334
# Epoch 25/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 26/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 27/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0336
# Epoch 28/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0334
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0334
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0334
# Epoch 31/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 32/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.0524
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0353
# Epoch 3/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0347
# Epoch 4/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0344
# Epoch 5/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 6/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 7/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 8/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# Epoch 9/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# Epoch 10/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0337
# Epoch 11/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0337
# Epoch 12/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0336
# Epoch 13/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0336
# Epoch 14/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0336
# Epoch 15/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0336
# Epoch 16/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0336
# Epoch 17/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0334
# Epoch 19/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0334
# Epoch 20/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0334
# Epoch 21/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0334
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 23/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0333
# Epoch 24/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0334
# Epoch 25/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0334
# Epoch 26/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0333
# Epoch 27/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0334
# Epoch 28/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0333
# Epoch 29/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0333
# Epoch 30/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0333
# Epoch 31/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0333
# Epoch 32/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0333
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.0471
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0344
# Epoch 3/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 4/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# Epoch 5/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0336
# Epoch 6/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0337
# Epoch 7/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0337
# Epoch 8/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 9/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 10/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0337
# Epoch 11/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 12/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0334
# Epoch 13/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0335
# Epoch 14/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 15/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0334
# Epoch 16/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 17/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0334
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0335
# Epoch 19/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0334
# Epoch 20/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 21/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0332
# Epoch 23/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 24/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0333
# Epoch 26/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 27/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0333
# Epoch 28/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0332
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0332
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0331
# Epoch 31/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0332
# Epoch 32/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0331
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.0554
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0353
# Epoch 3/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0348
# Epoch 4/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0348
# Epoch 5/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0346
# Epoch 6/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0344
# Epoch 7/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0344
# Epoch 8/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0343
# Epoch 9/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0343
# Epoch 10/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0342
# Epoch 11/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 12/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 13/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0341
# Epoch 14/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 15/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0340
# Epoch 16/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0339
# Epoch 17/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 19/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 20/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0339
# Epoch 21/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# Epoch 22/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0339
# Epoch 23/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# Epoch 24/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0338
# Epoch 26/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0339
# Epoch 27/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# Epoch 28/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0339
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0338
# Epoch 30/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0338
# Epoch 31/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0338
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0338
# Epoch 1/32
# 92/92 [==============================] - 4s 8ms/step - loss: 0.0493
# Epoch 2/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0348
# Epoch 3/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0345
# Epoch 4/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0342
# Epoch 5/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0343
# Epoch 6/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0344
# Epoch 7/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0342
# Epoch 8/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 9/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 10/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0341
# Epoch 11/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0342
# Epoch 12/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 13/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 14/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.0341
# Epoch 15/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0340
# Epoch 16/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0341
# Epoch 17/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0339
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# Epoch 19/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 20/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 21/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0338
# Epoch 22/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0339
# Epoch 23/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 24/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0338
# Epoch 26/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 27/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0339
# Epoch 28/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0338
# Epoch 29/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0337
# Epoch 31/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0338
# Epoch 32/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0337
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.0513
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0358
# Epoch 3/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0354
# Epoch 4/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0351
# Epoch 5/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0349
# Epoch 6/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0347
# Epoch 7/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0347
# Epoch 8/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0346
# Epoch 9/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0346
# Epoch 10/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0346
# Epoch 11/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0345
# Epoch 12/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0345
# Epoch 13/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0344
# Epoch 14/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0343
# Epoch 15/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0344
# Epoch 16/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0343
# Epoch 17/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0343
# Epoch 18/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0342
# Epoch 19/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0342
# Epoch 20/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0342
# Epoch 21/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0343
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 23/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0342
# Epoch 24/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0341
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 26/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0342
# Epoch 27/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0341
# Epoch 28/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 30/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.0340
# Epoch 31/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 1/32
# 92/92 [==============================] - 4s 8ms/step - loss: 0.0463
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0351
# Epoch 3/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0348
# Epoch 4/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0344
# Epoch 5/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0343
# Epoch 6/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0343
# Epoch 7/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0344
# Epoch 8/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0341
# Epoch 9/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0343
# Epoch 10/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0343
# Epoch 11/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 12/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0341
# Epoch 13/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0341
# Epoch 14/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 15/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0342
# Epoch 16/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0341
# Epoch 17/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 18/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 19/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0341
# Epoch 20/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0340
# Epoch 21/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 22/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0339
# Epoch 23/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0341
# Epoch 24/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 25/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0339
# Epoch 26/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# Epoch 27/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 28/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0339
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0340
# Epoch 31/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.0338
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.0339
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step

# %%
type(lstm_predictions)
# Out:
# list

# %%
# Lấy đầu ra của LSTM và GRU
lstm_outputs = np.concatenate(lstm_predictions, axis=0)
gru_outputs = np.concatenate(gru_predictions, axis=0)

# %%
from numpy import column_stack

lstm_outputs = xscaler.inverse_transform(lstm_outputs)
gru_outputs = xscaler.inverse_transform(gru_outputs)

y_train = xscaler.inverse_transform(y_train)

stacking_inputs = column_stack((lstm_outputs, gru_outputs))

# %%
print(stacking_inputs[:, 1], y_train[:, 1])
# Out:
# [ 7185.8403  7245.3066  7327.162  ... 10303.725  10284.713  10286.733 ] [ 7183.12  7208.98  7230.99 ... 10168.54 10159.5  10208.42]

# %%
stacking_model = Sequential()
stacking_model.add(Dense(16, input_shape=(stacking_inputs.shape[1],)))
stacking_model.add(Dense(8, activation='linear'))
stacking_model.compile(optimizer='adam', loss='mean_squared_error')

# Train stacking model
stacking_model.fit(stacking_inputs, y_train, epochs=50, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/50
# 114/114 [==============================] - 1s 1ms/step - loss: 20734454.0000
# Epoch 2/50
# 114/114 [==============================] - 0s 1ms/step - loss: 965390.1250
# Epoch 3/50
# 114/114 [==============================] - 0s 1ms/step - loss: 739406.1250
# Epoch 4/50
# 114/114 [==============================] - 0s 1ms/step - loss: 697455.6875
# Epoch 5/50
# 114/114 [==============================] - 0s 1ms/step - loss: 675693.8125
# Epoch 6/50
# 114/114 [==============================] - 0s 1ms/step - loss: 658634.1250
# Epoch 7/50
# 114/114 [==============================] - 0s 1ms/step - loss: 650919.0000
# Epoch 8/50
# 114/114 [==============================] - 0s 1ms/step - loss: 647257.6875
# Epoch 9/50
# 114/114 [==============================] - 0s 1ms/step - loss: 640670.1250
# Epoch 10/50
# 114/114 [==============================] - 0s 1ms/step - loss: 635394.4375
# Epoch 11/50
# 114/114 [==============================] - 0s 1ms/step - loss: 632908.5000
# Epoch 12/50
# 114/114 [==============================] - 0s 1ms/step - loss: 632414.3750
# Epoch 13/50
# 114/114 [==============================] - 0s 1ms/step - loss: 631040.8750
# Epoch 14/50
# 114/114 [==============================] - 0s 1ms/step - loss: 627306.2500
# Epoch 15/50
# 114/114 [==============================] - 0s 1ms/step - loss: 630838.8125
# Epoch 16/50
# 114/114 [==============================] - 0s 1ms/step - loss: 628796.0000
# Epoch 17/50
# 114/114 [==============================] - 0s 1ms/step - loss: 627024.7500
# Epoch 18/50
# 114/114 [==============================] - 0s 1ms/step - loss: 625043.2500
# Epoch 19/50
# 114/114 [==============================] - 0s 1ms/step - loss: 625973.3750
# Epoch 20/50
# 114/114 [==============================] - 0s 1ms/step - loss: 623132.7500
# Epoch 21/50
# 114/114 [==============================] - 0s 2ms/step - loss: 621879.9375
# Epoch 22/50
# 114/114 [==============================] - 0s 1ms/step - loss: 625034.7500
# Epoch 23/50
# 114/114 [==============================] - 0s 1ms/step - loss: 622475.8750
# Epoch 24/50
# 114/114 [==============================] - 0s 1ms/step - loss: 622909.3750
# Epoch 25/50
# 114/114 [==============================] - 0s 1ms/step - loss: 620801.4375
# Epoch 26/50
# 114/114 [==============================] - 0s 1ms/step - loss: 621102.2500
# Epoch 27/50
# 114/114 [==============================] - 0s 1ms/step - loss: 620347.8750
# Epoch 28/50
# 114/114 [==============================] - 0s 1ms/step - loss: 619256.1250
# Epoch 29/50
# 114/114 [==============================] - 0s 1ms/step - loss: 621189.5625
# Epoch 30/50
# 114/114 [==============================] - 0s 1ms/step - loss: 621374.0625
# Epoch 31/50
# 114/114 [==============================] - 0s 1ms/step - loss: 620371.9375
# Epoch 32/50
# 114/114 [==============================] - 0s 1ms/step - loss: 621571.4375
# Epoch 33/50
# 114/114 [==============================] - 0s 1ms/step - loss: 617883.1250
# Epoch 34/50
# 114/114 [==============================] - 0s 2ms/step - loss: 617526.6250
# Epoch 35/50
# 114/114 [==============================] - 0s 2ms/step - loss: 619059.7500
# Epoch 36/50
# 114/114 [==============================] - 0s 1ms/step - loss: 621650.2500
# Epoch 37/50
# 114/114 [==============================] - 0s 2ms/step - loss: 619831.0625
# Epoch 38/50
# 114/114 [==============================] - 0s 2ms/step - loss: 621348.0000
# Epoch 39/50
# 114/114 [==============================] - 0s 2ms/step - loss: 617829.2500
# Epoch 40/50
# 114/114 [==============================] - 0s 1ms/step - loss: 619418.1875
# Epoch 41/50
# 114/114 [==============================] - 0s 1ms/step - loss: 622136.6250
# Epoch 42/50
# 114/114 [==============================] - 0s 1ms/step - loss: 615437.5000
# Epoch 43/50
# 114/114 [==============================] - 0s 1ms/step - loss: 616023.6875
# Epoch 44/50
# 114/114 [==============================] - 0s 1ms/step - loss: 617039.5000
# Epoch 45/50
# 114/114 [==============================] - 0s 1ms/step - loss: 617572.3125
# Epoch 46/50
# 114/114 [==============================] - 0s 1ms/step - loss: 614878.6875
# Epoch 47/50
# 114/114 [==============================] - 0s 1ms/step - loss: 617708.0000
# Epoch 48/50
# 114/114 [==============================] - 0s 1ms/step - loss: 617343.4375
# Epoch 49/50
# 114/114 [==============================] - 0s 1ms/step - loss: 614690.5000
# Epoch 50/50
# 114/114 [==============================] - 0s 1ms/step - loss: 617171.6875

# %%
#tạo testing data set
test_data = scaler_data[train_size - n_lag: , :]
x_test = []
y_test = data_with_lagged[train_size:]

for i in range(n_lag, len(test_data)):
  x_test.append(test_data[i-n_lag:i, :])

x_test = np.asarray(x_test)
print(x_test.shape, y_test.shape)
# Out:
# (1610, 7, 8) (1610, 8)

# %%
#get the models predicted price value
lstm_test_predictions = lstm_model.predict(x_test)
gru_test_predictions = gru_model.predict(x_test)

lstm_test_predictions = xscaler.inverse_transform(lstm_test_predictions)
gru_test_predictions = xscaler.inverse_transform(gru_test_predictions)

stacking_close_predictions = stacking_model.predict(column_stack((lstm_test_predictions, gru_test_predictions)))

# stacking_close_predictions = xscaler.inverse_transform(stacking_close_predictions)

stacking_close_predictions.shape
# Out:
#  1/51 [..............................] - ETA: 1s
# 51/51 [==============================] - 0s 5ms/step
# 51/51 [==============================] - 0s 3ms/step
# 51/51 [==============================] - 0s 1ms/step
# (1610, 8)

# %%
#sai số
mse = (((y_test - stacking_close_predictions)**2).mean())
mae = np.abs((y_test - stacking_close_predictions).mean())
mape = np.mean(np.abs((y_test - stacking_close_predictions) / y_test)) * 100
smape = (100 / len(y_test)) * np.sum(2 * np.abs(stacking_close_predictions - y_test) / (np.abs(stacking_close_predictions) + np.abs(y_test)))
print(mse["Close"], mae["Close"], mape["Close"], smape["Close"])
# Out:
# 15059.492712056952 57.326386548913035 0.9768690975411021 0.9740597884037868
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#
valid = data_with_lagged[train_size:]
valid['Predictions'] = stacking_close_predictions[:, 1]
valid['LSTM'] = lstm_test_predictions[:, 1]
valid['GRU'] = gru_test_predictions[:, 1]

#hiển thị dữ liệu gần đây
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Giá (USD)', fontsize=18)
plt.plot(valid[['Close','Predictions','LSTM', 'GRU']])
plt.legend(['Val', 'Predictions', 'LSTM', 'GRU'], loc='lower right')
plt.show()
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_11652\653746799.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = stacking_close_predictions[:, 1]
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_11652\653746799.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['LSTM'] = lstm_test_predictions[:, 1]
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_11652\653746799.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['GRU'] = gru_test_predictions[:, 1]

# %%
#create file if it does not exist
data = {
    'Model': 'SE',
    'Thông tin': ['MAE', 'MSE', 'MAPE', 'sMAPE'],
    'Price + Twitter': [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]
}
result_table = pd.read_csv("result-hours.csv")
result_table['Price + Twitter'] = [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]
result_table.to_csv("result-hours.csv", index=False)
result_table
# Out:
#   Model Thông tin         Price  Price + Twitter
# 0    SE       MAE     46.741163        57.326387
# 1    SE       MSE  14537.286524     15059.492712
# 2    SE      MAPE      0.983028         0.976869
# 3    SE     sMAPE      0.988685         0.974060
