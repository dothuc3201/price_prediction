# %%
#imports các thư viện
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle
from sklearn.model_selection import KFold

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat


import keras.utils
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Input, concatenate, Dense
from keras.layers import LSTM, GRU
from sklearn.linear_model import LinearRegression
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
def rsi(data, period: int = 14):

    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity (độ trễ) - days or hours
lag_granularity = "hours"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "hour"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/" + \
    analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_" + \
    str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename, index_col='DateTime', parse_dates=True)

# %%
#group by datetime
df = df.groupby('DateTime').agg(lambda x: x.mean())
df
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\3489936249.py:2: FutureWarning: ['dt'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df = df.groupby('DateTime').agg(lambda x: x.mean())
#                              Close  Volume_(BTC)  Weighted_Price   neg_pol  \
# DateTime
# 2018-08-31 10:00:00+00:00  6949.40      2.333380     6948.996140  0.040167
# 2018-08-31 11:00:00+00:00  6946.06      2.430317     6948.538492  0.020167
# 2018-08-31 12:00:00+00:00  6963.30      3.922626     6964.052374  0.035800
# 2018-08-31 13:00:00+00:00  6900.00      9.040247     6932.162091  0.084000
# 2018-08-31 14:00:00+00:00  6927.92      5.947736     6912.448529  0.025333
# ...                            ...           ...             ...       ...
# 2019-11-23 11:00:00+00:00  7180.02      6.622678     7190.277423  0.067410
# 2019-11-23 12:00:00+00:00  7157.47      7.074875     7181.956969  0.072038
# 2019-11-23 13:00:00+00:00  7181.50      9.766378     7171.704462  0.072152
# 2019-11-23 14:00:00+00:00  7260.77      6.143298     7231.168406  0.064122
# 2019-11-23 15:00:00+00:00  7292.72      2.660796     7272.018586  0.063931
#
#                             neu_pol   pos_pol  compound  Tweet_vol
# DateTime
# 2018-08-31 10:00:00+00:00  0.876000  0.083833  0.155633       18.0
# 2018-08-31 11:00:00+00:00  0.865000  0.114833  0.246883       37.0
# 2018-08-31 12:00:00+00:00  0.839600  0.124600  0.254660       42.0
# 2018-08-31 13:00:00+00:00  0.789250  0.126917  0.218183       55.0
# 2018-08-31 14:00:00+00:00  0.861444  0.113222  0.263544       38.0
# ...                             ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00  0.760387  0.172199  0.250681     2304.0
# 2019-11-23 12:00:00+00:00  0.751780  0.176183  0.235377     2467.0
# 2019-11-23 13:00:00+00:00  0.756339  0.171514  0.245202     2612.0
# 2019-11-23 14:00:00+00:00  0.755714  0.180162  0.269456     2676.0
# 2019-11-23 15:00:00+00:00  0.754940  0.181127  0.254060     2271.0
#
# [10781 rows x 8 columns]

# %%
#tính toán các chỉ số indicator: rsi, ma
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = True
add_longMAvg = False
add_shortMAvg = False

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()

if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity', 'Tweet_vol', 'Volume_(BTC)'] if analyser == "Textblob" else [
    'Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")

if(add_longMAvg):
    features.append("long_mavg")

if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
data_with_lagged = df_copy.dropna()[-1000:]
data_with_lagged
# Out:
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2019-10-13 00:00:00+00:00       0  8303.43  0.183570  0.067381     1822.0
# 2019-10-13 01:00:00+00:00       1  8333.33  0.185161  0.060215     1618.0
# 2019-10-13 02:00:00+00:00       1  8349.07  0.195797  0.051072     1670.0
# 2019-10-13 03:00:00+00:00       0  8340.98  0.198426  0.058467     1778.0
# 2019-10-13 04:00:00+00:00       1  8346.46  0.202182  0.044574     1603.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI
# DateTime
# 2019-10-13 00:00:00+00:00  41.512649
# 2019-10-13 01:00:00+00:00  47.952750
# 2019-10-13 02:00:00+00:00  51.010831
# 2019-10-13 03:00:00+00:00  49.404102
# 2019-10-13 04:00:00+00:00  50.540542
# ...                              ...
# 2019-11-23 11:00:00+00:00  39.929000
# 2019-11-23 12:00:00+00:00  38.084247
# 2019-11-23 13:00:00+00:00  41.201744
# 2019-11-23 14:00:00+00:00  50.123331
# 2019-11-23 15:00:00+00:00  53.205251
#
# [1000 rows x 6 columns]

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)

data_hours = data_with_lagged.iloc[:, 1].reset_index().drop(['DateTime'], axis=1)

train = data_with_lagged.iloc[:train_size, 1]
train = train.reset_index()
train = train.drop(['DateTime'], axis=1)

train
# Out:
#        Close
# 0    8303.43
# 1    8333.33
# 2    8349.07
# 3    8340.98
# 4    8346.46
# ..       ...
# 845  8480.98
# 846  8478.31
# 847  8419.58
# 848  8558.37
# 849  8539.81
#
# [850 rows x 1 columns]

# %%
#chuẩn hóa
xscaler = MinMaxScaler(feature_range=(0, 1))
train = xscaler.fit_transform(train)
scaler_data = xscaler.transform(data_hours)
# scaler_data = data_with_lagged
print(train.shape, scaler_data.shape)
# Out:
# (850, 1) (1000, 1)

# %%
X_train = []
y_train = []

for i in range(n_lag, len(train)):
  X_train.append(train[i-n_lag:i, :])
  y_train.append(train[i, :])

X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

print(X_train.shape, y_train.shape)
# Out:
# (843, 7, 1) (843, 1)

# %%
# design network
neurons = 64
epochs = 50
dropout = 0.25
batch_size = 80
activ_func = "relu"

# %%
# early stopping callback
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =20)

# %%
# Số fold
k = 5
kf = KFold(n_splits=k, shuffle=False)

# List để lưu kết quả dự đoán từ LSTM và GRU
lstm_predictions = []
gru_predictions = []

lstm_models = []
gru_models = []

# Xây dựng mô hình stacking
for train_index, test_index in kf.split(X_train):
    X_sub_train, X_sub_test = X_train[train_index], X_train[test_index]
    y_sub_train, y_sub_test = y_train[train_index], y_train[test_index]
    # Xây dựng mô hình LSTM và huấn luyện
    lstm_model = Sequential()
    lstm_model.add(LSTM(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    lstm_model.add(LSTM(neurons, return_sequences=False))
    lstm_model.add(Dense(1))
    lstm_model.compile(optimizer='adam', loss='mean_squared_error')

    # Xây dựng mô hình GRU và huấn luyện
    gru_model = Sequential()
    gru_model.add(GRU(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    gru_model.add(GRU(neurons, return_sequences=False))
    gru_model.add(Dense(1))
    gru_model.compile(optimizer='adam', loss='mean_squared_error')
    
    lstm_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    gru_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    # Lấy đầu ra của mô hình LSTM và GRU
    lstm_output = lstm_model.predict(X_sub_test)
    gru_output = gru_model.predict(X_sub_test)
    
    lstm_predictions.append(lstm_output)
    gru_predictions.append(gru_output)
    
    lstm_models.append(lstm_model)
    gru_models.append(gru_model)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 4s 10ms/step - loss: 0.2150
# Epoch 2/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0316
# Epoch 3/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0202
# Epoch 4/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0131
# Epoch 5/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0065
# Epoch 6/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0039
# Epoch 7/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027
# Epoch 8/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0024
# Epoch 9/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 10/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0024
# Epoch 11/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 12/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 13/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 14/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0023
# Epoch 15/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 16/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 17/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0021
# Epoch 18/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 19/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0021
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 21/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 22/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 23/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 24/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 25/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 26/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 27/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 28/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 29/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 30/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 31/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 33/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 34/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0018
# Epoch 35/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 36/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 38/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 39/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 40/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 41/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 42/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 43/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 44/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 45/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 46/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 47/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 48/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 49/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 50/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 1/50
# 9/9 [==============================] - 3s 9ms/step - loss: 0.2250
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0296
# Epoch 3/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0223
# Epoch 4/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 5/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0072
# Epoch 6/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0026
# Epoch 7/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 8/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 9/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 10/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 11/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 12/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 13/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 14/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 15/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 16/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 17/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 18/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 19/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 21/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 22/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 23/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 24/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0015
# Epoch 25/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0014
# Epoch 26/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 27/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 28/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 29/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 30/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 31/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 32/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0013
# Epoch 33/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 34/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 35/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 36/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 37/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 38/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 39/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 40/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 41/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 42/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 43/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 44/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 45/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 46/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 47/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 48/50
# 9/9 [==============================] - 0s 11ms/step - loss: 9.9222e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.6721e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 9ms/step - loss: 9.6121e-04
# 6/6 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 1s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 3s 11ms/step - loss: 0.1458
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0184
# Epoch 3/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0083
# Epoch 4/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 5/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0044
# Epoch 6/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 7/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 8/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0021
# Epoch 9/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 10/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 11/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 12/50
# 9/9 [==============================] - 0s 9ms/step - loss: 8.9240e-04
# Epoch 13/50
# 9/9 [==============================] - 0s 9ms/step - loss: 8.1051e-04
# Epoch 14/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.7831e-04
# Epoch 15/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.5545e-04
# Epoch 16/50
# 9/9 [==============================] - 0s 16ms/step - loss: 7.5673e-04
# Epoch 17/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.4897e-04
# Epoch 18/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.6464e-04
# Epoch 19/50
# 9/9 [==============================] - 0s 12ms/step - loss: 7.8783e-04
# Epoch 20/50
# 9/9 [==============================] - 0s 12ms/step - loss: 7.4535e-04
# Epoch 21/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.4339e-04
# Epoch 22/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.5639e-04
# Epoch 23/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.8654e-04
# Epoch 24/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.7021e-04
# Epoch 25/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.4165e-04
# Epoch 26/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.4112e-04
# Epoch 27/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.4355e-04
# Epoch 28/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.4463e-04
# Epoch 29/50
# 9/9 [==============================] - 0s 9ms/step - loss: 8.0773e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.4421e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 15ms/step - loss: 7.6613e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.5990e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.4061e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.5002e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.2618e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.3337e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.6360e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.3210e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 11ms/step - loss: 7.3167e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.3738e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.3729e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.3563e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 11ms/step - loss: 7.2751e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 16ms/step - loss: 7.2802e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 10ms/step - loss: 7.5072e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.2338e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.2873e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.2899e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.1774e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 9ms/step - loss: 7.1754e-04
# Epoch 1/50
# 9/9 [==============================] - 4s 9ms/step - loss: 0.1696
# Epoch 2/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0221
# Epoch 3/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0103
# Epoch 4/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0099
# Epoch 5/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0051
# Epoch 6/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0046
# Epoch 7/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034
# Epoch 8/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0025
# Epoch 9/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 10/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 11/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.7743e-04
# Epoch 12/50
# 9/9 [==============================] - 0s 8ms/step - loss: 7.3843e-04
# Epoch 13/50
# 9/9 [==============================] - 0s 9ms/step - loss: 5.9283e-04
# Epoch 14/50
# 9/9 [==============================] - 0s 8ms/step - loss: 5.1592e-04
# Epoch 15/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.8297e-04
# Epoch 16/50
# 9/9 [==============================] - 0s 8ms/step - loss: 4.8074e-04
# Epoch 17/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.7598e-04
# Epoch 18/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.8124e-04
# Epoch 19/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.7737e-04
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.7438e-04
# Epoch 21/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.6914e-04
# Epoch 22/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.7085e-04
# Epoch 23/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.7981e-04
# Epoch 24/50
# 9/9 [==============================] - 0s 17ms/step - loss: 4.7117e-04
# Epoch 25/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.6612e-04
# Epoch 26/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.7168e-04
# Epoch 27/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6569e-04
# Epoch 28/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6920e-04
# Epoch 29/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6476e-04
# Epoch 30/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6624e-04
# Epoch 31/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.8372e-04
# Epoch 32/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.9293e-04
# Epoch 33/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.9367e-04
# Epoch 34/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.8360e-04
# Epoch 35/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6547e-04
# Epoch 36/50
# 9/9 [==============================] - 0s 8ms/step - loss: 4.7265e-04
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6628e-04
# Epoch 38/50
# 9/9 [==============================] - 0s 8ms/step - loss: 4.5475e-04
# Epoch 39/50
# 9/9 [==============================] - 0s 14ms/step - loss: 4.5597e-04
# Epoch 40/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.5791e-04
# Epoch 41/50
# 9/9 [==============================] - 0s 8ms/step - loss: 4.5245e-04
# Epoch 42/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6488e-04
# Epoch 43/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.7056e-04
# Epoch 44/50
# 9/9 [==============================] - 0s 11ms/step - loss: 4.8730e-04
# Epoch 45/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.5398e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.5593e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.6665e-04
# Epoch 48/50
# 9/9 [==============================] - 0s 10ms/step - loss: 4.6435e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6125e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 9ms/step - loss: 4.7762e-04
# 6/6 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 3s 14ms/step - loss: 0.1443
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0231
# Epoch 3/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0161
# Epoch 4/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0104
# Epoch 5/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0059
# Epoch 6/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 7/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027
# Epoch 8/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 9/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 10/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 11/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 12/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 13/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0021
# Epoch 14/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 15/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 16/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0021
# Epoch 17/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0022
# Epoch 18/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0021
# Epoch 19/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 21/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 22/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 23/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 24/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 25/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 26/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 27/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 28/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 29/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 30/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 31/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 33/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 34/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 35/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 36/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 37/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 38/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 39/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 40/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0018
# Epoch 41/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 42/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 43/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 44/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 45/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 46/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 47/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 48/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 49/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 50/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 1/50
# 9/9 [==============================] - 3s 9ms/step - loss: 0.1121
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0207
# Epoch 3/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0109
# Epoch 4/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0087
# Epoch 5/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040
# Epoch 6/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 7/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 8/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 9/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 10/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0015
# Epoch 11/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 12/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 13/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 14/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 15/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 16/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 17/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 18/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 19/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 21/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 22/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 23/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 24/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 25/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 26/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 27/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 28/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 29/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 30/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 31/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 32/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 33/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 34/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 35/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 36/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 38/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 39/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 40/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 41/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 42/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 43/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 44/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 45/50
# 9/9 [==============================] - 0s 9ms/step - loss: 9.6952e-04
# Epoch 46/50
# 9/9 [==============================] - 0s 9ms/step - loss: 9.5110e-04
# Epoch 47/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 48/50
# 9/9 [==============================] - 0s 13ms/step - loss: 9.2556e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 9ms/step - loss: 9.1152e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 8ms/step - loss: 9.2718e-04
# 6/6 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 0s 2ms/step
# Epoch 1/50
# 9/9 [==============================] - 3s 10ms/step - loss: 0.1679
# Epoch 2/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0357
# Epoch 3/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0251
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0153
# Epoch 5/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0081
# Epoch 6/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037
# Epoch 7/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0027
# Epoch 8/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0026
# Epoch 9/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0024
# Epoch 10/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0024
# Epoch 11/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0024
# Epoch 12/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0024
# Epoch 13/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 14/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 15/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 16/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 17/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 18/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 19/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 21/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 22/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 23/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 24/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 25/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0023
# Epoch 26/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0022
# Epoch 27/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0021
# Epoch 28/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 29/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 30/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 31/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 33/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 34/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 35/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 36/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 38/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 39/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 40/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 41/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 42/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0018
# Epoch 43/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 44/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 45/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 46/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 47/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 48/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 49/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 50/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 1/50
# 9/9 [==============================] - 4s 9ms/step - loss: 0.1293
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208
# Epoch 3/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0144
# Epoch 4/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0122
# Epoch 5/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0062
# Epoch 6/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 7/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 8/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 9/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 10/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 11/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 12/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 13/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 14/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 15/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0016
# Epoch 16/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 17/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 18/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 19/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 21/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 22/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 23/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 24/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 25/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0014
# Epoch 26/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 27/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 28/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 29/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 30/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 31/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 32/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 33/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 34/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 35/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 36/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 37/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 38/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 39/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 40/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 41/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 42/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 43/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 44/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 45/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 46/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0010
# Epoch 47/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 48/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0010
# Epoch 49/50
# 9/9 [==============================] - 0s 17ms/step - loss: 9.8894e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 15ms/step - loss: 9.9892e-04
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 1s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 4s 9ms/step - loss: 0.2183
# Epoch 2/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0535
# Epoch 3/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0309
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0156
# Epoch 5/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0110
# Epoch 6/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0047
# Epoch 7/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0026
# Epoch 8/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 9/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 10/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0022
# Epoch 11/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 12/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 13/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 14/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 15/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 16/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 17/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 18/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 19/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 20/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 21/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0021
# Epoch 22/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 23/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 24/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 25/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0020
# Epoch 26/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 27/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 28/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 29/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 30/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 31/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0018
# Epoch 32/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 33/50
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0017
# Epoch 34/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0017
# Epoch 35/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0017
# Epoch 36/50
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0017
# Epoch 37/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0016
# Epoch 38/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0016
# Epoch 39/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0017
# Epoch 40/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 41/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 42/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0015
# Epoch 43/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0015
# Epoch 44/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 45/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 46/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 47/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 48/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 49/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 50/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 1/50
# 9/9 [==============================] - 5s 12ms/step - loss: 0.1295
# Epoch 2/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0241
# Epoch 3/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0111
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0097
# Epoch 5/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0043
# Epoch 6/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 7/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 8/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 9/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 10/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 11/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 12/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 13/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0014
# Epoch 14/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 15/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 16/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 17/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 18/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 19/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 20/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 21/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 22/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 23/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 24/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 25/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 26/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 27/50
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0012
# Epoch 28/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 29/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 30/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 31/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0012
# Epoch 32/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 33/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 34/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 35/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 36/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 37/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 38/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 39/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 40/50
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0011
# Epoch 41/50
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 42/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 43/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 44/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0010
# Epoch 45/50
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0010
# Epoch 46/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0010
# Epoch 47/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 48/50
# 9/9 [==============================] - 0s 12ms/step - loss: 9.9922e-04
# Epoch 49/50
# 9/9 [==============================] - 0s 20ms/step - loss: 9.9112e-04
# Epoch 50/50
# 9/9 [==============================] - 0s 14ms/step - loss: 9.8228e-04
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 1s 18ms/step

# %%
type(lstm_predictions)
# Out:
# list

# %%
# Lấy đầu ra của LSTM và GRU
lstm_outputs = np.concatenate(lstm_predictions, axis=0)
gru_outputs = np.concatenate(gru_predictions, axis=0)
lstm_outputs
# Out:
# array([[0.35594958],
#        [0.35316432],
#        [0.3511318 ],
#        [0.35173982],
#        [0.35381573],
#        [0.3565877 ],
#        [0.35981578],
#        [0.3653366 ],
#        [0.37340277],
#        [0.381507  ],
#        [0.38575488],
#        [0.38734004],
#        [0.38780078],
#        [0.38777983],
#        [0.3890831 ],
#        [0.37630057],
#        [0.35707408],
#        [0.3389331 ],
#        [0.324534  ],
#        [0.3232483 ],
#        [0.3294204 ],
#        [0.3355853 ],
#        [0.3360324 ],
#        [0.33611903],
#        [0.3379134 ],
#        [0.34079543],
#        [0.34370524],
#        [0.34682342],
#        [0.347566  ],
#        [0.34716052],
#        [0.3447467 ],
#        [0.3393154 ],
#        [0.33528998],
#        [0.33042988],
#        [0.32692456],
#        [0.33293003],
#        [0.3404904 ],
#        [0.35003257],
#        [0.3563617 ],
#        [0.3572807 ],
#        [0.3540965 ],
#        [0.35135388],
#        [0.3532135 ],
#        [0.35639763],
#        [0.35955462],
#        [0.3585062 ],
#        [0.35439086],
#        [0.35049385],
#        [0.34910917],
#        [0.34826285],
#        [0.34586546],
#        [0.34176075],
#        [0.3362354 ],
#        [0.3345279 ],
#        [0.335646  ],
#        [0.33948308],
#        [0.3427897 ],
#        [0.33984038],
#        [0.33929297],
#        [0.3291727 ],
#        [0.31487325],
#        [0.30306715],
#        [0.292015  ],
#        [0.28601235],
#        [0.28548852],
#        [0.28442132],
#        [0.2820092 ],
#        [0.2830371 ],
#        [0.2861477 ],
#        [0.28831813],
#        [0.28931558],
#        [0.28888342],
#        [0.28827453],
#        [0.28796333],
#        [0.28607595],
#        [0.28352052],
#        [0.28147185],
#        [0.28089714],
#        [0.27473006],
#        [0.26076508],
#        [0.2441965 ],
#        [0.22665559],
#        [0.21503223],
#        [0.21325497],
#        [0.21448961],
#        [0.21534029],
#        [0.21639799],
#        [0.21921982],
#        [0.22031428],
#        [0.22267574],
#        [0.22634709],
#        [0.22658342],
#        [0.2241692 ],
#        [0.22192593],
#        [0.21937762],
#        [0.21627755],
#        [0.2172841 ],
#        [0.21727704],
#        [0.21751946],
#        [0.22497347],
#        [0.23421033],
#        [0.2440028 ],
#        [0.2526042 ],
#        [0.25510693],
#        [0.2539204 ],
#        [0.25101113],
#        [0.2507842 ],
#        [0.25348914],
#        [0.25703245],
#        [0.25914204],
#        [0.25848788],
#        [0.25514188],
#        [0.25157654],
#        [0.24927513],
#        [0.25018767],
#        [0.253502  ],
#        [0.2588487 ],
#        [0.26273906],
#        [0.26356983],
#        [0.26218855],
#        [0.24631125],
#        [0.2273468 ],
#        [0.21005438],
#        [0.19380239],
#        [0.18900715],
#        [0.19137265],
#        [0.19515471],
#        [0.19883218],
#        [0.20352472],
#        [0.2046027 ],
#        [0.2036506 ],
#        [0.20264184],
#        [0.20260133],
#        [0.20456086],
#        [0.20803116],
#        [0.21034375],
#        [0.21137594],
#        [0.21351525],
#        [0.21468477],
#        [0.21384946],
#        [0.21085273],
#        [0.20641916],
#        [0.20432283],
#        [0.20595542],
#        [0.20868932],
#        [0.2107235 ],
#        [0.21023168],
#        [0.21028017],
#        [0.21138717],
#        [0.21231376],
#        [0.21319576],
#        [0.22024561],
#        [0.22769387],
#        [0.23526137],
#        [0.23972403],
#        [0.2355478 ],
#        [0.2296259 ],
#        [0.2255993 ],
#        [0.22449881],
#        [0.22190227],
#        [0.21845587],
#        [0.21386193],
#        [0.21160753],
#        [0.20956567],
#        [0.20557754],
#        [0.20125175],
#        [0.19695295],
#        [0.19608428],
#        [0.1977964 ],
#        [0.20361279],
#        [0.20365617],
#        [0.20492153],
#        [0.20667373],
#        [0.20811939],
#        [0.20903274],
#        [0.2107614 ],
#        [0.21191448],
#        [0.21552837],
#        [0.21910262],
#        [0.22343834],
#        [0.23197372],
#        [0.24179545],
#        [0.25407022],
#        [0.26779756],
#        [0.2794167 ],
#        [0.29051012],
#        [0.29912776],
#        [0.30331576],
#        [0.3079206 ],
#        [0.3076542 ],
#        [0.30851257],
#        [0.3099731 ],
#        [0.31173187],
#        [0.31195134],
#        [0.3131631 ],
#        [0.31292924],
#        [0.31136286],
#        [0.31179988],
#        [0.31251663],
#        [0.31252256],
#        [0.31277937],
#        [0.31392047],
#        [0.31377122],
#        [0.3135159 ],
#        [0.3089491 ],
#        [0.30612803],
#        [0.30344042],
#        [0.3008209 ],
#        [0.29746234],
#        [0.29794133],
#        [0.29937527],
#        [0.29972136],
#        [0.30067807],
#        [0.30001011],
#        [0.29993105],
#        [0.29980677],
#        [0.30110893],
#        [0.30135   ],
#        [0.30286956],
#        [0.30637214],
#        [0.30977407],
#        [0.3119945 ],
#        [0.31453285],
#        [0.31709766],
#        [0.31923074],
#        [0.31947264],
#        [0.31692147],
#        [0.3130263 ],
#        [0.3108303 ],
#        [0.30616036],
#        [0.30294195],
#        [0.29934067],
#        [0.29529136],
#        [0.2882996 ],
#        [0.28044567],
#        [0.2709151 ],
#        [0.26172552],
#        [0.25410897],
#        [0.24738184],
#        [0.24123824],
#        [0.23549946],
#        [0.23213948],
#        [0.22814596],
#        [0.22399102],
#        [0.22007085],
#        [0.22156058],
#        [0.22202568],
#        [0.214994  ],
#        [0.20053867],
#        [0.18205683],
#        [0.15896182],
#        [0.13487796],
#        [0.10918435],
#        [0.0867544 ],
#        [0.08496674],
#        [0.08569233],
#        [0.08583878],
#        [0.08659092],
#        [0.085908  ],
#        [0.08438461],
#        [0.08202645],
#        [0.08041567],
#        [0.07844908],
#        [0.07822891],
#        [0.07796723],
#        [0.07555904],
#        [0.07358766],
#        [0.07327721],
#        [0.07381447],
#        [0.07507198],
#        [0.0759616 ],
#        [0.07715595],
#        [0.07968222],
#        [0.08086195],
#        [0.0808046 ],
#        [0.08104026],
#        [0.08115749],
#        [0.08181527],
#        [0.08217108],
#        [0.0821988 ],
#        [0.08130202],
#        [0.08157545],
#        [0.08105171],
#        [0.08071233],
#        [0.08024707],
#        [0.07880077],
#        [0.07860315],
#        [0.07861766],
#        [0.07811946],
#        [0.07862044],
#        [0.07953435],
#        [0.07981035],
#        [0.08043135],
#        [0.08310778],
#        [0.08764052],
#        [0.09318019],
#        [0.10043591],
#        [0.10794357],
#        [0.12897348],
#        [0.16150784],
#        [0.19912897],
#        [0.2471529 ],
#        [0.30024797],
#        [0.3527488 ],
#        [0.40619695],
#        [0.42482913],
#        [0.43796808],
#        [0.4593565 ],
#        [0.5048283 ],
#        [0.56300306],
#        [0.63203716],
#        [0.703017  ],
#        [0.77370125],
#        [0.8381733 ],
#        [0.86118895],
#        [0.819718  ],
#        [0.7978337 ],
#        [0.7774137 ],
#        [0.75134176],
#        [0.7268595 ],
#        [0.69902897],
#        [0.678272  ],
#        [0.6662003 ],
#        [0.66707206],
#        [0.6615309 ],
#        [0.654831  ],
#        [0.6426232 ],
#        [0.6414993 ],
#        [0.63973767],
#        [0.63704693],
#        [0.63874733],
#        [0.6442095 ],
#        [0.6531887 ],
#        [0.6646495 ],
#        [0.6673907 ],
#        [0.66299665],
#        [0.6637166 ],
#        [0.6594777 ],
#        [0.6628368 ],
#        [0.66714406],
#        [0.6800599 ],
#        [0.69191384],
#        [0.69838727],
#        [0.710575  ],
#        [0.72536194],
#        [0.74564433],
#        [0.7719041 ],
#        [0.7890371 ],
#        [0.804834  ],
#        [0.8214499 ],
#        [0.82446146],
#        [0.824201  ],
#        [0.8212415 ],
#        [0.80963767],
#        [0.8122443 ],
#        [0.82116866],
#        [0.83223987],
#        [0.8382163 ],
#        [0.8325181 ],
#        [0.8267448 ],
#        [0.8138087 ],
#        [0.7979034 ],
#        [0.77584505],
#        [0.75671005],
#        [0.7496711 ],
#        [0.7443774 ],
#        [0.73746645],
#        [0.7326386 ],
#        [0.72547317],
#        [0.72424746],
#        [0.7245935 ],
#        [0.7233939 ],
#        [0.7229352 ],
#        [0.72485495],
#        [0.7306429 ],
#        [0.7388797 ],
#        [0.7450001 ],
#        [0.73621345],
#        [0.72273576],
#        [0.7104435 ],
#        [0.69881594],
#        [0.6966449 ],
#        [0.7013829 ],
#        [0.7061275 ],
#        [0.72064626],
#        [0.7327045 ],
#        [0.7366301 ],
#        [0.74001646],
#        [0.74305165],
#        [0.7434292 ],
#        [0.7449733 ],
#        [0.7414148 ],
#        [0.7337806 ],
#        [0.72733295],
#        [0.72181785],
#        [0.71722245],
#        [0.7139621 ],
#        [0.70698   ],
#        [0.71139574],
#        [0.7166519 ],
#        [0.7248851 ],
#        [0.73639977],
#        [0.73535097],
#        [0.73436403],
#        [0.73042   ],
#        [0.7207478 ],
#        [0.71100473],
#        [0.6961876 ],
#        [0.6864023 ],
#        [0.67722225],
#        [0.6695889 ],
#        [0.6672182 ],
#        [0.66020083],
#        [0.6527811 ],
#        [0.645728  ],
#        [0.6341661 ],
#        [0.6291057 ],
#        [0.62606037],
#        [0.62129307],
#        [0.6232629 ],
#        [0.62769425],
#        [0.6341771 ],
#        [0.6436027 ],
#        [0.6482074 ],
#        [0.6526587 ],
#        [0.6539905 ],
#        [0.65371156],
#        [0.64816797],
#        [0.638747  ],
#        [0.63303256],
#        [0.62941647],
#        [0.6312468 ],
#        [0.6331465 ],
#        [0.63294363],
#        [0.635018  ],
#        [0.6297467 ],
#        [0.6264839 ],
#        [0.62737286],
#        [0.6371523 ],
#        [0.6547017 ],
#        [0.67016566],
#        [0.6787621 ],
#        [0.6799257 ],
#        [0.6816393 ],
#        [0.68359995],
#        [0.68123984],
#        [0.67611814],
#        [0.66783154],
#        [0.6588243 ],
#        [0.6510515 ],
#        [0.6453589 ],
#        [0.6416652 ],
#        [0.6388898 ],
#        [0.6338062 ],
#        [0.6308334 ],
#        [0.62861943],
#        [0.6282486 ],
#        [0.6300831 ],
#        [0.6337718 ],
#        [0.6355878 ],
#        [0.6392139 ],
#        [0.64302886],
#        [0.6478902 ],
#        [0.64921796],
#        [0.6477722 ],
#        [0.6424569 ],
#        [0.6399678 ],
#        [0.64069724],
#        [0.64420676],
#        [0.64804816],
#        [0.65285504],
#        [0.6602708 ],
#        [0.66558814],
#        [0.67031825],
#        [0.67492175],
#        [0.67637944],
#        [0.68064415],
#        [0.6825521 ],
#        [0.6796899 ],
#        [0.67868805],
#        [0.676489  ],
#        [0.67417026],
#        [0.67347574],
#        [0.6723547 ],
#        [0.67152786],
#        [0.6730503 ],
#        [0.67936075],
#        [0.6894803 ],
#        [0.6982937 ],
#        [0.70484114],
#        [0.7071314 ],
#        [0.70619833],
#        [0.7057053 ],
#        [0.7044562 ],
#        [0.7027843 ],
#        [0.70196986],
#        [0.70115197],
#        [0.69916594],
#        [0.69951713],
#        [0.70211124],
#        [0.70624757],
#        [0.7097422 ],
#        [0.70880723],
#        [0.7046211 ],
#        [0.69899106],
#        [0.69409263],
#        [0.6897787 ],
#        [0.6999661 ],
#        [0.6890423 ],
#        [0.6799293 ],
#        [0.67264676],
#        [0.67090774],
#        [0.66888785],
#        [0.67175025],
#        [0.67214656],
#        [0.6725452 ],
#        [0.6704504 ],
#        [0.66785324],
#        [0.66583085],
#        [0.66476357],
#        [0.6690664 ],
#        [0.6742791 ],
#        [0.677722  ],
#        [0.6752268 ],
#        [0.6713026 ],
#        [0.667657  ],
#        [0.66442156],
#        [0.662426  ],
#        [0.66280186],
#        [0.6666151 ],
#        [0.6694635 ],
#        [0.6716632 ],
#        [0.6740802 ],
#        [0.68230015],
#        [0.6908448 ],
#        [0.6974842 ],
#        [0.70428693],
#        [0.71097386],
#        [0.7170518 ],
#        [0.7200296 ],
#        [0.71833247],
#        [0.7146052 ],
#        [0.72469777],
#        [0.740998  ],
#        [0.7547911 ],
#        [0.75636303],
#        [0.7530012 ],
#        [0.75500894],
#        [0.76096773],
#        [0.7654591 ],
#        [0.7626761 ],
#        [0.7579775 ],
#        [0.747222  ],
#        [0.7313185 ],
#        [0.7144617 ],
#        [0.7065663 ],
#        [0.70704854],
#        [0.7104593 ],
#        [0.713339  ],
#        [0.7104093 ],
#        [0.7131206 ],
#        [0.72102416],
#        [0.73104095],
#        [0.73482335],
#        [0.7333917 ],
#        [0.7349969 ],
#        [0.7382748 ],
#        [0.7404026 ],
#        [0.7360892 ],
#        [0.7313309 ],
#        [0.72483987],
#        [0.72214293],
#        [0.7195853 ],
#        [0.7202602 ],
#        [0.72189844],
#        [0.7250854 ],
#        [0.731008  ],
#        [0.7387294 ],
#        [0.7473667 ],
#        [0.7487486 ],
#        [0.7466624 ],
#        [0.74376285],
#        [0.7431592 ],
#        [0.74009514],
#        [0.7349378 ],
#        [0.73175764],
#        [0.72977823],
#        [0.7272653 ],
#        [0.72322893],
#        [0.71973157],
#        [0.7176684 ],
#        [0.7181876 ],
#        [0.72156096],
#        [0.72622216],
#        [0.7304096 ],
#        [0.73098004],
#        [0.72798455],
#        [0.7230073 ],
#        [0.7187077 ],
#        [0.7175512 ],
#        [0.7165333 ],
#        [0.71295226],
#        [0.7069979 ],
#        [0.700289  ],
#        [0.693993  ],
#        [0.68774784],
#        [0.6812466 ],
#        [0.6779727 ],
#        [0.67883956],
#        [0.6800642 ],
#        [0.68107116],
#        [0.68081075],
#        [0.6817652 ],
#        [0.6819165 ],
#        [0.6809258 ],
#        [0.68013656],
#        [0.68178207],
#        [0.683349  ],
#        [0.6827527 ],
#        [0.6826932 ],
#        [0.68442345],
#        [0.6873966 ],
#        [0.68816495],
#        [0.686435  ],
#        [0.683095  ],
#        [0.67662597],
#        [0.6644971 ],
#        [0.64770746],
#        [0.6326899 ],
#        [0.6220426 ],
#        [0.61624   ],
#        [0.5987746 ],
#        [0.5751641 ],
#        [0.55200243],
#        [0.53295445],
#        [0.52532405],
#        [0.527632  ],
#        [0.5312003 ],
#        [0.53396183],
#        [0.53974056],
#        [0.54407084],
#        [0.542552  ],
#        [0.5388718 ],
#        [0.5376139 ],
#        [0.5374177 ],
#        [0.5379995 ],
#        [0.5409396 ],
#        [0.54316056],
#        [0.5475835 ],
#        [0.55008954],
#        [0.54943204],
#        [0.54706466],
#        [0.5484468 ],
#        [0.5478059 ],
#        [0.5482063 ],
#        [0.55038375],
#        [0.55114245],
#        [0.548439  ],
#        [0.54107046],
#        [0.535686  ],
#        [0.53046286],
#        [0.52714413],
#        [0.5260622 ],
#        [0.5283506 ],
#        [0.5321544 ],
#        [0.53546035],
#        [0.5357715 ],
#        [0.5354336 ],
#        [0.53238714],
#        [0.5308375 ],
#        [0.52999943],
#        [0.5358228 ],
#        [0.5429597 ],
#        [0.5496293 ],
#        [0.5507169 ],
#        [0.5497806 ],
#        [0.5473298 ],
#        [0.5458353 ],
#        [0.54747295],
#        [0.547847  ],
#        [0.5463596 ],
#        [0.5428844 ],
#        [0.55495507],
#        [0.57742864],
#        [0.6011393 ],
#        [0.62539387],
#        [0.6291902 ],
#        [0.6251157 ],
#        [0.62358415],
#        [0.6220189 ],
#        [0.62262505],
#        [0.6244497 ],
#        [0.6226382 ],
#        [0.6210106 ],
#        [0.6128984 ],
#        [0.5963513 ],
#        [0.5705563 ],
#        [0.54792917],
#        [0.5310862 ],
#        [0.5124382 ],
#        [0.5033232 ],
#        [0.4972783 ],
#        [0.4944591 ],
#        [0.49937424],
#        [0.5044073 ],
#        [0.50492215],
#        [0.5046687 ],
#        [0.50542736],
#        [0.50707686],
#        [0.5105228 ],
#        [0.5117012 ],
#        [0.5126416 ],
#        [0.50906104],
#        [0.50591457],
#        [0.5070255 ],
#        [0.5083747 ],
#        [0.5115079 ],
#        [0.51313335],
#        [0.51227015],
#        [0.5111748 ],
#        [0.51222104],
#        [0.51568776],
#        [0.51863706],
#        [0.5204446 ],
#        [0.51825446],
#        [0.5144277 ],
#        [0.5102493 ],
#        [0.50153404],
#        [0.49250597],
#        [0.48586145],
#        [0.4851511 ],
#        [0.49258563],
#        [0.5019214 ],
#        [0.5113751 ],
#        [0.51999354],
#        [0.5248714 ],
#        [0.5278675 ],
#        [0.53086835],
#        [0.5299542 ],
#        [0.5291371 ],
#        [0.5266022 ],
#        [0.51866305],
#        [0.51213086],
#        [0.5069082 ],
#        [0.5072022 ],
#        [0.50922364],
#        [0.51327115],
#        [0.51825273],
#        [0.5226707 ],
#        [0.5251819 ],
#        [0.52343845],
#        [0.5194028 ],
#        [0.5126637 ],
#        [0.50893193],
#        [0.50816166],
#        [0.51017135],
#        [0.51197046],
#        [0.5154404 ],
#        [0.5164569 ],
#        [0.51658994],
#        [0.51705647],
#        [0.51635545],
#        [0.5182853 ],
#        [0.51949424],
#        [0.5189006 ],
#        [0.51738286],
#        [0.50901073],
#        [0.50098336],
#        [0.49420157],
#        [0.48585287],
#        [0.47911325],
#        [0.473071  ],
#        [0.46763402],
#        [0.4647571 ],
#        [0.46615317],
#        [0.46856365],
#        [0.4742634 ],
#        [0.47527513],
#        [0.47740072],
#        [0.4759865 ],
#        [0.47406682],
#        [0.4740764 ],
#        [0.4758192 ],
#        [0.4771543 ],
#        [0.47914553],
#        [0.47962183],
#        [0.47656116],
#        [0.46661016],
#        [0.45442715],
#        [0.44409713],
#        [0.43830284],
#        [0.4390993 ],
#        [0.442629  ],
#        [0.44581074],
#        [0.45198467],
#        [0.45698637],
#        [0.46315262],
#        [0.46952638],
#        [0.47217807],
#        [0.47721997],
#        [0.46398365],
#        [0.44973025],
#        [0.4291629 ],
#        [0.41301754],
#        [0.41157687],
#        [0.41096142],
#        [0.41515985],
#        [0.41403726],
#        [0.4153143 ],
#        [0.41544122],
#        [0.4150912 ],
#        [0.41567627],
#        [0.41176996],
#        [0.41052645],
#        [0.4080495 ],
#        [0.4080547 ],
#        [0.40862358],
#        [0.41034916],
#        [0.41353837],
#        [0.41696742],
#        [0.41893244],
#        [0.41840193],
#        [0.4163274 ],
#        [0.4148819 ],
#        [0.41595322],
#        [0.41724476],
#        [0.419397  ],
#        [0.4183648 ],
#        [0.41701525],
#        [0.4148561 ],
#        [0.41167495],
#        [0.41131702],
#        [0.41104397],
#        [0.41335273],
#        [0.417751  ],
#        [0.4192886 ],
#        [0.42033333],
#        [0.41857198],
#        [0.41597572],
#        [0.41570702],
#        [0.4155937 ],
#        [0.41292542],
#        [0.41734824]], dtype=float32)

# %%
from numpy import column_stack

lstm_outputs = xscaler.inverse_transform(lstm_outputs)
gru_outputs = xscaler.inverse_transform(gru_outputs)

y_train = xscaler.inverse_transform(y_train)

stacking_inputs = column_stack((lstm_outputs, gru_outputs))

# %%
stacking_inputs
# Out:
# array([[8348.446, 8362.847],
#        [8340.826, 8354.995],
#        [8335.267, 8356.665],
#        ...,
#        [8511.618, 8455.61 ],
#        [8504.319, 8433.126],
#        [8516.419, 8470.685]], dtype=float32)

# %%
# stacking_model = Sequential()
# stacking_model.add(Dense(2, input_shape=(stacking_inputs.shape[1],)))
# stacking_model.add(Dense(1, activation='linear'))
# stacking_model.compile(optimizer='adam', loss='mean_squared_error')
stacking_model = LinearRegression()

# Train stacking model
stacking_model.fit(stacking_inputs, y_train)
# Out:
# LinearRegression()

# %%
#tạo testing data set
test_data = scaler_data[train_size - n_lag: , :]
x_test = []
y_test = data_with_lagged.iloc[train_size:, 1]
y_test = y_test.reset_index()
y_test = y_test.drop(['DateTime'], axis=1)

for i in range(n_lag, len(test_data)):
  x_test.append(test_data[i-n_lag:i, :])

x_test = np.asarray(x_test)
print(x_test.shape, y_test.shape)
# Out:
# (150, 7, 1) (150, 1)

# %%
#get the models predicted price value
lstm_test_predictions = []
gru_test_predictions = []

for i in range(5):
  lstm_test_prediction = lstm_models[i].predict(x_test)
  gru_test_prediction = gru_models[i].predict(x_test)
  
  lstm_test_prediction = xscaler.inverse_transform(lstm_test_prediction)
  gru_test_prediction = xscaler.inverse_transform(gru_test_prediction)
  
  lstm_test_predictions.append(lstm_test_prediction)
  gru_test_predictions.append(gru_test_prediction)

lstm_test_predictions = sum(lstm_test_predictions) / len(lstm_test_predictions)
gru_test_predictions = sum(gru_test_predictions) / len(gru_test_predictions)

stacking_close_predictions = stacking_model.predict(column_stack((lstm_test_predictions, gru_test_predictions)))

# stacking_close_predictions = xscaler.inverse_transform(stacking_close_predictions)
# stacking_close_predictions.to_csv("pred-price.csv", index=False)
stacking_close_predictions.shape
# Out:
# 5/5 [==============================] - 0s 6ms/step
# 5/5 [==============================] - 0s 10ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# (150, 1)

# %%
#sai số
mse = np.mean((y_test - stacking_close_predictions)**2)
mae = np.mean(np.abs(y_test - stacking_close_predictions))
mape = np.mean(np.abs((y_test - stacking_close_predictions) / y_test)) * 100
smape = 200 * np.mean(np.abs((y_test - stacking_close_predictions) / (np.abs(y_test) + np.abs(stacking_close_predictions))))
print(mse["Close"], mae["Close"], mape["Close"], smape["Close"])

#sai số
mseLSTM = np.mean((y_test - lstm_test_predictions)**2)
maeLSTM = np.mean(np.abs(y_test - lstm_test_predictions))
mapeLSTM = np.mean(np.abs((y_test - lstm_test_predictions) / y_test)) * 100
smapeLSTM = 200 * np.mean(np.abs((y_test - lstm_test_predictions) / (np.abs(y_test) + np.abs(lstm_test_predictions))))
print(mseLSTM["Close"], maeLSTM["Close"], mapeLSTM["Close"], smapeLSTM["Close"])

#sai số
mseGRU = np.mean((y_test - gru_test_predictions)**2)
maeGRU = np.mean(np.abs(y_test - gru_test_predictions))
mapeGRU = np.mean(np.abs((y_test - gru_test_predictions) / y_test)) * 100
smapeGRU = 200 * np.mean(np.abs((y_test - gru_test_predictions) / (np.abs(y_test) + np.abs(gru_test_predictions))))
print(mseGRU["Close"], maeGRU["Close"], mapeGRU["Close"], smapeGRU["Close"])
# Out:
# 3660.381268974755 45.411734505208344 0.5835822312511582 0.5827810192904663
# 9772.108584791247 63.516346744791676 0.8341796751653338 0.8260139905555106
# 7165.594491019001 52.65087304687502 0.6980769914434637 0.6917168685526324
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#
valid = data_with_lagged[train_size:]
valid['SE'] = stacking_close_predictions
valid['LSTM'] = lstm_test_predictions
valid['GRU'] = gru_test_predictions

#hiển thị dữ liệu gần đây
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Giá (USD)', fontsize=18)
plt.plot(valid[['Close','SE','LSTM', 'GRU']])
plt.legend(['Val', 'SE', 'LSTM', 'GRU'], loc='lower right')
plt.show()
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\871103454.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['SE'] = stacking_close_predictions
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\871103454.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['LSTM'] = lstm_test_predictions
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\871103454.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['GRU'] = gru_test_predictions

# %%
#create file if it does not exist
data = {
    'Model': 'SE',
    'Thông tin': ['MAE', 'MSE', 'MAPE', 'sMAPE'],
    'Price': [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]
}
result_table = pd.DataFrame(data)
result_table.to_csv("result-hours.csv", index=False)
result_table
# Out:
#   Model Thông tin        Price
# 0    SE       MAE    45.411735
# 1    SE       MSE  3660.381269
# 2    SE      MAPE     0.583582
# 3    SE     sMAPE     0.582781

# %%
valid["PredSE"] = (valid["SE"] > valid["SE"].shift(1)).astype(int)
valid["PredLSTM"] = (valid["LSTM"] > valid["LSTM"].shift(1)).astype(int)
valid["PredGRU"] = (valid["GRU"] > valid["GRU"].shift(1)).astype(int)
valid["CorrectSE"] = (valid["PredSE"] - valid["Change"]) == 0
valid["CorrectLSTM"] = (valid["PredLSTM"] - valid["Change"]) == 0
valid["CorrectGRU"] = (valid["PredGRU"] - valid["Change"]) == 0
incorrect = valid.loc[valid['CorrectSE'] == False]
incorrect_len = len(incorrect)
prices_len = len(valid)
print("Accuracy = ",((prices_len-incorrect_len + 1)/prices_len))
print("Accuracy = ",((len(valid.loc[valid['CorrectLSTM'] == True]) + 1)/prices_len))
print("Accuracy = ",((len(valid.loc[valid['CorrectGRU'] == True]) + 1)/prices_len))
valid
# Out:
# Accuracy =  0.52
# Accuracy =  0.49333333333333335
# Accuracy =  0.4666666666666667
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\3164592590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["PredSE"] = (valid["SE"] > valid["SE"].shift(1)).astype(int)
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\3164592590.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["PredLSTM"] = (valid["LSTM"] > valid["LSTM"].shift(1)).astype(int)
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\3164592590.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["PredGRU"] = (valid["GRU"] > valid["GRU"].shift(1)).astype(int)
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\3164592590.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["CorrectSE"] = (valid["PredSE"] - valid["Change"]) == 0
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\3164592590.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["CorrectLSTM"] = (valid["PredLSTM"] - valid["Change"]) == 0
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_15376\3164592590.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["CorrectGRU"] = (valid["PredGRU"] - valid["Change"]) == 0
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2019-11-17 10:00:00+00:00       0  8521.51  0.179613  0.086724     2003.0
# 2019-11-17 11:00:00+00:00       0  8517.85  0.176844  0.083686     2095.0
# 2019-11-17 12:00:00+00:00       1  8562.34  0.178609  0.089045     2209.0
# 2019-11-17 13:00:00+00:00       0  8533.17  0.174711  0.071781     2239.0
# 2019-11-17 14:00:00+00:00       0  8516.54  0.188581  0.061722     2492.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI           SE         LSTM          GRU  \
# DateTime
# 2019-11-17 10:00:00+00:00  55.449108  8503.429688  8505.213867  8508.057617
# 2019-11-17 11:00:00+00:00  54.785894  8504.878906  8519.552734  8513.761719
# 2019-11-17 12:00:00+00:00  60.906931  8498.413086  8531.643555  8513.815430
# 2019-11-17 13:00:00+00:00  55.592844  8520.105469  8539.125000  8529.743164
# 2019-11-17 14:00:00+00:00  52.766279  8517.065430  8548.267578  8530.927734
# ...                              ...          ...          ...          ...
# 2019-11-23 11:00:00+00:00  39.929000  7206.333008  7261.972656  7288.815430
# 2019-11-23 12:00:00+00:00  38.084247  7210.072266  7255.469727  7288.948242
# 2019-11-23 13:00:00+00:00  41.201744  7206.525391  7248.551758  7284.434570
# 2019-11-23 14:00:00+00:00  50.123331  7211.918945  7244.190430  7286.308594
# 2019-11-23 15:00:00+00:00  53.205251  7243.887695  7250.809570  7308.304688
#
#                            PredSE  PredLSTM  PredGRU  CorrectSE  CorrectLSTM  \
# DateTime
# 2019-11-17 10:00:00+00:00       0         0        0       True         True
# 2019-11-17 11:00:00+00:00       1         1        1      False        False
# 2019-11-17 12:00:00+00:00       0         1        1      False         True
# 2019-11-17 13:00:00+00:00       1         1        1      False        False
# 2019-11-17 14:00:00+00:00       0         1        1       True        False
# ...                           ...       ...      ...        ...          ...
# 2019-11-23 11:00:00+00:00       1         0        0       True        False
# 2019-11-23 12:00:00+00:00       1         0        1      False         True
# 2019-11-23 13:00:00+00:00       0         0        0      False        False
# 2019-11-23 14:00:00+00:00       1         0        1       True        False
# 2019-11-23 15:00:00+00:00       1         1        1       True         True
#
#                            CorrectGRU
# DateTime
# 2019-11-17 10:00:00+00:00        True
# 2019-11-17 11:00:00+00:00       False
# 2019-11-17 12:00:00+00:00        True
# 2019-11-17 13:00:00+00:00       False
# 2019-11-17 14:00:00+00:00       False
# ...                               ...
# 2019-11-23 11:00:00+00:00       False
# 2019-11-23 12:00:00+00:00       False
# 2019-11-23 13:00:00+00:00       False
# 2019-11-23 14:00:00+00:00        True
# 2019-11-23 15:00:00+00:00        True
#
# [150 rows x 15 columns]
