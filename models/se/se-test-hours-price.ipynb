# %%
#imports các thư viện
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle
from sklearn.model_selection import KFold

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat


import keras.utils
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Input, concatenate, Dense
from keras.layers import LSTM, GRU
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
def rsi(data, period: int = 14):

    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity (độ trễ) - days or hours
lag_granularity = "hours"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "hour"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/" + \
    analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_" + \
    str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename, index_col='DateTime', parse_dates=True)

# %%
#group by datetime
df = df.groupby('DateTime').agg(lambda x: x.mean())
df
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_18772\3489936249.py:2: FutureWarning: ['dt'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df = df.groupby('DateTime').agg(lambda x: x.mean())
#                              Close  Volume_(BTC)  Weighted_Price   neg_pol  \
# DateTime
# 2018-08-31 10:00:00+00:00  6949.40      2.333380     6948.996140  0.040167
# 2018-08-31 11:00:00+00:00  6946.06      2.430317     6948.538492  0.020167
# 2018-08-31 12:00:00+00:00  6963.30      3.922626     6964.052374  0.035800
# 2018-08-31 13:00:00+00:00  6900.00      9.040247     6932.162091  0.084000
# 2018-08-31 14:00:00+00:00  6927.92      5.947736     6912.448529  0.025333
# ...                            ...           ...             ...       ...
# 2019-11-23 11:00:00+00:00  7180.02      6.622678     7190.277423  0.067410
# 2019-11-23 12:00:00+00:00  7157.47      7.074875     7181.956969  0.072038
# 2019-11-23 13:00:00+00:00  7181.50      9.766378     7171.704462  0.072152
# 2019-11-23 14:00:00+00:00  7260.77      6.143298     7231.168406  0.064122
# 2019-11-23 15:00:00+00:00  7292.72      2.660796     7272.018586  0.063931
#
#                             neu_pol   pos_pol  compound  Tweet_vol
# DateTime
# 2018-08-31 10:00:00+00:00  0.876000  0.083833  0.155633       18.0
# 2018-08-31 11:00:00+00:00  0.865000  0.114833  0.246883       37.0
# 2018-08-31 12:00:00+00:00  0.839600  0.124600  0.254660       42.0
# 2018-08-31 13:00:00+00:00  0.789250  0.126917  0.218183       55.0
# 2018-08-31 14:00:00+00:00  0.861444  0.113222  0.263544       38.0
# ...                             ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00  0.760387  0.172199  0.250681     2304.0
# 2019-11-23 12:00:00+00:00  0.751780  0.176183  0.235377     2467.0
# 2019-11-23 13:00:00+00:00  0.756339  0.171514  0.245202     2612.0
# 2019-11-23 14:00:00+00:00  0.755714  0.180162  0.269456     2676.0
# 2019-11-23 15:00:00+00:00  0.754940  0.181127  0.254060     2271.0
#
# [10781 rows x 8 columns]

# %%
#tính toán các chỉ số indicator: rsi, ma
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = True
add_longMAvg = True
add_shortMAvg = True

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()

if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_18772\259356298.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_18772\259356298.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity', 'Tweet_vol', 'Volume_(BTC)'] if analyser == "Textblob" else [
    'Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")

if(add_longMAvg):
    features.append("long_mavg")

if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
data_with_lagged = df_copy.dropna()
data_with_lagged
# Out:
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2018-09-01 21:00:00+00:00       0  7195.95  0.070500  0.019000       30.0
# 2018-09-01 22:00:00+00:00       0  7187.23  0.073000  0.073833       37.0
# 2018-09-01 23:00:00+00:00       1  7189.90  0.152250  0.032000       30.0
# 2018-09-02 00:00:00+00:00       1  7197.50  0.063333  0.040333       31.0
# 2018-09-02 01:00:00+00:00       0  7159.99  0.233667  0.000000       18.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI    long_mavg   short_mavg
# DateTime
# 2018-09-01 21:00:00+00:00  65.930409  7097.183810  7156.526667
# 2018-09-01 22:00:00+00:00  64.172838  7104.425238  7173.410000
# 2018-09-01 23:00:00+00:00  64.485028  7111.765714  7188.968889
# 2018-09-02 00:00:00+00:00  65.408993  7119.059048  7197.981111
# 2018-09-02 01:00:00+00:00  57.462959  7123.820476  7196.502222
# ...                              ...          ...          ...
# 2019-11-23 11:00:00+00:00  39.929000  7223.752857  7204.497778
# 2019-11-23 12:00:00+00:00  38.084247  7225.775238  7190.205556
# 2019-11-23 13:00:00+00:00  41.201744  7228.573810  7185.751111
# 2019-11-23 14:00:00+00:00  50.123331  7233.933810  7189.787778
# 2019-11-23 15:00:00+00:00  53.205251  7236.630476  7196.947778
#
# [10727 rows x 8 columns]

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)

data_hours = data_with_lagged.iloc[:, :2].reset_index().drop(['DateTime'], axis=1)

train = data_with_lagged.iloc[:train_size, :2]
train = train.reset_index()
train = train.drop(['DateTime'], axis=1)

train
# Out:
#       Change     Close
# 0          0   7195.95
# 1          0   7187.23
# 2          1   7189.90
# 3          1   7197.50
# 4          0   7159.99
# ...      ...       ...
# 9112       0  10168.00
# 9113       0  10153.97
# 9114       1  10168.54
# 9115       0  10159.50
# 9116       1  10208.42
#
# [9117 rows x 2 columns]

# %%
#chuẩn hóa
xscaler = MinMaxScaler(feature_range=(0, 1))
train = xscaler.fit_transform(train)
scaler_data = xscaler.transform(data_hours)
# scaler_data = data_with_lagged
print(train.shape, scaler_data.shape)
# Out:
# (9117, 2) (10727, 2)

# %%
X_train = []
y_train = []

for i in range(n_lag, len(train)):
  X_train.append(train[i-n_lag:i, :])
  y_train.append(train[i, :])

X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

print(X_train.shape, y_train.shape)
# Out:
# (9110, 7, 2) (9110, 2)

# %%
# design network
neurons = 64
epochs = 32
dropout = 0.25
batch_size = 80
activ_func = "relu"

# %%
# early stopping callback
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =20)

# %%
# Số fold
k = 5
kf = KFold(n_splits=k, shuffle=False)

# List để lưu kết quả dự đoán từ LSTM và GRU
lstm_predictions = []
gru_predictions = []

# Xây dựng mô hình stacking
for train_index, test_index in kf.split(X_train):
    X_sub_train, X_sub_test = X_train[train_index], X_train[test_index]
    y_sub_train, y_sub_test = y_train[train_index], y_train[test_index]
    # Xây dựng mô hình LSTM và huấn luyện
    lstm_model = Sequential()
    lstm_model.add(LSTM(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    lstm_model.add(LSTM(neurons, return_sequences=False))
    lstm_model.add(Dense(2))
    lstm_model.compile(optimizer='adam', loss='mean_squared_error')

    # Xây dựng mô hình GRU và huấn luyện
    gru_model = Sequential()
    gru_model.add(GRU(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    gru_model.add(GRU(neurons, return_sequences=False))
    gru_model.add(Dense(2))
    gru_model.compile(optimizer='adam', loss='mean_squared_error')
    
    lstm_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    gru_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    # Lấy đầu ra của mô hình LSTM và GRU
    lstm_output = lstm_model.predict(X_sub_test)
    gru_output = gru_model.predict(X_sub_test)
    
    lstm_predictions.append(lstm_output)
    gru_predictions.append(gru_output)
# Out:
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.1508
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1252
# Epoch 3/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1248
# Epoch 4/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1246
# Epoch 5/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1244
# Epoch 6/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1249
# Epoch 7/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1241
# Epoch 8/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1251
# Epoch 9/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1238
# Epoch 10/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1237
# Epoch 11/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1239
# Epoch 12/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1242
# Epoch 13/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1236
# Epoch 14/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1235
# Epoch 15/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1235
# Epoch 16/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1238
# Epoch 17/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1237
# Epoch 18/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1236
# Epoch 19/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1233
# Epoch 20/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1235
# Epoch 21/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 22/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 23/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 24/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 26/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1232
# Epoch 27/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 28/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1236
# Epoch 29/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 30/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 31/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1232
# Epoch 32/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1233
# Epoch 1/32
# 92/92 [==============================] - 4s 8ms/step - loss: 0.1437
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1242
# Epoch 3/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1240
# Epoch 4/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1238
# Epoch 5/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1238
# Epoch 6/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1239
# Epoch 7/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 8/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1235
# Epoch 9/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1238
# Epoch 10/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1236
# Epoch 11/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1235
# Epoch 12/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 13/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1238
# Epoch 14/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1236
# Epoch 15/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1233
# Epoch 16/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1234
# Epoch 17/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1236
# Epoch 18/32
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1234
# Epoch 19/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1234
# Epoch 20/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1233
# Epoch 21/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1232
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 23/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 24/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1233
# Epoch 25/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 26/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 27/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1235
# Epoch 28/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1233
# Epoch 29/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 31/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1233
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# 57/57 [==============================] - 1s 4ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 92/92 [==============================] - 4s 10ms/step - loss: 0.1482
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1254
# Epoch 3/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1252
# Epoch 4/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1253
# Epoch 5/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1244
# Epoch 6/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1245
# Epoch 7/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1245
# Epoch 8/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1245
# Epoch 9/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1238
# Epoch 10/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1239
# Epoch 11/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1239
# Epoch 12/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 13/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1239
# Epoch 14/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1239
# Epoch 15/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1240
# Epoch 16/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1239
# Epoch 17/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1237
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1239
# Epoch 19/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 20/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1240
# Epoch 21/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1239
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 23/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 24/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1238
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 26/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 27/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 28/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1237
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1239
# Epoch 30/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1234
# Epoch 31/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1235
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.1420
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1242
# Epoch 3/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1241
# Epoch 4/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 5/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1244
# Epoch 6/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1243
# Epoch 7/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 8/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1241
# Epoch 9/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1236
# Epoch 10/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 11/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1242
# Epoch 12/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 13/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1238
# Epoch 14/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1243
# Epoch 15/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 16/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 17/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1242
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1242
# Epoch 19/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 20/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 21/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1236
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 23/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1240
# Epoch 24/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 26/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 27/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 28/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 29/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1236
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1241
# Epoch 31/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1237
# Epoch 32/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1235
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.1522
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1258
# Epoch 3/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1257
# Epoch 4/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1246
# Epoch 5/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1246
# Epoch 6/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1249
# Epoch 7/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1242
# Epoch 8/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1243
# Epoch 9/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1240
# Epoch 10/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1241
# Epoch 11/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 12/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1238
# Epoch 13/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1239
# Epoch 14/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 15/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1238
# Epoch 16/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 17/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1235
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 19/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1238
# Epoch 20/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1238
# Epoch 21/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1238
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 23/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1233
# Epoch 24/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 26/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 27/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 28/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1233
# Epoch 29/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1236
# Epoch 30/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1234
# Epoch 31/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.1457
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1244
# Epoch 3/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1251
# Epoch 4/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1237
# Epoch 5/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1239
# Epoch 6/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 7/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1238
# Epoch 8/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1237
# Epoch 9/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 10/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 11/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1233
# Epoch 12/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1239
# Epoch 13/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1240
# Epoch 14/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 15/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1240
# Epoch 16/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1237
# Epoch 17/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1235
# Epoch 18/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1236
# Epoch 19/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1233
# Epoch 20/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 21/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1234
# Epoch 22/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 23/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1233
# Epoch 24/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 25/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 26/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 27/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 28/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 29/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1232
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 31/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1233
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 92/92 [==============================] - 4s 11ms/step - loss: 0.1523
# Epoch 2/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1258
# Epoch 3/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1249
# Epoch 4/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1249
# Epoch 5/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1243
# Epoch 6/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1241
# Epoch 7/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1246
# Epoch 8/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1239
# Epoch 9/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1234
# Epoch 10/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1234
# Epoch 11/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1235
# Epoch 12/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 13/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1232
# Epoch 14/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1232
# Epoch 15/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1233
# Epoch 16/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1233
# Epoch 17/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1229
# Epoch 18/32
# 92/92 [==============================] - 1s 14ms/step - loss: 0.1233
# Epoch 19/32
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1230
# Epoch 20/32
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1229
# Epoch 21/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1232
# Epoch 22/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1230
# Epoch 23/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1229
# Epoch 24/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1232
# Epoch 25/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1229
# Epoch 26/32
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1233
# Epoch 27/32
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1230
# Epoch 28/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1230
# Epoch 29/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1229
# Epoch 30/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1231
# Epoch 31/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1230
# Epoch 32/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1228
# Epoch 1/32
# 92/92 [==============================] - 4s 8ms/step - loss: 0.1417
# Epoch 2/32
# 92/92 [==============================] - 1s 8ms/step - loss: 0.1239
# Epoch 3/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1238
# Epoch 4/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1240
# Epoch 5/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1236
# Epoch 6/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1233
# Epoch 7/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 8/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1236
# Epoch 9/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1230
# Epoch 10/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1239
# Epoch 11/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1236
# Epoch 12/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 13/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1231
# Epoch 14/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 15/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1230
# Epoch 16/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1230
# Epoch 17/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1231
# Epoch 18/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1231
# Epoch 19/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 20/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1231
# Epoch 21/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1231
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1231
# Epoch 23/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1229
# Epoch 24/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1229
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1231
# Epoch 26/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1229
# Epoch 27/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1232
# Epoch 28/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1230
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1228
# Epoch 31/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 32/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1231
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 92/92 [==============================] - 4s 10ms/step - loss: 0.1462
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1251
# Epoch 3/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1246
# Epoch 4/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1244
# Epoch 5/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1245
# Epoch 6/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1241
# Epoch 7/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1240
# Epoch 8/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1235
# Epoch 9/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1237
# Epoch 10/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1236
# Epoch 11/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1233
# Epoch 12/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 13/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 14/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 15/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 16/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 17/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1232
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1231
# Epoch 19/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1235
# Epoch 20/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1233
# Epoch 21/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1230
# Epoch 22/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 23/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 24/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 25/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 26/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 27/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 28/32
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1230
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 30/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 31/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1233
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1230
# Epoch 1/32
# 92/92 [==============================] - 4s 9ms/step - loss: 0.1440
# Epoch 2/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 3/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1237
# Epoch 4/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1236
# Epoch 5/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1234
# Epoch 6/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1237
# Epoch 7/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 8/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1234
# Epoch 9/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1233
# Epoch 10/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1233
# Epoch 11/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1235
# Epoch 12/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1231
# Epoch 13/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 14/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1231
# Epoch 15/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 16/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 17/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1233
# Epoch 18/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1230
# Epoch 19/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1231
# Epoch 20/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1233
# Epoch 21/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 22/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1231
# Epoch 23/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1231
# Epoch 24/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1231
# Epoch 25/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1231
# Epoch 26/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1230
# Epoch 27/32
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1230
# Epoch 28/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1232
# Epoch 29/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1232
# Epoch 30/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1231
# Epoch 31/32
# 92/92 [==============================] - 1s 9ms/step - loss: 0.1235
# Epoch 32/32
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1231
# 57/57 [==============================] - 1s 4ms/step
# 57/57 [==============================] - 1s 3ms/step

# %%
type(lstm_predictions)
# Out:
# list

# %%
# Lấy đầu ra của LSTM và GRU
lstm_outputs = np.concatenate(lstm_predictions, axis=0)
gru_outputs = np.concatenate(gru_predictions, axis=0)

# %%
from numpy import column_stack

lstm_outputs = xscaler.inverse_transform(lstm_outputs)
gru_outputs = xscaler.inverse_transform(gru_outputs)

y_train = xscaler.inverse_transform(y_train)

stacking_inputs = column_stack((lstm_outputs, gru_outputs))

# %%
print(stacking_inputs[:, 1], y_train[:, 1])
stacking_inputs
# Out:
# [ 7208.0083  7270.038   7314.183  ... 10229.62   10213.335  10192.16  ] [ 7183.12  7208.98  7230.99 ... 10168.54 10159.5  10208.42]
# array([[5.1320428e-01, 7.2080083e+03, 5.5029619e-01, 7.1162979e+03],
#        [4.8034668e-01, 7.2700381e+03, 5.0294387e-01, 7.1363457e+03],
#        [4.6404609e-01, 7.3141831e+03, 4.8719996e-01, 7.1168477e+03],
#        ...,
#        [5.8459353e-01, 1.0229620e+04, 5.4372972e-01, 9.9780420e+03],
#        [5.2083486e-01, 1.0213335e+04, 4.8539624e-01, 9.9525840e+03],
#        [5.5656701e-01, 1.0192160e+04, 5.2007043e-01, 9.9609658e+03]],
#       dtype=float32)

# %%
stacking_model = Sequential()
stacking_model.add(Dense(4, input_shape=(stacking_inputs.shape[1],)))
stacking_model.add(Dense(2, activation='linear'))
stacking_model.compile(optimizer='adam', loss='mean_squared_error')

# Train stacking model
stacking_model.fit(stacking_inputs, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/32
# 114/114 [==============================] - 1s 1ms/step - loss: 11389804.0000
# Epoch 2/32
# 114/114 [==============================] - 0s 1ms/step - loss: 1142306.8750
# Epoch 3/32
# 114/114 [==============================] - 0s 2ms/step - loss: 51528.2422
# Epoch 4/32
# 114/114 [==============================] - 0s 1ms/step - loss: 7373.2656
# Epoch 5/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6806.5483
# Epoch 6/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6804.5024
# Epoch 7/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6802.5010
# Epoch 8/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6804.3481
# Epoch 9/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6804.8779
# Epoch 10/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6803.6836
# Epoch 11/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6804.4243
# Epoch 12/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6801.8022
# Epoch 13/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6804.8140
# Epoch 14/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6802.1411
# Epoch 15/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6807.3296
# Epoch 16/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6805.8281
# Epoch 17/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6802.3501
# Epoch 18/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6804.1328
# Epoch 19/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6807.2832
# Epoch 20/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6808.2251
# Epoch 21/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6802.4756
# Epoch 22/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6796.8882
# Epoch 23/32
# 114/114 [==============================] - 0s 1ms/step - loss: 6804.5913
# Epoch 24/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6801.0903
# Epoch 25/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6796.2627
# Epoch 26/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6796.3105
# Epoch 27/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6796.0986
# Epoch 28/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6798.4150
# Epoch 29/32
# 114/114 [==============================] - 0s 3ms/step - loss: 6789.3521
# Epoch 30/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6800.8940
# Epoch 31/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6798.8477
# Epoch 32/32
# 114/114 [==============================] - 0s 2ms/step - loss: 6807.3467

# %%
#tạo testing data set
test_data = scaler_data[train_size - n_lag: , :]
x_test = []
y_test = data_with_lagged.iloc[train_size:, :2]

for i in range(n_lag, len(test_data)):
  x_test.append(test_data[i-n_lag:i, :])

x_test = np.asarray(x_test)
print(x_test.shape, y_test.shape)
# Out:
# (1610, 7, 2) (1610, 2)

# %%
#get the models predicted price value
lstm_test_predictions = lstm_model.predict(x_test)
gru_test_predictions = gru_model.predict(x_test)

lstm_test_predictions = xscaler.inverse_transform(lstm_test_predictions)
gru_test_predictions = xscaler.inverse_transform(gru_test_predictions)

stacking_close_predictions = stacking_model.predict(column_stack((lstm_test_predictions, gru_test_predictions)))

# stacking_close_predictions = xscaler.inverse_transform(stacking_close_predictions)

stacking_close_predictions.shape
# Out:
# 51/51 [==============================] - 0s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# 51/51 [==============================] - 0s 1ms/step
# (1610, 2)

# %%
#sai số
mse = (((y_test - stacking_close_predictions)**2).mean())
mae = np.abs((y_test - stacking_close_predictions).mean())
mape = np.mean(np.abs((y_test - stacking_close_predictions) / y_test)) * 100
smape = (100 / len(y_test)) * np.sum(2 * np.abs(stacking_close_predictions - y_test) / (np.abs(stacking_close_predictions) + np.abs(y_test)))
print(mse["Close"], mae["Close"], mape["Close"], smape["Close"])
# Out:
# 10761.438389761708 39.85442248156057 0.7934258866262713 0.797254598513918
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#
valid = data_with_lagged[train_size:]
valid['Predictions'] = stacking_close_predictions[:, 1]
valid['LSTM'] = lstm_test_predictions[:, 1]
valid['GRU'] = gru_test_predictions[:, 1]

#hiển thị dữ liệu gần đây
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Giá (USD)', fontsize=18)
plt.plot(valid[['Close','Predictions','LSTM', 'GRU']])
plt.legend(['Val', 'Predictions', 'LSTM', 'GRU'], loc='lower right')
plt.show()
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_18772\653746799.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = stacking_close_predictions[:, 1]
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_18772\653746799.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['LSTM'] = lstm_test_predictions[:, 1]
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_18772\653746799.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['GRU'] = gru_test_predictions[:, 1]

# %%
#create file if it does not exist
data = {
    'Model': 'SE',
    'Thông tin': ['MAE', 'MSE', 'MAPE', 'sMAPE'],
    'Price': [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]
}
result_table = pd.DataFrame(data)
result_table.to_csv("result-hours.csv", index=False)
result_table
# Out:
#   Model Thông tin         Price
# 0    SE       MAE     39.854422
# 1    SE       MSE  10761.438390
# 2    SE      MAPE      0.793426
# 3    SE     sMAPE      0.797255
