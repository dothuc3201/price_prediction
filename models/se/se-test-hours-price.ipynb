# %%
#imports các thư viện
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle
from sklearn.model_selection import KFold

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat


import keras.utils
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Input, concatenate, Dense
from keras.layers import LSTM, GRU
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
def rsi(data, period: int = 14):

    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity (độ trễ) - days or hours
lag_granularity = "hours"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "hour"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/" + \
    analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_" + \
    str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename, index_col='DateTime', parse_dates=True)

# %%
#group by datetime
df = df.groupby('DateTime').agg(lambda x: x.mean())
df
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17400\3489936249.py:2: FutureWarning: ['dt'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df = df.groupby('DateTime').agg(lambda x: x.mean())
#                              Close  Volume_(BTC)  Weighted_Price   neg_pol  \
# DateTime
# 2018-08-31 10:00:00+00:00  6949.40      2.333380     6948.996140  0.040167
# 2018-08-31 11:00:00+00:00  6946.06      2.430317     6948.538492  0.020167
# 2018-08-31 12:00:00+00:00  6963.30      3.922626     6964.052374  0.035800
# 2018-08-31 13:00:00+00:00  6900.00      9.040247     6932.162091  0.084000
# 2018-08-31 14:00:00+00:00  6927.92      5.947736     6912.448529  0.025333
# ...                            ...           ...             ...       ...
# 2019-11-23 11:00:00+00:00  7180.02      6.622678     7190.277423  0.067410
# 2019-11-23 12:00:00+00:00  7157.47      7.074875     7181.956969  0.072038
# 2019-11-23 13:00:00+00:00  7181.50      9.766378     7171.704462  0.072152
# 2019-11-23 14:00:00+00:00  7260.77      6.143298     7231.168406  0.064122
# 2019-11-23 15:00:00+00:00  7292.72      2.660796     7272.018586  0.063931
#
#                             neu_pol   pos_pol  compound  Tweet_vol
# DateTime
# 2018-08-31 10:00:00+00:00  0.876000  0.083833  0.155633       18.0
# 2018-08-31 11:00:00+00:00  0.865000  0.114833  0.246883       37.0
# 2018-08-31 12:00:00+00:00  0.839600  0.124600  0.254660       42.0
# 2018-08-31 13:00:00+00:00  0.789250  0.126917  0.218183       55.0
# 2018-08-31 14:00:00+00:00  0.861444  0.113222  0.263544       38.0
# ...                             ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00  0.760387  0.172199  0.250681     2304.0
# 2019-11-23 12:00:00+00:00  0.751780  0.176183  0.235377     2467.0
# 2019-11-23 13:00:00+00:00  0.756339  0.171514  0.245202     2612.0
# 2019-11-23 14:00:00+00:00  0.755714  0.180162  0.269456     2676.0
# 2019-11-23 15:00:00+00:00  0.754940  0.181127  0.254060     2271.0
#
# [10781 rows x 8 columns]

# %%
#tính toán các chỉ số indicator: rsi, ma
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = True
add_longMAvg = True
add_shortMAvg = True

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()

if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17400\259356298.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17400\259356298.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity', 'Tweet_vol', 'Volume_(BTC)'] if analyser == "Textblob" else [
    'Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")

if(add_longMAvg):
    features.append("long_mavg")

if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
data_with_lagged = df_copy.dropna()
data_with_lagged
# Out:
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2018-09-01 21:00:00+00:00       0  7195.95  0.070500  0.019000       30.0
# 2018-09-01 22:00:00+00:00       0  7187.23  0.073000  0.073833       37.0
# 2018-09-01 23:00:00+00:00       1  7189.90  0.152250  0.032000       30.0
# 2018-09-02 00:00:00+00:00       1  7197.50  0.063333  0.040333       31.0
# 2018-09-02 01:00:00+00:00       0  7159.99  0.233667  0.000000       18.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI    long_mavg   short_mavg
# DateTime
# 2018-09-01 21:00:00+00:00  65.930409  7097.183810  7156.526667
# 2018-09-01 22:00:00+00:00  64.172838  7104.425238  7173.410000
# 2018-09-01 23:00:00+00:00  64.485028  7111.765714  7188.968889
# 2018-09-02 00:00:00+00:00  65.408993  7119.059048  7197.981111
# 2018-09-02 01:00:00+00:00  57.462959  7123.820476  7196.502222
# ...                              ...          ...          ...
# 2019-11-23 11:00:00+00:00  39.929000  7223.752857  7204.497778
# 2019-11-23 12:00:00+00:00  38.084247  7225.775238  7190.205556
# 2019-11-23 13:00:00+00:00  41.201744  7228.573810  7185.751111
# 2019-11-23 14:00:00+00:00  50.123331  7233.933810  7189.787778
# 2019-11-23 15:00:00+00:00  53.205251  7236.630476  7196.947778
#
# [10727 rows x 8 columns]

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)

data_hours = data_with_lagged.iloc[:, :2].reset_index().drop(['DateTime'], axis=1)

train = data_with_lagged.iloc[:train_size, :2]
train = train.reset_index()
train = train.drop(['DateTime'], axis=1)

train
# Out:
#       Change     Close
# 0          0   7195.95
# 1          0   7187.23
# 2          1   7189.90
# 3          1   7197.50
# 4          0   7159.99
# ...      ...       ...
# 9112       0  10168.00
# 9113       0  10153.97
# 9114       1  10168.54
# 9115       0  10159.50
# 9116       1  10208.42
#
# [9117 rows x 2 columns]

# %%
#chuẩn hóa
xscaler = MinMaxScaler(feature_range=(0, 1))
train = xscaler.fit_transform(train)
scaler_data = xscaler.transform(data_hours)
# scaler_data = data_with_lagged
print(train.shape, scaler_data.shape)
# Out:
# (9117, 2) (10727, 2)

# %%
X_train = []
y_train = []

for i in range(n_lag, len(train)):
  X_train.append(train[i-n_lag:i, :])
  y_train.append(train[i, :])

X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

print(X_train.shape, y_train.shape)
# Out:
# (9110, 7, 2) (9110, 2)

# %%
# design network
neurons = 64
epochs = 32
dropout = 0.25
batch_size = 80
activ_func = "relu"

# %%
# early stopping callback
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =20)

# %%
# Số fold
k = 5
kf = KFold(n_splits=k, shuffle=False)

# List để lưu kết quả dự đoán từ LSTM và GRU
lstm_predictions = []
gru_predictions = []

# Xây dựng mô hình stacking
for train_index, test_index in kf.split(X_train):
    X_sub_train, X_sub_test = X_train[train_index], X_train[test_index]
    y_sub_train, y_sub_test = y_train[train_index], y_train[test_index]
    # Xây dựng mô hình LSTM và huấn luyện
    lstm_model = Sequential()
    lstm_model.add(LSTM(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    lstm_model.add(LSTM(neurons, return_sequences=False))
    lstm_model.add(Dense(2))
    lstm_model.compile(optimizer='adam', loss='mean_squared_error')

    # Xây dựng mô hình GRU và huấn luyện
    gru_model = Sequential()
    gru_model.add(GRU(neurons, return_sequences=True, input_shape=(
        X_train.shape[1], X_train.shape[2]), activation=activ_func))
    gru_model.add(GRU(neurons, return_sequences=False))
    gru_model.add(Dense(2))
    gru_model.compile(optimizer='adam', loss='mean_squared_error')
    
    lstm_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    gru_model.fit(X_sub_train, y_sub_train, epochs=epochs, batch_size=batch_size)

    # Lấy đầu ra của mô hình LSTM và GRU
    lstm_output = lstm_model.predict(X_sub_test)
    gru_output = gru_model.predict(X_sub_test)
    
    lstm_predictions.append(lstm_output)
    gru_predictions.append(gru_output)
# Out:
# Epoch 1/32
# 73/73 - 5s - loss: 0.1494 - val_loss: 0.1253 - 5s/epoch - 71ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1251 - val_loss: 0.1287 - 1s/epoch - 20ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1245 - val_loss: 0.1254 - 921ms/epoch - 13ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1246 - val_loss: 0.1256 - 666ms/epoch - 9ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1243 - val_loss: 0.1250 - 680ms/epoch - 9ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1239 - val_loss: 0.1252 - 686ms/epoch - 9ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1242 - val_loss: 0.1259 - 724ms/epoch - 10ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1240 - val_loss: 0.1248 - 668ms/epoch - 9ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1259 - 710ms/epoch - 10ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1244 - 695ms/epoch - 10ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1244 - 697ms/epoch - 10ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1243 - 685ms/epoch - 9ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1243 - 971ms/epoch - 13ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1247 - 963ms/epoch - 13ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1243 - 857ms/epoch - 12ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1261 - 1s/epoch - 19ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1266 - 1s/epoch - 15ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1242 - 875ms/epoch - 12ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1252 - 1s/epoch - 16ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1253 - 823ms/epoch - 11ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1252 - 801ms/epoch - 11ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1246 - 826ms/epoch - 11ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1243 - 825ms/epoch - 11ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1252 - 819ms/epoch - 11ms/step
# Epoch 25/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1243 - 809ms/epoch - 11ms/step
# Epoch 26/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1243 - 908ms/epoch - 12ms/step
# Epoch 27/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1260 - 786ms/epoch - 11ms/step
# Epoch 28/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1243 - 803ms/epoch - 11ms/step
# Epoch 29/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1243 - 850ms/epoch - 12ms/step
# Epoch 30/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1243 - 799ms/epoch - 11ms/step
# Epoch 31/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1255 - 812ms/epoch - 11ms/step
# Epoch 32/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1247 - 808ms/epoch - 11ms/step
# Epoch 1/32
# 73/73 - 4s - loss: 0.1450 - val_loss: 0.1253 - 4s/epoch - 59ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1241 - val_loss: 0.1245 - 704ms/epoch - 10ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1237 - val_loss: 0.1247 - 752ms/epoch - 10ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1249 - 738ms/epoch - 10ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1244 - 729ms/epoch - 10ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1255 - 742ms/epoch - 10ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1243 - 733ms/epoch - 10ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1246 - 743ms/epoch - 10ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1241 - val_loss: 0.1247 - 743ms/epoch - 10ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1243 - 740ms/epoch - 10ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1257 - 800ms/epoch - 11ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1268 - 805ms/epoch - 11ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1244 - val_loss: 0.1246 - 778ms/epoch - 11ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1245 - 733ms/epoch - 10ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1249 - 751ms/epoch - 10ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1244 - 750ms/epoch - 10ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1252 - 741ms/epoch - 10ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1246 - 757ms/epoch - 10ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1244 - 742ms/epoch - 10ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1245 - 740ms/epoch - 10ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1244 - 741ms/epoch - 10ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1243 - 758ms/epoch - 10ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1252 - 774ms/epoch - 11ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1246 - 814ms/epoch - 11ms/step
# Epoch 25/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1247 - 733ms/epoch - 10ms/step
# Epoch 26/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1258 - 747ms/epoch - 10ms/step
# Epoch 27/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1254 - 733ms/epoch - 10ms/step
# Epoch 28/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1243 - 730ms/epoch - 10ms/step
# Epoch 29/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1265 - 722ms/epoch - 10ms/step
# Epoch 30/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1244 - 807ms/epoch - 11ms/step
# Epoch 31/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1248 - 743ms/epoch - 10ms/step
# Epoch 32/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1256 - 737ms/epoch - 10ms/step
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 73/73 - 4s - loss: 0.1597 - val_loss: 0.1283 - 4s/epoch - 57ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1252 - val_loss: 0.1286 - 761ms/epoch - 10ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1249 - val_loss: 0.1252 - 814ms/epoch - 11ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1244 - val_loss: 0.1252 - 797ms/epoch - 11ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1250 - val_loss: 0.1259 - 805ms/epoch - 11ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1247 - val_loss: 0.1277 - 803ms/epoch - 11ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1243 - val_loss: 0.1248 - 803ms/epoch - 11ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1248 - 794ms/epoch - 11ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1237 - val_loss: 0.1251 - 796ms/epoch - 11ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1252 - 853ms/epoch - 12ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1240 - val_loss: 0.1251 - 838ms/epoch - 11ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1244 - 889ms/epoch - 12ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1251 - 870ms/epoch - 12ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1245 - 862ms/epoch - 12ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1245 - 854ms/epoch - 12ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1251 - 834ms/epoch - 11ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1244 - 845ms/epoch - 12ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1251 - 854ms/epoch - 12ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1242 - 866ms/epoch - 12ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1246 - 854ms/epoch - 12ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1245 - 885ms/epoch - 12ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1241 - 878ms/epoch - 12ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1237 - val_loss: 0.1242 - 798ms/epoch - 11ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1244 - 803ms/epoch - 11ms/step
# Epoch 25/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1245 - 793ms/epoch - 11ms/step
# Epoch 26/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1249 - 836ms/epoch - 11ms/step
# Epoch 27/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1244 - 783ms/epoch - 11ms/step
# Epoch 28/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1243 - 879ms/epoch - 12ms/step
# Epoch 29/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1242 - 862ms/epoch - 12ms/step
# Epoch 30/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1246 - 880ms/epoch - 12ms/step
# Epoch 31/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1244 - 919ms/epoch - 13ms/step
# Epoch 32/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1242 - 914ms/epoch - 13ms/step
# Epoch 1/32
# 73/73 - 5s - loss: 0.1464 - val_loss: 0.1285 - 5s/epoch - 72ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1275 - 1s/epoch - 14ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1240 - val_loss: 0.1252 - 882ms/epoch - 12ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1242 - val_loss: 0.1259 - 905ms/epoch - 12ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1242 - val_loss: 0.1253 - 919ms/epoch - 13ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1241 - 777ms/epoch - 11ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1256 - 762ms/epoch - 10ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1239 - val_loss: 0.1245 - 766ms/epoch - 10ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1242 - 750ms/epoch - 10ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1240 - val_loss: 0.1241 - 751ms/epoch - 10ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1240 - 751ms/epoch - 10ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1264 - 748ms/epoch - 10ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1240 - 782ms/epoch - 11ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1241 - 767ms/epoch - 11ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1249 - 764ms/epoch - 10ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1242 - val_loss: 0.1244 - 768ms/epoch - 11ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1241 - 798ms/epoch - 11ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1241 - 797ms/epoch - 11ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1243 - 734ms/epoch - 10ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1237 - val_loss: 0.1246 - 747ms/epoch - 10ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1275 - 752ms/epoch - 10ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1237 - val_loss: 0.1240 - 785ms/epoch - 11ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1241 - val_loss: 0.1241 - 739ms/epoch - 10ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1240 - 790ms/epoch - 11ms/step
# Epoch 25/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1256 - 824ms/epoch - 11ms/step
# Epoch 26/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1248 - 760ms/epoch - 10ms/step
# Epoch 27/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1241 - 746ms/epoch - 10ms/step
# Epoch 28/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1242 - 811ms/epoch - 11ms/step
# Epoch 29/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1252 - 763ms/epoch - 10ms/step
# Epoch 30/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1240 - 733ms/epoch - 10ms/step
# Epoch 31/32
# 73/73 - 1s - loss: 0.1240 - val_loss: 0.1243 - 750ms/epoch - 10ms/step
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 73/73 - 5s - loss: 0.1502 - val_loss: 0.1265 - 5s/epoch - 64ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1255 - val_loss: 0.1264 - 1s/epoch - 18ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1248 - val_loss: 0.1256 - 971ms/epoch - 13ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1246 - val_loss: 0.1262 - 931ms/epoch - 13ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1246 - val_loss: 0.1250 - 1s/epoch - 15ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1249 - val_loss: 0.1259 - 841ms/epoch - 12ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1240 - val_loss: 0.1271 - 879ms/epoch - 12ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1243 - val_loss: 0.1250 - 820ms/epoch - 11ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1239 - val_loss: 0.1245 - 839ms/epoch - 11ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1240 - val_loss: 0.1262 - 829ms/epoch - 11ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1242 - 837ms/epoch - 11ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1246 - 822ms/epoch - 11ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1239 - val_loss: 0.1244 - 847ms/epoch - 12ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1242 - 843ms/epoch - 12ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1274 - 858ms/epoch - 12ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1246 - 858ms/epoch - 12ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1241 - 829ms/epoch - 11ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1237 - val_loss: 0.1240 - 832ms/epoch - 11ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1249 - 828ms/epoch - 11ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1241 - 828ms/epoch - 11ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1241 - 841ms/epoch - 12ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1242 - 838ms/epoch - 11ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1241 - 813ms/epoch - 11ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1246 - 827ms/epoch - 11ms/step
# Epoch 25/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1240 - 830ms/epoch - 11ms/step
# Epoch 26/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1250 - 821ms/epoch - 11ms/step
# Epoch 27/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1282 - 853ms/epoch - 12ms/step
# Epoch 28/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1249 - 839ms/epoch - 11ms/step
# Epoch 29/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1244 - 818ms/epoch - 11ms/step
# Epoch 30/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1247 - 837ms/epoch - 11ms/step
# Epoch 31/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1241 - 810ms/epoch - 11ms/step
# Epoch 32/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1241 - 820ms/epoch - 11ms/step
# Epoch 1/32
# 73/73 - 4s - loss: 0.1498 - val_loss: 0.1250 - 4s/epoch - 60ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1242 - val_loss: 0.1246 - 723ms/epoch - 10ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1244 - 779ms/epoch - 11ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1240 - 757ms/epoch - 10ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1237 - val_loss: 0.1255 - 762ms/epoch - 10ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1243 - 779ms/epoch - 11ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1240 - val_loss: 0.1246 - 775ms/epoch - 11ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1250 - 745ms/epoch - 10ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1243 - 741ms/epoch - 10ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1274 - 742ms/epoch - 10ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1241 - 755ms/epoch - 10ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1242 - 755ms/epoch - 10ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1263 - 783ms/epoch - 11ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1237 - val_loss: 0.1242 - 742ms/epoch - 10ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1240 - 755ms/epoch - 10ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1242 - 776ms/epoch - 11ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1240 - 779ms/epoch - 11ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1253 - 766ms/epoch - 10ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1240 - 775ms/epoch - 11ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1240 - 768ms/epoch - 11ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1241 - 757ms/epoch - 10ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1241 - 757ms/epoch - 10ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1242 - 752ms/epoch - 10ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1242 - 756ms/epoch - 10ms/step
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 73/73 - 4s - loss: 0.1491 - val_loss: 0.1266 - 4s/epoch - 59ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1252 - val_loss: 0.1263 - 793ms/epoch - 11ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1245 - val_loss: 0.1287 - 821ms/epoch - 11ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1246 - val_loss: 0.1253 - 816ms/epoch - 11ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1245 - val_loss: 0.1256 - 832ms/epoch - 11ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1271 - 828ms/epoch - 11ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1241 - val_loss: 0.1247 - 832ms/epoch - 11ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1264 - 809ms/epoch - 11ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1250 - 814ms/epoch - 11ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1272 - 825ms/epoch - 11ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1245 - 817ms/epoch - 11ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1247 - 812ms/epoch - 11ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1240 - 814ms/epoch - 11ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1239 - 877ms/epoch - 12ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1241 - 809ms/epoch - 11ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1240 - 815ms/epoch - 11ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1241 - 814ms/epoch - 11ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1246 - 793ms/epoch - 11ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1226 - val_loss: 0.1243 - 807ms/epoch - 11ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1242 - 795ms/epoch - 11ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1239 - 838ms/epoch - 11ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1240 - 812ms/epoch - 11ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1247 - 802ms/epoch - 11ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1256 - 815ms/epoch - 11ms/step
# Epoch 25/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1242 - 803ms/epoch - 11ms/step
# Epoch 26/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1241 - 811ms/epoch - 11ms/step
# Epoch 27/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1254 - 937ms/epoch - 13ms/step
# Epoch 28/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1247 - 816ms/epoch - 11ms/step
# Epoch 29/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1258 - 820ms/epoch - 11ms/step
# Epoch 30/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1240 - 801ms/epoch - 11ms/step
# Epoch 31/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1239 - 811ms/epoch - 11ms/step
# Epoch 32/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1249 - 841ms/epoch - 12ms/step
# Epoch 1/32
# 73/73 - 4s - loss: 0.1423 - val_loss: 0.1253 - 4s/epoch - 60ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1238 - val_loss: 0.1255 - 705ms/epoch - 10ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1252 - 775ms/epoch - 11ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1246 - 795ms/epoch - 11ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1241 - 816ms/epoch - 11ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1242 - 747ms/epoch - 10ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1240 - 759ms/epoch - 10ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1242 - 774ms/epoch - 11ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1242 - 768ms/epoch - 11ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1234 - val_loss: 0.1240 - 763ms/epoch - 10ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1240 - 775ms/epoch - 11ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1241 - 757ms/epoch - 10ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1249 - 802ms/epoch - 11ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1226 - val_loss: 0.1253 - 786ms/epoch - 11ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1240 - 770ms/epoch - 11ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1251 - 802ms/epoch - 11ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1240 - 795ms/epoch - 11ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1258 - 879ms/epoch - 12ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1224 - val_loss: 0.1241 - 799ms/epoch - 11ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1264 - 755ms/epoch - 10ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1252 - 763ms/epoch - 10ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1255 - 749ms/epoch - 10ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1256 - 750ms/epoch - 10ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1240 - 750ms/epoch - 10ms/step
# Epoch 25/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1240 - 767ms/epoch - 11ms/step
# Epoch 26/32
# 73/73 - 1s - loss: 0.1225 - val_loss: 0.1251 - 772ms/epoch - 11ms/step
# Epoch 27/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1252 - 743ms/epoch - 10ms/step
# Epoch 28/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1241 - 761ms/epoch - 10ms/step
# Epoch 29/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1242 - 778ms/epoch - 11ms/step
# Epoch 30/32
# 73/73 - 1s - loss: 0.1226 - val_loss: 0.1252 - 773ms/epoch - 11ms/step
# Epoch 31/32
# 73/73 - 1s - loss: 0.1226 - val_loss: 0.1239 - 793ms/epoch - 11ms/step
# Epoch 32/32
# 73/73 - 1s - loss: 0.1226 - val_loss: 0.1242 - 768ms/epoch - 11ms/step
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 3ms/step
# Epoch 1/32
# 73/73 - 5s - loss: 0.1444 - val_loss: 0.1306 - 5s/epoch - 70ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1248 - val_loss: 0.1244 - 718ms/epoch - 10ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1245 - val_loss: 0.1244 - 798ms/epoch - 11ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1247 - val_loss: 0.1258 - 890ms/epoch - 12ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1239 - val_loss: 0.1240 - 876ms/epoch - 12ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1241 - val_loss: 0.1240 - 833ms/epoch - 11ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1235 - val_loss: 0.1249 - 831ms/epoch - 11ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1238 - 841ms/epoch - 12ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1249 - 897ms/epoch - 12ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1282 - 843ms/epoch - 12ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1245 - 825ms/epoch - 11ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1258 - 903ms/epoch - 12ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1269 - 843ms/epoch - 12ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1254 - 811ms/epoch - 11ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1262 - 832ms/epoch - 11ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1240 - 827ms/epoch - 11ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1244 - 827ms/epoch - 11ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1249 - 865ms/epoch - 12ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1269 - 840ms/epoch - 12ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1244 - 837ms/epoch - 11ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1260 - 811ms/epoch - 11ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1261 - 828ms/epoch - 11ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1245 - 838ms/epoch - 11ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1251 - 845ms/epoch - 12ms/step
# Epoch 25/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1267 - 835ms/epoch - 11ms/step
# Epoch 26/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1245 - 837ms/epoch - 11ms/step
# Epoch 27/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1260 - 848ms/epoch - 12ms/step
# Epoch 28/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1258 - 846ms/epoch - 12ms/step
# Epoch 1/32
# 73/73 - 4s - loss: 0.1393 - val_loss: 0.1260 - 4s/epoch - 60ms/step
# Epoch 2/32
# 73/73 - 1s - loss: 0.1246 - val_loss: 0.1275 - 745ms/epoch - 10ms/step
# Epoch 3/32
# 73/73 - 1s - loss: 0.1239 - val_loss: 0.1259 - 788ms/epoch - 11ms/step
# Epoch 4/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1265 - 780ms/epoch - 11ms/step
# Epoch 5/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1253 - 769ms/epoch - 11ms/step
# Epoch 6/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1270 - 786ms/epoch - 11ms/step
# Epoch 7/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1254 - 758ms/epoch - 10ms/step
# Epoch 8/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1258 - 796ms/epoch - 11ms/step
# Epoch 9/32
# 73/73 - 1s - loss: 0.1236 - val_loss: 0.1255 - 836ms/epoch - 11ms/step
# Epoch 10/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1269 - 775ms/epoch - 11ms/step
# Epoch 11/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1295 - 781ms/epoch - 11ms/step
# Epoch 12/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1258 - 784ms/epoch - 11ms/step
# Epoch 13/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1255 - 786ms/epoch - 11ms/step
# Epoch 14/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1251 - 765ms/epoch - 10ms/step
# Epoch 15/32
# 73/73 - 1s - loss: 0.1232 - val_loss: 0.1260 - 780ms/epoch - 11ms/step
# Epoch 16/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1250 - 784ms/epoch - 11ms/step
# Epoch 17/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1254 - 768ms/epoch - 11ms/step
# Epoch 18/32
# 73/73 - 1s - loss: 0.1231 - val_loss: 0.1253 - 788ms/epoch - 11ms/step
# Epoch 19/32
# 73/73 - 1s - loss: 0.1230 - val_loss: 0.1260 - 763ms/epoch - 10ms/step
# Epoch 20/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1249 - 773ms/epoch - 11ms/step
# Epoch 21/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1259 - 777ms/epoch - 11ms/step
# Epoch 22/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1250 - 804ms/epoch - 11ms/step
# Epoch 23/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1249 - 785ms/epoch - 11ms/step
# Epoch 24/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1255 - 798ms/epoch - 11ms/step
# Epoch 25/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1252 - 790ms/epoch - 11ms/step
# Epoch 26/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1263 - 780ms/epoch - 11ms/step
# Epoch 27/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1254 - 781ms/epoch - 11ms/step
# Epoch 28/32
# 73/73 - 1s - loss: 0.1233 - val_loss: 0.1252 - 779ms/epoch - 11ms/step
# Epoch 29/32
# 73/73 - 1s - loss: 0.1229 - val_loss: 0.1251 - 759ms/epoch - 10ms/step
# Epoch 30/32
# 73/73 - 1s - loss: 0.1228 - val_loss: 0.1259 - 768ms/epoch - 11ms/step
# Epoch 31/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1271 - 781ms/epoch - 11ms/step
# Epoch 32/32
# 73/73 - 1s - loss: 0.1227 - val_loss: 0.1254 - 752ms/epoch - 10ms/step
# 57/57 [==============================] - 1s 3ms/step
# 57/57 [==============================] - 1s 4ms/step

# %%
type(lstm_predictions)
# Out:
# list

# %%
# Lấy đầu ra của LSTM và GRU
lstm_outputs = np.concatenate(lstm_predictions, axis=0)
gru_outputs = np.concatenate(gru_predictions, axis=0)

# %%
from numpy import column_stack

lstm_outputs = xscaler.inverse_transform(lstm_outputs)
gru_outputs = xscaler.inverse_transform(gru_outputs)

y_train = xscaler.inverse_transform(y_train)

stacking_inputs = column_stack((lstm_outputs, gru_outputs))

# %%
print(stacking_inputs[:, 1], y_train[:, 1])
stacking_inputs
# Out:
# [7207.9053 7247.0146 7275.7544 ... 9831.794  9692.781  9696.692 ] [ 7183.12  7208.98  7230.99 ... 10168.54 10159.5  10208.42]
# array([[5.2224147e-01, 7.2079053e+03, 5.4091805e-01, 7.1805942e+03],
#        [4.7578603e-01, 7.2470146e+03, 4.9469048e-01, 7.2100894e+03],
#        [4.5565447e-01, 7.2757544e+03, 4.7609264e-01, 7.2145063e+03],
#        ...,
#        [5.4382491e-01, 9.8317939e+03, 6.0847634e-01, 9.5064971e+03],
#        [4.5683956e-01, 9.6927812e+03, 5.2059603e-01, 9.4738252e+03],
#        [4.9993119e-01, 9.6966924e+03, 5.6009567e-01, 9.5179004e+03]],
#       dtype=float32)

# %%
stacking_model = Sequential()
stacking_model.add(Dense(4, input_shape=(stacking_inputs.shape[1],)))
stacking_model.add(Dense(2, activation='linear'))
stacking_model.compile(optimizer='adam', loss='mean_squared_error')

# Train stacking model
stacking_model.fit(stacking_inputs, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/32
# 114/114 [==============================] - 1s 1ms/step - loss: 1381251.2500
# Epoch 2/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34598.2500
# Epoch 3/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34418.4570
# Epoch 4/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34397.0039
# Epoch 5/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34344.8828
# Epoch 6/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34311.3945
# Epoch 7/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34267.8828
# Epoch 8/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34235.1328
# Epoch 9/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34162.1875
# Epoch 10/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34110.6250
# Epoch 11/32
# 114/114 [==============================] - 0s 1ms/step - loss: 34023.7422
# Epoch 12/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33973.9570
# Epoch 13/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33904.5820
# Epoch 14/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33831.8789
# Epoch 15/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33797.5000
# Epoch 16/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33666.2539
# Epoch 17/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33589.9258
# Epoch 18/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33445.3672
# Epoch 19/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33353.7500
# Epoch 20/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33215.6367
# Epoch 21/32
# 114/114 [==============================] - 0s 1ms/step - loss: 33085.3438
# Epoch 22/32
# 114/114 [==============================] - 0s 1ms/step - loss: 32973.1602
# Epoch 23/32
# 114/114 [==============================] - 0s 1ms/step - loss: 32816.3828
# Epoch 24/32
# 114/114 [==============================] - 0s 1ms/step - loss: 32793.8789
# Epoch 25/32
# 114/114 [==============================] - 0s 1ms/step - loss: 32636.3125
# Epoch 26/32
# 114/114 [==============================] - 0s 1ms/step - loss: 32427.6582
# Epoch 27/32
# 114/114 [==============================] - 0s 1ms/step - loss: 32242.6348
# Epoch 28/32
# 114/114 [==============================] - 0s 1ms/step - loss: 32237.3027
# Epoch 29/32
# 114/114 [==============================] - 0s 1ms/step - loss: 32081.5449
# Epoch 30/32
# 114/114 [==============================] - 0s 1ms/step - loss: 31878.9551
# Epoch 31/32
# 114/114 [==============================] - 0s 1ms/step - loss: 31668.4297
# Epoch 32/32
# 114/114 [==============================] - 0s 1ms/step - loss: 31528.5879

# %%
#tạo testing data set
test_data = scaler_data[train_size - n_lag: , :]
x_test = []
y_test = data_with_lagged.iloc[train_size:, :2]

for i in range(n_lag, len(test_data)):
  x_test.append(test_data[i-n_lag:i, :])

x_test = np.asarray(x_test)
print(x_test.shape, y_test.shape)
# Out:
# (1610, 7, 2) (1610, 2)

# %%
#get the models predicted price value
lstm_test_predictions = lstm_model.predict(x_test)
gru_test_predictions = gru_model.predict(x_test)

lstm_test_predictions = xscaler.inverse_transform(lstm_test_predictions)
gru_test_predictions = xscaler.inverse_transform(gru_test_predictions)

stacking_close_predictions = stacking_model.predict(column_stack((lstm_test_predictions, gru_test_predictions)))

# stacking_close_predictions = xscaler.inverse_transform(stacking_close_predictions)

stacking_close_predictions.shape
# Out:
# 51/51 [==============================] - 0s 5ms/step
# 51/51 [==============================] - 0s 3ms/step
# 51/51 [==============================] - 0s 1ms/step
# (1610, 2)

# %%
#sai số
mse = (((y_test - stacking_close_predictions)**2).mean())
mae = np.abs((y_test - stacking_close_predictions).mean())
mape = np.mean(np.abs((y_test - stacking_close_predictions) / y_test)) * 100
smape = (100 / len(y_test)) * np.sum(2 * np.abs(stacking_close_predictions - y_test) / (np.abs(stacking_close_predictions) + np.abs(y_test)))
print(mse["Close"], mae["Close"], mape["Close"], smape["Close"])
# Out:
# 25516.312750559915 87.91755482094335 1.3096752714304776 1.321273371436694
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#
valid = data_with_lagged[train_size:]
valid['Predictions'] = stacking_close_predictions[:, 1]
valid['LSTM'] = lstm_test_predictions[:, 1]
valid['GRU'] = gru_test_predictions[:, 1]

#hiển thị dữ liệu gần đây
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Giá (USD)', fontsize=18)
plt.plot(valid[['Close','Predictions','LSTM', 'GRU']])
plt.legend(['Val', 'Predictions', 'LSTM', 'GRU'], loc='lower right')
plt.show()
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17400\653746799.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = stacking_close_predictions[:, 1]
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17400\653746799.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['LSTM'] = lstm_test_predictions[:, 1]
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17400\653746799.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['GRU'] = gru_test_predictions[:, 1]

# %%
#create file if it does not exist
data = {
    'Model': 'SE',
    'Thông tin': ['MAE', 'MSE', 'MAPE', 'sMAPE'],
    'Price': [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]
}
result_table = pd.DataFrame(data)
result_table.to_csv("result-hours.csv", index=False)
result_table
# Out:
#   Model Thông tin         Price
# 0    SE       MAE     87.917555
# 1    SE       MSE  25516.312751
# 2    SE      MAPE      1.309675
# 3    SE     sMAPE      1.321273
