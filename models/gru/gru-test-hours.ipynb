# %%
#imports các thư viện
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat


import keras.utils
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Dense
from keras.layers import GRU
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
def rsi(data, period: int = 14):

    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity (độ trễ) - days or hours
lag_granularity = "hours"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "hour"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/" + \
    analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_" + \
    str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename, index_col='DateTime', parse_dates=True)

# %%
#group by datetime
df = df.groupby('DateTime').agg(lambda x: x.mean())
df
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_6476\3489936249.py:2: FutureWarning: ['dt'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df = df.groupby('DateTime').agg(lambda x: x.mean())
#                              Close  Volume_(BTC)  Weighted_Price   neg_pol  \
# DateTime
# 2018-08-31 10:00:00+00:00  6949.40      2.333380     6948.996140  0.040167
# 2018-08-31 11:00:00+00:00  6946.06      2.430317     6948.538492  0.020167
# 2018-08-31 12:00:00+00:00  6963.30      3.922626     6964.052374  0.035800
# 2018-08-31 13:00:00+00:00  6900.00      9.040247     6932.162091  0.084000
# 2018-08-31 14:00:00+00:00  6927.92      5.947736     6912.448529  0.025333
# ...                            ...           ...             ...       ...
# 2019-11-23 11:00:00+00:00  7180.02      6.622678     7190.277423  0.067410
# 2019-11-23 12:00:00+00:00  7157.47      7.074875     7181.956969  0.072038
# 2019-11-23 13:00:00+00:00  7181.50      9.766378     7171.704462  0.072152
# 2019-11-23 14:00:00+00:00  7260.77      6.143298     7231.168406  0.064122
# 2019-11-23 15:00:00+00:00  7292.72      2.660796     7272.018586  0.063931
#
#                             neu_pol   pos_pol  compound  Tweet_vol
# DateTime
# 2018-08-31 10:00:00+00:00  0.876000  0.083833  0.155633       18.0
# 2018-08-31 11:00:00+00:00  0.865000  0.114833  0.246883       37.0
# 2018-08-31 12:00:00+00:00  0.839600  0.124600  0.254660       42.0
# 2018-08-31 13:00:00+00:00  0.789250  0.126917  0.218183       55.0
# 2018-08-31 14:00:00+00:00  0.861444  0.113222  0.263544       38.0
# ...                             ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00  0.760387  0.172199  0.250681     2304.0
# 2019-11-23 12:00:00+00:00  0.751780  0.176183  0.235377     2467.0
# 2019-11-23 13:00:00+00:00  0.756339  0.171514  0.245202     2612.0
# 2019-11-23 14:00:00+00:00  0.755714  0.180162  0.269456     2676.0
# 2019-11-23 15:00:00+00:00  0.754940  0.181127  0.254060     2271.0
#
# [10781 rows x 8 columns]

# %%
#tính toán các chỉ số indicator: rsi, ma
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = True
add_longMAvg = True
add_shortMAvg = True

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()

if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_6476\259356298.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_6476\259356298.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity', 'Tweet_vol', 'Volume_(BTC)'] if analyser == "Textblob" else [
    'Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")

if(add_longMAvg):
    features.append("long_mavg")

if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy().dropna()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
data_with_lagged = df_copy
data_with_lagged
# Out:
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2018-09-01 21:00:00+00:00       0  7195.95  0.070500  0.019000       30.0
# 2018-09-01 22:00:00+00:00       0  7187.23  0.073000  0.073833       37.0
# 2018-09-01 23:00:00+00:00       1  7189.90  0.152250  0.032000       30.0
# 2018-09-02 00:00:00+00:00       1  7197.50  0.063333  0.040333       31.0
# 2018-09-02 01:00:00+00:00       0  7159.99  0.233667  0.000000       18.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-23 11:00:00+00:00       1  7180.02  0.172199  0.067410     2304.0
# 2019-11-23 12:00:00+00:00       0  7157.47  0.176183  0.072038     2467.0
# 2019-11-23 13:00:00+00:00       1  7181.50  0.171514  0.072152     2612.0
# 2019-11-23 14:00:00+00:00       1  7260.77  0.180162  0.064122     2676.0
# 2019-11-23 15:00:00+00:00       1  7292.72  0.181127  0.063931     2271.0
#
#                                  RSI    long_mavg   short_mavg
# DateTime
# 2018-09-01 21:00:00+00:00  65.930409  7097.183810  7156.526667
# 2018-09-01 22:00:00+00:00  64.172838  7104.425238  7173.410000
# 2018-09-01 23:00:00+00:00  64.485028  7111.765714  7188.968889
# 2018-09-02 00:00:00+00:00  65.408993  7119.059048  7197.981111
# 2018-09-02 01:00:00+00:00  57.462959  7123.820476  7196.502222
# ...                              ...          ...          ...
# 2019-11-23 11:00:00+00:00  39.929000  7223.752857  7204.497778
# 2019-11-23 12:00:00+00:00  38.084247  7225.775238  7190.205556
# 2019-11-23 13:00:00+00:00  41.201744  7228.573810  7185.751111
# 2019-11-23 14:00:00+00:00  50.123331  7233.933810  7189.787778
# 2019-11-23 15:00:00+00:00  53.205251  7236.630476  7196.947778
#
# [10727 rows x 8 columns]

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)

train = data_with_lagged.iloc[:train_size]
train = train.reset_index()
train = train.drop(['DateTime'], axis=1)

train
# Out:
#       Change     Close   pos_pol   neg_pol  Tweet_vol        RSI  \
# 0          0   7195.95  0.070500  0.019000       30.0  65.930409
# 1          0   7187.23  0.073000  0.073833       37.0  64.172838
# 2          1   7189.90  0.152250  0.032000       30.0  64.485028
# 3          1   7197.50  0.063333  0.040333       31.0  65.408993
# 4          0   7159.99  0.233667  0.000000       18.0  57.462959
# ...      ...       ...       ...       ...        ...        ...
# 9112       0  10168.00  0.178109  0.082320     2790.0  40.532781
# 9113       0  10153.97  0.185682  0.075785     2765.0  38.801796
# 9114       1  10168.54  0.170748  0.071725     3092.0  41.591447
# 9115       0  10159.50  0.174339  0.061375     3405.0  40.362089
# 9116       1  10208.42  0.186011  0.074069     3264.0  49.125569
#
#          long_mavg    short_mavg
# 0      7097.183810   7156.526667
# 1      7104.425238   7173.410000
# 2      7111.765714   7188.968889
# 3      7119.059048   7197.981111
# 4      7123.820476   7196.502222
# ...            ...           ...
# 9112  10194.198095  10216.297778
# 9113  10194.863333  10208.506667
# 9114  10195.836190  10201.170000
# 9115  10197.285714  10192.781111
# 9116  10202.210476  10187.507778
#
# [9117 rows x 8 columns]

# %%
#chuẩn hóa
xscaler = MinMaxScaler(feature_range=(0, 1))
train = xscaler.fit_transform(train)
scaler_data = xscaler.transform(data_with_lagged)

print(train.shape, scaler_data.shape)
# Out:
# (9117, 8) (10727, 8)

# %%
X_train = []
y_train = []

for i in range(n_lag, len(train)):
  X_train.append(train[i-n_lag:i, :])
  y_train.append(train[i, :])

X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

print(y_train)
# Out:
# [[1.         0.37787558 0.2017744  ... 0.60415788 0.40742761 0.40210631]
#  [1.         0.38029309 0.31866739 ... 0.64211537 0.40815568 0.40154166]
#  [1.         0.38235069 0.32294043 ... 0.67143041 0.40903978 0.40192953]
#  ...
#  [1.         0.65696609 0.43282049 ... 0.39987978 0.72106686 0.70226333]
#  [0.         0.65612099 0.44192408 ... 0.38658505 0.7212157  0.70142758]
#  [1.         0.66069425 0.47151112 ... 0.48135652 0.72172138 0.70090222]]

# %%
# np.random.seed(1)
# tf.random.set_seed(1)

# design network
model_gru_hour_2 = Sequential()

neurons = 64
epochs = 50
dropout = 0.25
batch_size = 80
activ_func = "relu"

model_gru_hour_2.add(GRU(neurons, return_sequences=True, input_shape=(
    X_train.shape[1], X_train.shape[2]), activation=activ_func))
model_gru_hour_2.add(GRU(neurons, return_sequences=False))
model_gru_hour_2.add(Dense(8))
model_gru_hour_2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# early stopping callback
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =20)

# fit network
history = model_gru_hour_2.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=2, shuffle=True, validation_split=0.2,callbacks=[callback])
# Out:
# Epoch 1/50
# 92/92 - 5s - loss: 0.0489 - val_loss: 0.0338 - 5s/epoch - 57ms/step
# Epoch 2/50
# 92/92 - 1s - loss: 0.0353 - val_loss: 0.0325 - 920ms/epoch - 10ms/step
# Epoch 3/50
# 92/92 - 1s - loss: 0.0348 - val_loss: 0.0338 - 941ms/epoch - 10ms/step
# Epoch 4/50
# 92/92 - 1s - loss: 0.0349 - val_loss: 0.0327 - 931ms/epoch - 10ms/step
# Epoch 5/50
# 92/92 - 1s - loss: 0.0343 - val_loss: 0.0330 - 980ms/epoch - 11ms/step
# Epoch 6/50
# 92/92 - 1s - loss: 0.0346 - val_loss: 0.0321 - 929ms/epoch - 10ms/step
# Epoch 7/50
# 92/92 - 1s - loss: 0.0343 - val_loss: 0.0321 - 934ms/epoch - 10ms/step
# Epoch 8/50
# 92/92 - 1s - loss: 0.0344 - val_loss: 0.0320 - 931ms/epoch - 10ms/step
# Epoch 9/50
# 92/92 - 1s - loss: 0.0342 - val_loss: 0.0320 - 931ms/epoch - 10ms/step
# Epoch 10/50
# 92/92 - 1s - loss: 0.0341 - val_loss: 0.0320 - 928ms/epoch - 10ms/step
# Epoch 11/50
# 92/92 - 1s - loss: 0.0341 - val_loss: 0.0321 - 931ms/epoch - 10ms/step
# Epoch 12/50
# 92/92 - 1s - loss: 0.0342 - val_loss: 0.0326 - 922ms/epoch - 10ms/step
# Epoch 13/50
# 92/92 - 1s - loss: 0.0342 - val_loss: 0.0318 - 933ms/epoch - 10ms/step
# Epoch 14/50
# 92/92 - 1s - loss: 0.0341 - val_loss: 0.0321 - 922ms/epoch - 10ms/step
# Epoch 15/50
# 92/92 - 1s - loss: 0.0341 - val_loss: 0.0318 - 917ms/epoch - 10ms/step
# Epoch 16/50
# 92/92 - 1s - loss: 0.0343 - val_loss: 0.0319 - 912ms/epoch - 10ms/step
# Epoch 17/50
# 92/92 - 1s - loss: 0.0341 - val_loss: 0.0319 - 916ms/epoch - 10ms/step
# Epoch 18/50
# 92/92 - 1s - loss: 0.0340 - val_loss: 0.0318 - 923ms/epoch - 10ms/step
# Epoch 19/50
# 92/92 - 1s - loss: 0.0340 - val_loss: 0.0319 - 919ms/epoch - 10ms/step
# Epoch 20/50
# 92/92 - 1s - loss: 0.0341 - val_loss: 0.0318 - 960ms/epoch - 10ms/step
# Epoch 21/50
# 92/92 - 1s - loss: 0.0340 - val_loss: 0.0322 - 934ms/epoch - 10ms/step
# Epoch 22/50
# 92/92 - 1s - loss: 0.0341 - val_loss: 0.0322 - 921ms/epoch - 10ms/step
# Epoch 23/50
# 92/92 - 1s - loss: 0.0340 - val_loss: 0.0320 - 918ms/epoch - 10ms/step
# Epoch 24/50
# 92/92 - 1s - loss: 0.0340 - val_loss: 0.0318 - 915ms/epoch - 10ms/step
# Epoch 25/50
# 92/92 - 1s - loss: 0.0339 - val_loss: 0.0323 - 919ms/epoch - 10ms/step
# Epoch 26/50
# 92/92 - 1s - loss: 0.0340 - val_loss: 0.0322 - 933ms/epoch - 10ms/step
# Epoch 27/50
# 92/92 - 1s - loss: 0.0340 - val_loss: 0.0319 - 979ms/epoch - 11ms/step
# Epoch 28/50
# 92/92 - 1s - loss: 0.0339 - val_loss: 0.0318 - 932ms/epoch - 10ms/step
# Epoch 29/50
# 92/92 - 1s - loss: 0.0338 - val_loss: 0.0318 - 933ms/epoch - 10ms/step
# Epoch 30/50
# 92/92 - 1s - loss: 0.0338 - val_loss: 0.0317 - 931ms/epoch - 10ms/step
# Epoch 31/50
# 92/92 - 1s - loss: 0.0339 - val_loss: 0.0322 - 919ms/epoch - 10ms/step
# Epoch 32/50
# 92/92 - 1s - loss: 0.0339 - val_loss: 0.0317 - 926ms/epoch - 10ms/step
# Epoch 33/50
# 92/92 - 1s - loss: 0.0338 - val_loss: 0.0323 - 959ms/epoch - 10ms/step
# Epoch 34/50
# 92/92 - 1s - loss: 0.0338 - val_loss: 0.0318 - 925ms/epoch - 10ms/step
# Epoch 35/50
# 92/92 - 1s - loss: 0.0338 - val_loss: 0.0318 - 927ms/epoch - 10ms/step
# Epoch 36/50
# 92/92 - 1s - loss: 0.0338 - val_loss: 0.0327 - 996ms/epoch - 11ms/step
# Epoch 37/50
# 92/92 - 1s - loss: 0.0337 - val_loss: 0.0321 - 933ms/epoch - 10ms/step
# Epoch 38/50
# 92/92 - 1s - loss: 0.0338 - val_loss: 0.0318 - 936ms/epoch - 10ms/step
# Epoch 39/50
# 92/92 - 1s - loss: 0.0338 - val_loss: 0.0324 - 943ms/epoch - 10ms/step
# Epoch 40/50
# 92/92 - 1s - loss: 0.0337 - val_loss: 0.0321 - 935ms/epoch - 10ms/step
# Epoch 41/50
# 92/92 - 1s - loss: 0.0338 - val_loss: 0.0332 - 913ms/epoch - 10ms/step
# Epoch 42/50
# 92/92 - 1s - loss: 0.0337 - val_loss: 0.0318 - 916ms/epoch - 10ms/step
# Epoch 43/50
# 92/92 - 1s - loss: 0.0337 - val_loss: 0.0327 - 924ms/epoch - 10ms/step
# Epoch 44/50
# 92/92 - 1s - loss: 0.0335 - val_loss: 0.0319 - 916ms/epoch - 10ms/step
# Epoch 45/50
# 92/92 - 1s - loss: 0.0335 - val_loss: 0.0327 - 937ms/epoch - 10ms/step
# Epoch 46/50
# 92/92 - 1s - loss: 0.0336 - val_loss: 0.0319 - 942ms/epoch - 10ms/step
# Epoch 47/50
# 92/92 - 1s - loss: 0.0335 - val_loss: 0.0322 - 918ms/epoch - 10ms/step
# Epoch 48/50
# 92/92 - 1s - loss: 0.0335 - val_loss: 0.0327 - 928ms/epoch - 10ms/step
# Epoch 49/50
# 92/92 - 1s - loss: 0.0334 - val_loss: 0.0331 - 922ms/epoch - 10ms/step
# Epoch 50/50
# 92/92 - 1s - loss: 0.0336 - val_loss: 0.0319 - 959ms/epoch - 10ms/step

# %%
#tạo testing data set
test_data = scaler_data[train_size - n_lag: , :]
x_test = []
y_test = data_with_lagged[train_size:]

for i in range(n_lag, len(test_data)):
  x_test.append(test_data[i-n_lag:i, :])

x_test = np.asarray(x_test)
print(x_test.shape, y_test.shape)
# Out:
# (1610, 7, 8) (1610, 8)

# %%
#get the models predicted price value
predictions = model_gru_hour_2.predict(x_test)
predictions = xscaler.inverse_transform(predictions)
predictions
# Out:
# 51/51 [==============================] - 1s 3ms/step
# array([[4.61027175e-01, 1.01528564e+04, 1.88521609e-01, ...,
#         4.80920792e+01, 1.02188672e+04, 1.00339883e+04],
#        [5.64731121e-01, 1.01508330e+04, 1.89081982e-01, ...,
#         4.31806412e+01, 1.02263877e+04, 1.00656289e+04],
#        [4.75494742e-01, 1.01895986e+04, 1.85978577e-01, ...,
#         4.90691986e+01, 1.01906934e+04, 1.00330205e+04],
#        ...,
#        [5.36103964e-01, 7.17086279e+03, 1.83735520e-01, ...,
#         3.78607445e+01, 7.27963281e+03, 7.14700732e+03],
#        [5.05509198e-01, 7.22065234e+03, 1.84427217e-01, ...,
#         4.13770561e+01, 7.24435107e+03, 7.10743555e+03],
#        [4.22938973e-01, 7.30495068e+03, 1.84683204e-01, ...,
#         4.94893799e+01, 7.23296533e+03, 7.13182227e+03]], dtype=float32)

# %%
#sai số
rmse = (((y_test - predictions)**2).mean())
mae = np.abs((y_test - predictions).mean())
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
smape = (100 / len(y_test)) * np.sum(2 * np.abs(predictions - y_test) / (np.abs(predictions) + np.abs(y_test)))
print(rmse["Close"], mae["Close"], mape["Close"], smape["Close"])
# Out:
# 17305.543257700647 30.94562301048135 1.1309803320437664 1.1296130081802198
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#
valid = data_with_lagged[train_size:]
valid['Predictions'] = predictions[:, 1]

#hiển thị dữ liệu gần đây
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Giá (USD)', fontsize=18)
plt.plot(valid[['Close','Predictions']])
plt.legend(['Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_6476\3531470222.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions[:, 1]

# %%
#create file if it does not exist
data = {
    'Model': 'GRU',
    'Thông tin': ['MAE', 'MSE', 'MAPE', 'sMAPE'],
    'Kết quả': [mae["Close"], rmse["Close"], mape["Close"], smape["Close"]]
}
result_table = pd.read_csv("result-hours.csv")
result_table['Price + Twitter'] = [mae["Close"], rmse["Close"], mape["Close"], smape["Close"]]
result_table.to_csv("result-hours.csv", index=False)
result_table
# Out:
#   Model Thông tin        Price  Price + Twitter
# 0   GRU       MAE    35.487260        30.945623
# 1   GRU       MSE  8514.646184     17305.543258
# 2   GRU      MAPE     0.709688         1.130980
# 3   GRU     sMAPE     0.713099         1.129613
