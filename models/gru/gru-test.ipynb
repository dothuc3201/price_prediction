# %%
#imports các thư viện
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat


import keras.utils
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Dense
from keras.layers import GRU
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
def rsi(data, period: int = 14):

    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity (độ trễ) - days or hours
lag_granularity = "days"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "day"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/" + \
    analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_" + \
    str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename, index_col='DateTime', parse_dates=True)

# %%
#group by datetime
df = df.groupby('DateTime').agg(lambda x: x.mean())
df
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17004\3489936249.py:2: FutureWarning: ['dt'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df = df.groupby('DateTime').agg(lambda x: x.mean())
#                              Close  Volume_(BTC)  Weighted_Price   neg_pol  \
# DateTime
# 2018-08-30 00:00:00+00:00  7027.99      5.484323     6979.227679  0.043827
# 2018-08-31 00:00:00+00:00  7187.23      3.694477     7097.021073  0.039833
# 2018-09-01 00:00:00+00:00  7275.00      2.830380     7233.487967  0.036618
# 2018-09-02 00:00:00+00:00  7301.01      2.130486     7260.380171  0.047145
# 2018-09-03 00:00:00+00:00  7357.07      3.392408     7317.186602  0.045408
# ...                            ...           ...             ...       ...
# 2019-11-19 00:00:00+00:00  8085.36      2.133512     8098.781070  0.066980
# 2019-11-20 00:00:00+00:00  7618.17      7.593120     7834.680432  0.060034
# 2019-11-21 00:00:00+00:00  7272.99     16.570352     7301.606288  0.071387
# 2019-11-22 00:00:00+00:00  7308.09      4.480279     7236.946563  0.079548
# 2019-11-23 00:00:00+00:00  7087.81      3.120988     7211.746257  0.069257
#
#                             neu_pol   pos_pol  compound  Tweet_vol
# DateTime
# 2018-08-30 00:00:00+00:00  0.825543  0.130654  0.230801      557.0
# 2018-08-31 00:00:00+00:00  0.847201  0.112971  0.196773      902.0
# 2018-09-01 00:00:00+00:00  0.846208  0.117174  0.208065      818.0
# 2018-09-02 00:00:00+00:00  0.837654  0.115190  0.163561      860.0
# 2018-09-03 00:00:00+00:00  0.839805  0.114770  0.181093      980.0
# ...                             ...       ...       ...        ...
# 2019-11-19 00:00:00+00:00  0.751580  0.181439  0.269207    62924.0
# 2019-11-20 00:00:00+00:00  0.744159  0.195808  0.297821    61536.0
# 2019-11-21 00:00:00+00:00  0.744532  0.184078  0.250644    69663.0
# 2019-11-22 00:00:00+00:00  0.748070  0.172377  0.214543    74716.0
# 2019-11-23 00:00:00+00:00  0.750448  0.180296  0.251346    35701.0
#
# [451 rows x 8 columns]

# %%
#tính toán các chỉ số indicator: rsi, ma
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = True
add_longMAvg = True
add_shortMAvg = True

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()

if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17004\259356298.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17004\259356298.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity', 'Tweet_vol', 'Volume_(BTC)'] if analyser == "Textblob" else [
    'Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")

if(add_longMAvg):
    features.append("long_mavg")

if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
data_with_lagged = df_copy.dropna()
data_with_lagged
# Out:
#                            Change    Close   pos_pol   neg_pol  Tweet_vol  \
# DateTime
# 2018-10-04 00:00:00+00:00       1  6558.37  0.109372  0.040379      833.0
# 2018-10-05 00:00:00+00:00       0  6550.12  0.131859  0.041832      790.0
# 2018-10-06 00:00:00+00:00       0  6532.00  0.130573  0.031604      601.0
# 2018-10-07 00:00:00+00:00       1  6613.67  0.120965  0.034553      723.0
# 2018-10-08 00:00:00+00:00       0  6581.04  0.119315  0.044390      687.0
# ...                           ...      ...       ...       ...        ...
# 2019-11-19 00:00:00+00:00       0  8085.36  0.181439  0.066980    62924.0
# 2019-11-20 00:00:00+00:00       0  7618.17  0.195808  0.060034    61536.0
# 2019-11-21 00:00:00+00:00       0  7272.99  0.184078  0.071387    69663.0
# 2019-11-22 00:00:00+00:00       1  7308.09  0.172377  0.079548    74716.0
# 2019-11-23 00:00:00+00:00       0  7087.81  0.180296  0.069257    35701.0
#
#                                  RSI    long_mavg   short_mavg
# DateTime
# 2018-10-04 00:00:00+00:00  48.836903  6531.749524  6567.716667
# 2018-10-05 00:00:00+00:00  48.461841  6534.014762  6549.258889
# 2018-10-06 00:00:00+00:00  47.597220  6535.592857  6538.434444
# 2018-10-07 00:00:00+00:00  51.773599  6552.890000  6543.312222
# 2018-10-08 00:00:00+00:00  50.057073  6565.130476  6546.205556
# ...                              ...          ...          ...
# 2019-11-19 00:00:00+00:00  35.295210  8838.712381  8454.672222
# 2019-11-20 00:00:00+00:00  28.520124  8766.839524  8326.661111
# 2019-11-21 00:00:00+00:00  24.741288  8674.864286  8162.943333
# 2019-11-22 00:00:00+00:00  25.817638  8579.869048  8014.171111
# 2019-11-23 00:00:00+00:00  23.542050  8478.588571  7856.845556
#
# [416 rows x 8 columns]

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)

train = data_with_lagged.iloc[:train_size]
train = train.reset_index()
train = train.drop(['DateTime'], axis=1)
test = data_with_lagged.iloc[train_size:]
train
# Out:
#      Change     Close   pos_pol   neg_pol  Tweet_vol        RSI     long_mavg  \
# 0         1   6558.37  0.109372  0.040379      833.0  48.836903   6531.749524
# 1         0   6550.12  0.131859  0.041832      790.0  48.461841   6534.014762
# 2         0   6532.00  0.130573  0.031604      601.0  47.597220   6535.592857
# 3         1   6613.67  0.120965  0.034553      723.0  51.773599   6552.890000
# 4         0   6581.04  0.119315  0.044390      687.0  50.057073   6565.130476
# ..      ...       ...       ...       ...        ...        ...           ...
# 348       0  10192.25  0.183205  0.067056   116973.0  47.281141  10228.756667
# 349       1  10270.00  0.188101  0.060736    71351.0  49.205441  10265.267143
# 350       0  10130.00  0.183674  0.068687    70623.0  45.952835  10291.148095
# 351       0   9975.24  0.187195  0.063402    62544.0  42.600492  10306.603333
# 352       1  10057.84  0.190763  0.062166    51783.0  44.910487  10323.183810
#
#        short_mavg
# 0     6567.716667
# 1     6549.258889
# 2     6538.434444
# 3     6543.312222
# 4     6546.205556
# ..            ...
# 348  10263.055556
# 349  10283.132222
# 350  10279.127778
# 351  10230.932222
# 352  10203.487778
#
# [353 rows x 8 columns]

# %%
#chuẩn hóa
xscaler = MinMaxScaler(feature_range=(0, 1))
train = xscaler.fit_transform(train)
scaler_data = xscaler.transform(data_with_lagged)
print(train.shape, scaler_data.shape)
# Out:
# (353, 8) (416, 8)

# %%
X_train = []
y_train = []

for i in range(n_lag, len(train)):
  X_train.append(train[i-n_lag:i, :])
  y_train.append(train[i, :])

X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

print(X_train.shape, y_train.shape)
# Out:
# (346, 7, 8) (346, 8)

# %%
# np.random.seed(1)
# tf.random.set_seed(1)

# design network
model_gru_2 = Sequential()
neurons = 64
epochs = 100
dropout = 0.25
batch_size = 80
activ_func = "relu"

model_gru_2.add(GRU(neurons, return_sequences=True, input_shape=(
    X_train.shape[1], X_train.shape[2]), activation=activ_func))
model_gru_2.add(GRU(neurons, return_sequences=False))
model_gru_2.add(Dense(8))
model_gru_2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# early stopping callback
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =20)

# fit network
# history = model_gru_2.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=2, shuffle=True,validation_split=0.2,callbacks=[callback])
model_gru_2.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 4s 12ms/step - loss: 0.2976
# Epoch 2/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1576
# Epoch 3/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0829
# Epoch 4/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0691
# Epoch 5/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0653
# Epoch 6/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0563
# Epoch 7/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0526
# Epoch 8/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0483
# Epoch 9/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0445
# Epoch 10/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0419
# Epoch 11/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0399
# Epoch 12/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0392
# Epoch 13/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0388
# Epoch 14/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0382
# Epoch 15/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0378
# Epoch 16/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0373
# Epoch 17/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0371
# Epoch 18/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0368
# Epoch 19/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0365
# Epoch 20/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0363
# Epoch 21/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0360
# Epoch 22/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0359
# Epoch 23/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0357
# Epoch 24/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0356
# Epoch 25/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0355
# Epoch 26/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0354
# Epoch 27/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0355
# Epoch 28/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0352
# Epoch 29/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0354
# Epoch 30/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0352
# Epoch 31/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0350
# Epoch 32/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0350
# Epoch 33/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0349
# Epoch 34/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0347
# Epoch 35/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0348
# Epoch 36/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0344
# Epoch 37/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0347
# Epoch 38/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0350
# Epoch 39/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0344
# Epoch 40/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0344
# Epoch 41/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0342
# Epoch 42/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0343
# Epoch 43/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0342
# Epoch 44/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0343
# Epoch 45/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0340
# Epoch 46/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0341
# Epoch 47/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0339
# Epoch 48/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0339
# Epoch 49/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0340
# Epoch 50/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0338
# Epoch 51/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0338
# Epoch 52/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0336
# Epoch 53/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0335
# Epoch 54/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0335
# Epoch 55/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0334
# Epoch 56/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0333
# Epoch 57/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0333
# Epoch 58/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0332
# Epoch 59/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0332
# Epoch 60/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0329
# Epoch 61/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0329
# Epoch 62/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0328
# Epoch 63/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0329
# Epoch 64/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0327
# Epoch 65/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0325
# Epoch 66/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0325
# Epoch 67/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0326
# Epoch 68/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0325
# Epoch 69/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0322
# Epoch 70/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0321
# Epoch 71/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0321
# Epoch 72/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0320
# Epoch 73/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0320
# Epoch 74/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0320
# Epoch 75/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0319
# Epoch 76/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0324
# Epoch 77/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0332
# Epoch 78/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0327
# Epoch 79/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0342
# Epoch 80/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0336
# Epoch 81/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0325
# Epoch 82/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0325
# Epoch 83/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0320
# Epoch 84/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0316
# Epoch 85/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0315
# Epoch 86/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0319
# Epoch 87/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0313
# Epoch 88/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0311
# Epoch 89/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0312
# Epoch 90/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0312
# Epoch 91/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0320
# Epoch 92/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0324
# Epoch 93/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0318
# Epoch 94/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0322
# Epoch 95/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0322
# Epoch 96/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0323
# Epoch 97/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0313
# Epoch 98/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0320
# Epoch 99/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0315
# Epoch 100/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0313

# %%
#tạo testing data set
test_data = scaler_data[train_size - n_lag: , :]
x_test = []
y_test = data_with_lagged[train_size:]

for i in range(n_lag, len(test_data)):
  x_test.append(test_data[i-n_lag:i, :])

x_test = np.asarray(x_test)
print(x_test.shape, y_test.shape)
# Out:
# (63, 7, 8) (63, 8)

# %%
#get the models predicted price value
predictions = model_gru_2.predict(x_test)
predictions = xscaler.inverse_transform(predictions)
predictions.shape
# Out:
# 2/2 [==============================] - 1s 5ms/step
# (63, 8)

# %%
#sai số
mse = (((y_test - predictions)**2).mean())
mae = np.abs((y_test - predictions).mean())
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
smape = (100 / len(y_test)) * np.sum(2 * np.abs(predictions - y_test) / (np.abs(predictions) + np.abs(y_test)))
print(mse["Close"], mae["Close"], mape["Close"], smape["Close"])
# Out:
# 163760.56403942974 141.2736225818452 3.68978594669516 3.645041966584907
# c:\Users\Windows 10\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#
valid = data_with_lagged[train_size:]
valid['Predictions'] = predictions[:, 1]

#hiển thị dữ liệu gần đây
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Giá (USD)', fontsize=18)
plt.plot(valid[['Close','Predictions']])
plt.legend(['Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_17004\3531470222.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions[:, 1]

# %%
#create file if it does not exist
result_table = pd.read_csv("result.csv")
result_table['Price + Twitter'] = [mae["Close"], mse["Close"], mape["Close"], smape["Close"]]

result_table.to_csv("result.csv", index=False)
result_table
# Out:
#   Model Thông tin          Price  Price + Twitter
# 0  LSTM       MAE     226.815731       141.273623
# 1  LSTM       MSE  190913.287992    163760.564039
# 2  LSTM      MAPE       4.148686         3.689786
# 3  LSTM     sMAPE       4.056888         3.645042
